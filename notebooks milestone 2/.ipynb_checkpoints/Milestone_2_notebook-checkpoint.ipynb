# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
from collections import OrderedDict

# %% [markdown]
# ### what is done:
# construct Wikispeedia graph
# run page rank
# process the 'finished paths':
#     <br> - take into account back clicks to consider only the effective path
#     <br> - 'processed_paths' contains all the finished paths starting from the 'hub' (the page with highest page rank in that path)
#
#
# #### see next step at the bottom
#
# ##### please update this cell to keep track of prject progress

# %%
links = pd.read_csv("wikispeedia_paths-and-graph/links.tsv", sep='\t', skiprows = 11, names = ['link_source', 'link_target'])
# links.tsv contains all links between articles. It can be used to contruct a graph

# %%
#verify that there is no missing source/target
links.any().isna()
# Out:
# link_source    False
# link_target    False
# dtype: bool

# %%
G = nx.from_pandas_edgelist(links, 'link_source', 'link_target', create_using=nx.DiGraph())

# %%
dangling_nodes = []
for node, out_deg in G.out_degree():
    if out_deg == 0:
        dangling_nodes.append(node)
        
dangling_nodes
# Out:
# ['Osteomalacia',
#  'Local_community',
#  'Directdebit',
#  'Duchenne_muscular_dystrophy',
#  'Klinefelter%27s_syndrome']

# %%
page_rank = nx.pagerank(G, alpha = 0.95)

# %%
keys = list(page_rank.keys())
vals = list(page_rank.values())
sorted_page_rank = {keys[i]: vals[i] for i in np.argsort(vals)[::-1]}

# %%
#At this step page rank is done for each page
# now we would like to consider the paths (FINISHED PATHS FOR NOW) and consider only the pages visited after the 'hub'

# %%
finished_paths = pd.read_csv("wikispeedia_paths-and-graph/paths_finished.tsv", sep='\t', skiprows = 17, names=['hashedIpAddress','timestamp','durationInSec','path','rating'])
unfinished_paths = pd.read_csv("wikispeedia_paths-and-graph/paths_unfinished.tsv", sep='\t', skiprows = 17, names=['hashedIpAddress' ,  'timestamp' ,  'durationInSec' ,  'path' ,  'target'   ,'type'])

# %%
finished_paths.head()
# Out:
#     hashedIpAddress   timestamp  durationInSec  \
# 0  3824310e536af032  1344753412             88
# 1  415612e93584d30e  1349298640            138
# 2  64dd5cd342e3780c  1265613925             37
# 3  015245d773376aab  1366730828            175
# 4  5295bca242be81fe  1372890414            110
#
#                                                 path  rating
# 0  14th_century;Europe;Africa;Atlantic_slave_trad...     3.0
# 1  14th_century;Niger;Nigeria;British_Empire;Slav...     NaN
# 2     14th_century;Renaissance;Ancient_Greece;Greece     NaN
# 3  14th_century;Italy;Roman_Catholic_Church;HIV;R...     3.0
# 4  14th_century;Europe;North_America;United_State...     NaN

# %%
unfinished_paths.head()
# Out:
#     hashedIpAddress   timestamp  durationInSec  \
# 0  2426091a53125110  1297054935           1804
# 1  26141fd878806294  1297055651           1805
# 2  2b015fb8181c48f2  1297090819           1818
# 3  53a53bc244e08a6a  1297094761             49
# 4  53a53bc244e08a6a  1297099105           1808
#
#                                    path            target     type
# 0                        Obi-Wan_Kenobi         Microsoft  timeout
# 1                         Julius_Caesar           Caracas  timeout
# 2  Malawi;Democracy;Alexander_the_Great     First_Crusade  timeout
# 3                              Paraguay  Mount_St._Helens  restart
# 4                      Paraguay;Bolivia  Mount_St._Helens  timeout

# %%
#final version of remove_unvisited_pages
# working well enfiiin

def remove_unvisited_pages(path):
    if path.count('<') == 0:
        return path
    
    i=0
    while i<len(path):

        if path[i] == '<':
        
            counter = 0
            tmp_i = i

            while tmp_i<len(path) and path[tmp_i] == '<':
       
                tmp_i +=1
                counter+=1
            v=max(0,i-counter)

            for j in range(v, i):

                path[j] = '<'
            i = tmp_i
        else:
            i+=1
    indx = np.where(np.array(path)=='<')[0]
    path = np.delete(np.array(path), indx)
    return path

# %%
#test remove_unvisited_pages
l =(finished_paths['path'].iloc[40]).split(';')
print(l)           
l=remove_unvisited_pages(l)
l
# Out:
# ['14th_century', 'Europe', '<', 'England', '<', 'Christianity', 'Anglicanism', 'United_States', 'Walt_Whitman', '<', 'Poetry_of_the_United_States', '<', '<', '<', 'French_Revolution', 'Age_of_Enlightenment', 'David_Hume', 'Philosophy', 'Fyodor_Dostoevsky', '<', '<', '<', '<', 'Constitutional_monarchy', 'Government', 'Anarchism', 'Henry_David_Thoreau']
# array(['14th_century', 'Christianity', 'Anglicanism', 'United_States',
#        'French_Revolution', 'Constitutional_monarchy', 'Government',
#        'Anarchism', 'Henry_David_Thoreau'], dtype='<U23')

# %%
processed_finished_paths = []
pages_with_no_rank_finished_paths = []  # those pages are missing in 'articles' ?! Should we add them to the graph ?
def process_paths(paths,processed_paths,pages_with_no_rank) :
    for i, s in paths.iterrows():
        path_split=(paths['path'].iloc[i]).split(';')
        path_split = remove_unvisited_pages(path_split)
        ranks = []
        for elem in path_split:
            r = page_rank.get(elem, -1)
            if r==-1:
                pages_with_no_rank.append(elem)
            ranks.append(r)

        processed_paths.append(path_split[np.argmax(ranks):])

# %%
#processed paths contains all the paths starting from the 'hub' (selected as the page with highest page rank in that path)

# %%
processed_finished_paths = []
pages_with_no_rank_finished_paths = []  # those pages are missing in 'articles' ?! Should we add them to the graph ?
process_paths(finished_paths,processed_finished_paths,pages_with_no_rank_finished_paths)  
processed_finished_paths
# Out:
# [['Europe', 'Africa', 'Atlantic_slave_trade', 'African_slave_trade'],
#  ['Africa', 'Atlantic_slave_trade', 'African_slave_trade'],
#  ['Greece'],
#  ['Italy',
#   'Roman_Catholic_Church',
#   'HIV',
#   'Ronald_Reagan',
#   'President_of_the_United_States',
#   'John_F._Kennedy'],
#  ['United_States', 'President_of_the_United_States', 'John_F._Kennedy'],
#  ['China', 'Gunpowder', 'Fire'],
#  ['Color', 'Rainbow'],
#  ['Light', 'Rainbow'],
#  ['Color', 'Rainbow'],
#  array(['Science', 'Nature', 'Weather', 'Sun', 'Earth%27s_atmosphere',
#         'Ultraviolet', 'Color', 'Light', 'Rainbow'], dtype='<U20'),
#  ['Christianity',
#   'Bible',
#   'God',
#   'Nature',
#   'Earth%27s_atmosphere',
#   'Ultraviolet',
#   'Optical_fiber',
#   'Light',
#   'Rainbow'],
#  ['Light', 'Rainbow'],
#  array(['Sun', 'Isaac_Newton', 'Rainbow'], dtype='<U12'),
#  array(['Water', 'Rainbow'], dtype='<U17'),
#  ['Water', 'Rainbow'],
#  array(['Physics', 'Speed_of_light', 'Rainbow'], dtype='<U14'),
#  ['19th_century',
#   'The_Origin_of_Species',
#   'Biology',
#   'Science',
#   'Physics',
#   'Speed_of_light',
#   'Rainbow'],
#  ['India', 'Rice', 'Rain', 'Acid_rain', 'Cloud', 'Color', 'Rainbow'],
#  array(['Color', 'Rainbow'], dtype='<U12'),
#  ['France',
#   'World_War_II',
#   'Nuclear_weapon',
#   'Neutron',
#   'Physics',
#   'Speed_of_light',
#   'Rainbow'],
#  ['Christianity', 'Religion', 'Astrology', 'Isaac_Newton', 'Color', 'Rainbow'],
#  ['Light', 'Rainbow'],
#  ['Light', 'Rainbow'],
#  ['Color', 'Rainbow'],
#  ['Climate', 'Weather', 'Sunlight', 'Ultraviolet', 'Color', 'Rainbow'],
#  ['Isaac_Newton', 'Rainbow'],
#  ['Physics', 'Isaac_Newton', 'Color', 'Rainbow'],
#  ['Isaac_Newton', 'Rainbow'],
#  ['Light', 'Rainbow'],
#  ['Color', 'Rainbow'],
#  ['Time', 'Special_relativity', 'Speed_of_light', 'Rainbow'],
#  ['Egypt',
#   'Ancient_Egypt',
#   'Glass',
#   'Chromatic_aberration',
#   'Light',
#   'Rainbow'],
#  ['Isaac_Newton', 'Rainbow'],
#  ['Atlantic_Ocean', 'Ocean', 'Seawater', 'Sodium'],
#  ['Science', 'Chemistry', 'Sodium'],
#  array(['England', 'London', 'Spanish_Armada', 'England', '10th_century',
#         '11th_century', '12th_century', '13th_century', '14th_century',
#         '15th_century', '16th_century', 'Francis_Drake',
#         'Elizabeth_I_of_England'], dtype='<U22'),
#  ['England', 'James_I_of_England', 'Elizabeth_I_of_England'],
#  ['14th_century',
#   'Hundred_Years%27_War',
#   'Henry_VI_of_England',
#   'Wars_of_the_Roses',
#   'Henry_VIII_of_England',
#   'Elizabeth_I_of_England'],
#  ['14th_century',
#   'Hundred_Years%27_War',
#   'Henry_VI_of_England',
#   'Wars_of_the_Roses',
#   'Henry_VIII_of_England',
#   'Elizabeth_I_of_England'],
#  ['14th_century',
#   'Edward_III_of_England',
#   'Windsor_Castle',
#   'Elizabeth_I_of_England'],
#  array(['United_States', 'French_Revolution', 'Constitutional_monarchy',
#         'Government', 'Anarchism', 'Henry_David_Thoreau'], dtype='<U23'),
#  array(['United_States', 'Fine_art', 'Drawing', 'Art'], dtype='<U30'),
#  ['Periodic_table', 'Chromium'],
#  ['Oxygen', 'Chemical_element', 'Periodic_table', 'Chromium'],
#  ['Physics', 'Atom'],
#  ['Water', 'Atom'],
#  array(['Global_warming', 'Climate_change', 'Ice_age'], dtype='<U33'),
#  ['Global_warming', 'Climate_change', 'Ice_age'],
#  array(['Global_warming', 'Ice_age'], dtype='<U33'),
#  ['Pacific_Ocean', '16th_century', '8th_century'],
#  ['United_States',
#   'Medicine',
#   'Science',
#   'Chemistry',
#   'Iron',
#   'Chemical_element',
#   'Carbon',
#   'Buckminster_Fuller'],
#  array(['Atlantic_Ocean', 'Tropical_cyclone', 'Sun', 'Comet',
#         'Comet_Hale-Bopp', 'Great_comet'], dtype='<U30'),
#  ['United_States',
#   'George_Washington',
#   'American_Revolutionary_War',
#   'British_Empire',
#   'James_I_of_England',
#   'James_II_of_England'],
#  ['England', 'James_I_of_England', 'James_II_of_England'],
#  ['Spain'],
#  ['English_language',
#   'Latin',
#   'Italy',
#   'Vienna',
#   'Opera',
#   'Ludwig_van_Beethoven',
#   'Piano',
#   'Jazz'],
#  array(['Culture', 'Folk_music', 'Louis_Armstrong', 'Jazz'], dtype='<U30'),
#  array(['United_States', 'Jazz'], dtype='<U30'),
#  ['Chicago', 'Jazz'],
#  ['Cuba', 'Salsa_music', 'Jazz'],
#  ['Spain', 'European_Union', 'United_Nations', 'Switzerland', 'Liechtenstein'],
#  ['Europe', 'Liechtenstein'],
#  ['Europe', 'Sweden'],
#  ['Africa', 'Burundi'],
#  ['Oxygen', 'Hydrogen_peroxide'],
#  array(['United_States', 'New_York_City', 'United_Nations',
#         'International_Court_of_Justice'], dtype='<U30'),
#  ['Portugal', 'Lisbon'],
#  ['United_States_dollar',
#   'Richard_Nixon',
#   'President_of_the_United_States',
#   'William_McKinley'],
#  ['United_States', 'President_of_the_United_States', 'William_McKinley'],
#  ['President_of_the_United_States', 'William_McKinley'],
#  array(['Petroleum', 'Climate_change', 'Global_warming', 'Sea_level_rise',
#         'Effects_of_global_warming'], dtype='<U25'),
#  ['England', 'Season', 'Winter', 'Bat', 'Vampire_bat'],
#  ['Europe',
#   'Romania',
#   'Football_%28soccer%29',
#   'FIFA_World_Cup',
#   'Brazil',
#   'Amazon_Rainforest',
#   'Mammal',
#   'Bat',
#   'Vampire_bat'],
#  ['Money', 'Barley', 'Bread'],
#  ['List_of_countries_by_system_of_government', 'Sweden', 'Alfred_Nobel'],
#  ['London', 'University_of_Cambridge', 'Oxford'],
#  ['Europe', 'Paris', 'RER'],
#  ['England',
#   'British_Isles',
#   'River_Severn',
#   'Wader',
#   'Bird',
#   'Hawk',
#   'Sparrowhawk'],
#  ['Germany', 'Dresden'],
#  ['Earth', 'Mammal', 'Elephant'],
#  ['Water', 'Hydrogen'],
#  array(['Physics', 'Chemistry', 'Water', 'Hydrogen'], dtype='<U12'),
#  array(['Hydrogen'], dtype='<U12'),
#  ['United_States', 'Minnesota'],
#  ['United_States', 'Minnesota'],
#  array(['Animal', 'Fish', 'Fishing', 'Trout'], dtype='<U12'),
#  array(['Water', 'Fishing', 'Trout'], dtype='<U14'),
#  ['Atlantic_Ocean', 'Cod', 'Fish', 'Fishing', 'Trout'],
#  array(['Animal', 'Fish', 'Fishing', 'Trout'], dtype='<U12'),
#  ['Iron',
#   'Chemical_element',
#   'Neon',
#   'Sodium',
#   'Magnesium',
#   'Aluminium',
#   'Silicon',
#   'Phosphorus',
#   'Sulfur',
#   'Chlorine',
#   'Argon',
#   'Potassium',
#   'Potassium_iodide'],
#  ['Physics', 'Chemistry', 'Salt', 'Potassium', 'Potassium_iodide'],
#  ['Physics', 'Chemistry', 'Periodic_table', 'Potassium', 'Potassium_iodide'],
#  ['United_States', 'Tennis', 'Martina_Navratilova'],
#  ['United_States',
#   'Education_in_the_United_States',
#   'Computer',
#   'Internet',
#   'Microsoft',
#   'Microsoft_Windows',
#   'Macintosh',
#   'Internet',
#   'World_Wide_Web',
#   'Mozilla_Firefox'],
#  array(['Albert_Einstein', 'Electrical_engineering', 'Computer',
#         'World_Wide_Web', 'Mozilla_Firefox'], dtype='<U22'),
#  array(['Physics', 'Computer', 'Internet', 'OpenOffice.org',
#         'Mozilla_Firefox'], dtype='<U15'),
#  ['Earth',
#   'Government',
#   'Communication',
#   'Internet',
#   'World_Wide_Web',
#   'Mozilla_Firefox'],
#  ['Physics',
#   'Science',
#   'Computer_science',
#   'Internet',
#   'World_Wide_Web',
#   'Mozilla_Firefox'],
#  ['California', 'Computer', 'World_Wide_Web', 'Mozilla_Firefox'],
#  array(['Internet', 'OpenOffice.org', 'Mozilla_Firefox'], dtype='<U15'),
#  ['Physics',
#   'Electrical_engineering',
#   'Computer',
#   'Internet',
#   'Microsoft',
#   'World_Wide_Web',
#   'History_of_the_Internet',
#   'Internet_Explorer',
#   'Mozilla_Firefox'],
#  ['Physics', 'Computer', 'Internet', 'World_Wide_Web', 'Mozilla_Firefox'],
#  array(['Internet', 'World_Wide_Web', 'Mozilla_Firefox'], dtype='<U15'),
#  array(['Physics', 'Technology', 'Computer', 'Internet', 'World_Wide_Web',
#         'Mozilla_Firefox'], dtype='<U15'),
#  array(['Europe', 'Iceland', 'Surtsey'], dtype='<U18'),
#  array(['Atlantic_Ocean', 'Iceland', 'Surtsey'], dtype='<U14'),
#  ['Europe', 'Iceland', 'Surtsey'],
#  ['Romania', 'The_Wall_Street_Journal', 'Mass_media', 'Internet'],
#  ['United_States', 'Internet'],
#  ['England', 'Winston_Churchill'],
#  ['World_War_II', 'Winston_Churchill'],
#  ['World_War_II', 'Winston_Churchill'],
#  ['United_Kingdom', 'World_War_II', 'Winston_Churchill'],
#  ['World_War_II', 'Winston_Churchill'],
#  ['Europe',
#   'United_Kingdom',
#   'Prime_Minister_of_the_United_Kingdom',
#   'Winston_Churchill'],
#  ['World_War_II', 'Winston_Churchill'],
#  ['United_Kingdom', 'World_War_II', 'Winston_Churchill'],
#  array(['World_War_II', 'Winston_Churchill'], dtype='<U17'),
#  array(['World_War_II', 'Winston_Churchill'], dtype='<U17'),
#  ['World_War_II', 'Winston_Churchill'],
#  array(['United_Kingdom', 'World_War_II', 'Winston_Churchill'],
#        dtype='<U19'),
#  ['France', 'Euro', 'Currency', 'Gold'],
#  ['Currency', 'Money', 'Gold'],
#  ['Africa', 'Gold'],
#  ['Science', 'Atom', 'Chemistry', 'Gold'],
#  array(['Literature', 'Novel', 'Fiction', 'Propaganda',
#         'Nineteen_Eighty-Four'], dtype='<U20'),
#  ['Language',
#   'J._R._R._Tolkien',
#   'C._S._Lewis',
#   'Propaganda',
#   'Nineteen_Eighty-Four'],
#  ['Africa', 'Crocodile'],
#  array(['United_States', 'Bald_Eagle', 'Animal', 'Mammal', 'Dolphin',
#         'Fish', 'Whale_shark', 'Shark', 'Great_white_shark'], dtype='<U17'),
#  ['Atlantic_Ocean',
#   'Whale',
#   'Fish',
#   'Whale_shark',
#   'Shark',
#   'Great_white_shark'],
#  ['Atlantic_Ocean',
#   'Ocean',
#   'Pacific_Ocean',
#   'Great_Barrier_Reef',
#   'Humpback_Whale',
#   'Orca',
#   'Shark',
#   'Great_white_shark'],
#  array(['Fish', 'Whale_shark', 'Shark', 'Great_white_shark'], dtype='<U17'),
#  array(['United_States', 'Chicago', 'University_of_Chicago', 'Plutonium',
#         'Americium'], dtype='<U21'),
#  ['Europe', 'United_Kingdom', 'England', 'History_of_Anglo-Saxon_England'],
#  ['England', 'History_of_Anglo-Saxon_England'],
#  ['English_language', 'England', 'History_of_Anglo-Saxon_England'],
#  ['England', 'History_of_Anglo-Saxon_England'],
#  ['Africa', 'Lion', 'Antelope', 'Bongo_%28antelope%29'],
#  ['India', 'Mammal', 'Elephant', 'Ivory'],
#  ['Europe',
#   'United_Kingdom',
#   'British_Empire',
#   'India',
#   'Mammal',
#   'Elephant',
#   'Ivory'],
#  ['Africa', 'Elephant', 'Ivory'],
#  ['United_States',
#   'World_Health_Organization',
#   'Tobacco',
#   'Beetle',
#   'Mummy',
#   'Medicine',
#   'Health',
#   'Nutrition',
#   'Calcium',
#   'Vitamin_D',
#   'Milk',
#   'Mammal',
#   'Elephant_shrew',
#   'Elephant',
#   'Ivory'],
#  ['Africa', 'Elephant', 'Ivory'],
#  array(['Africa', 'Elephant', 'Ivory'], dtype='<U15'),
#  ['Africa', 'Elephant', 'Ivory'],
#  array(['Elephant', 'Ivory'], dtype='<U15'),
#  ['Indonesia', 'Elephant', 'Ivory'],
#  ['Africa', 'Elephant', 'Ivory'],
#  array(['Europe', 'Africa', 'Elephant', 'Ivory'], dtype='<U15'),
#  ['Ethiopia', 'Kenya', 'Elephant', 'Ivory'],
#  ['Elephant', 'Ivory'],
#  ['Elephant', 'Ivory'],
#  ['Africa', 'Elephant', 'Ivory'],
#  ['Latin', 'Roman_Empire', 'Maghreb', 'Africa', 'Elephant', 'Ivory'],
#  array(['Africa', 'Elephant', 'Ivory'], dtype='<U15'),
#  ['France', 'Sub-Saharan_Africa', 'Kenya', 'Elephant', 'Ivory'],
#  array(['Europe', 'Africa', 'Kenya', 'Elephant', 'Ivory'], dtype='<U19'),
#  ['Ethiopia', 'Democratic_Republic_of_the_Congo', 'Ivory'],
#  array(['Europe', 'Africa', 'Egypt', 'Sahara', 'Horse', 'Mammal',
#         'Elephant', 'Ivory'], dtype='<U15'),
#  ['Mammal', 'Elephant', 'Ivory'],
#  ['Ethiopia', 'Scramble_for_Africa', 'Ivory'],
#  ['Ocean'],
#  ['Atlantic_Ocean', 'Ocean'],
#  array(['Atlantic_Ocean', 'Ocean'], dtype='<U15'),
#  ['Ocean'],
#  ['Europe', 'Arctic_Ocean', 'Ocean'],
#  ['Atlantic_Ocean', 'Ocean'],
#  ['Atlantic_Ocean', 'Ocean'],
#  ['United_States', 'Pacific_Ocean', 'Ocean'],
#  ['Atlantic_Ocean', 'Ocean'],
#  ['English_language',
#   'World_War_II',
#   'Attack_on_Pearl_Harbor',
#   'Imperial_Japanese_Navy',
#   'Aircraft_carrier',
#   'Aircraft',
#   'Hydrogen',
#   'Water',
#   'Ocean'],
#  ['Portugal', 'Atlantic_Ocean', 'Ocean'],
#  ['Atlantic_Ocean', 'Ocean'],
#  ['Latin', 'Great_Britain', 'British_Isles', 'Atlantic_Ocean', 'Ocean'],
#  ['Ocean'],
#  ['France', 'Atlantic_Ocean', 'Ocean'],
#  ['Atlantic_Ocean', 'Ocean'],
#  ['Atlantic_Ocean', 'Ocean'],
#  ['Atlantic_Ocean', 'Ocean'],
#  array(['United_States', 'Pacific_Ocean', 'Water', 'Ocean'], dtype='<U15'),
#  array(['Atlantic_Ocean', 'Ocean'], dtype='<U15'),
#  ['Atlantic_Ocean', 'Ocean'],
#  ['Europe', 'Atlantic_Ocean', 'Ocean'],
#  ['Europe', 'Atlantic_Ocean', 'Ocean'],
#  ['Atlantic_Ocean', 'Ocean'],
#  ['Ocean'],
#  ['Ocean'],
#  array(['Ocean'], dtype='<U15'),
#  ['Ocean'],
#  ['Ocean'],
#  ['United_States', 'Caribbean_Sea', 'Atlantic_Ocean', 'Ocean'],
#  ['Ocean'],
#  ['Atlantic_Ocean', 'Ocean'],
#  ['Atlantic_Ocean', 'Ocean'],
#  ['Atlantic_Ocean', 'Ocean'],
#  ['Ocean'],
#  array(['Roman_Empire', 'Augustus', 'Julius_Caesar', 'Atlantic_Ocean',
#         'Ocean'], dtype='<U15'),
#  ['Middle_Ages',
#   'Scotland_in_the_High_Middle_Ages',
#   'Camel',
#   'Desert',
#   'Rain',
#   'Water',
#   'Ocean'],
#  ['Ocean'],
#  ['Ocean'],
#  ['Atlantic_Ocean', 'Ocean'],
#  ['Atlantic_Ocean',
#   'Ocean',
#   'Fish',
#   'Whale_shark',
#   'Shark',
#   'Great_white_shark'],
#  ['United_States',
#   'Atlantic_Ocean',
#   'Whale',
#   'Dolphin',
#   'Fish',
#   'Whale_shark',
#   'Shark',
#   'Great_white_shark'],
#  ['Africa', 'HIV', 'AIDS'],
#  ['Europe', 'United_Kingdom', 'England'],
#  ['England'],
#  ['Europe',
#   'Finland',
#   'European_Union',
#   'Europe',
#   'United_Kingdom',
#   'England'],
#  ['Europe', 'United_Kingdom', 'England'],
#  ['Europe', 'United_Kingdom', 'Great_Britain', 'England'],
#  ['United_Kingdom', 'England'],
#  ['England'],
#  ['United_Kingdom', 'England'],
#  ['Europe', 'England'],
#  ['English_language', 'England'],
#  ['Europe', 'United_Kingdom', 'England'],
#  ['United_Kingdom', 'England'],
#  ['United_Kingdom', 'England'],
#  ['Europe', 'England'],
#  ['United_Kingdom', 'England'],
#  ['Europe', 'England'],
#  ['United_Kingdom', 'England'],
#  ['Europe', 'United_Kingdom', 'England'],
#  ['Europe', 'England'],
#  ['France', 'United_Kingdom', 'England'],
#  ['Europe', 'United_Kingdom', 'England'],
#  ['English_language', 'England'],
#  ['Europe', 'England'],
#  ['English_language', 'England'],
#  ['Europe', 'United_Kingdom', 'England'],
#  ['Europe', 'England'],
#  ['Europe', 'United_Kingdom', 'England'],
#  ['United_Kingdom', 'England'],
#  ['United_Kingdom', 'England'],
#  ['English_language', 'England'],
#  ['Africa', 'Continent', 'North_America', 'Mexico'],
#  ['United_States', 'Potato'],
#  ['Africa', 'Cocoa', 'Almond', 'Fruit', 'Vegetable', 'Potato'],
#  ['United_States', 'Potato'],
#  ['Africa', 'Rice', 'Plant', 'Potato'],
#  ['Africa', 'Rice', 'Maize', 'Vegetable', 'Potato'],
#  ['Africa', 'Earth', 'Solar_System'],
#  ['Africa', 'Rice', 'Asia', 'Vietnam'],
#  ['Africa', 'Fossil', 'History'],
#  ['Africa', 'Earth', 'Moon', 'Solar_System', 'Sun'],
#  ['Africa', 'Continent', 'Earth', 'Sun'],
#  ['Africa', 'Continent', 'Earth', 'Sun'],
#  ['Africa', 'Indian_Ocean', 'Australia'],
#  array(['Africa', 'Rainforest', 'Tropics', 'Temperate'], dtype='<U10'),
#  ['Africa', 'Crocodile', 'Reptile', 'Dinosaur', 'Sauropodomorpha'],
#  ['Africa', 'Poverty'],
#  ['Africa', 'Gold', 'Xenon', 'Periodic_table', 'Americium'],
#  ['Africa', 'Diamond', 'Carbon', 'Periodic_table', 'Americium'],
#  array(['United_Kingdom', 'Parliament_of_the_United_Kingdom',
#         'Glorious_Revolution', 'James_II_of_England',
#         'Roman_Catholic_Church', 'Crusades', 'Middle_Ages', 'Dark_Ages',
#         'Age_of_Enlightenment', 'Physics', 'Mathematics',
#         'Differential_equation'], dtype='<U32'),
#  ['Africa',
#   'Belgium',
#   'European_Union',
#   'Latin_alphabet',
#   'Greece',
#   'Athens',
#   'Athena',
#   'Greek_mythology',
#   'Leonardo_da_Vinci',
#   'Engineering',
#   'Mathematics',
#   'Differential_equation'],
#  ['Africa', 'Human', 'Science', 'Mathematics', 'Differential_equation'],
#  ['Africa', 'Temperate', 'Aristotle', 'Mathematics', 'Differential_equation'],
#  array(['Africa', 'Earth', 'Photosynthesis', 'Photon', 'Physics',
#         'Maxwell%27s_equations', 'Manifold', 'Calculus',
#         'Differential_equation'], dtype='<U21'),
#  ['Africa',
#   'Ptolemy',
#   'Color',
#   'Physics',
#   'Mathematics',
#   'Differential_equation'],
#  array(['Africa', 'Egypt', 'Age_of_Enlightenment', 'Calculus',
#         'Differential_equation'], dtype='<U21'),
#  ['Latin',
#   'Science',
#   'Mathematics',
#   'Trigonometry',
#   'Trigonometric_function',
#   'Differential_equation'],
#  ['Africa', 'Language', 'Mathematics', 'Differential_equation'],
#  ['United_States', 'Education', 'Mathematics', 'Differential_equation'],
#  ['Africa', 'Egypt', 'Ancient_Egypt', 'Mathematics', 'Differential_equation'],
#  ['Africa', 'Human', 'Science', 'Mathematics', 'Differential_equation'],
#  ['Africa',
#   'Ancient_Greece',
#   'Renaissance',
#   'Mathematics',
#   'Differential_equation'],
#  ['English_language',
#   'England',
#   'Stephen_Hawking',
#   'Mathematics',
#   'Differential_equation'],
#  array(['Europe', 'British_Isles', 'Great_Britain', 'United_Kingdom',
#         'England', 'London', 'Hampstead_Heath'], dtype='<U15'),
#  ['United_Kingdom', 'London', 'Hampstead_Heath'],
#  ['Europe', 'United_Kingdom', 'London', 'Hampstead_Heath'],
#  ['United_States', 'California', 'Colorado_River', 'Lake_Mead'],
#  ['Japan', 'Nintendo', 'Computer_and_video_games', 'Pac-Man'],
#  array(['Africa', 'HIV', 'Human', 'Brain', 'Sleep'], dtype='<U6'),
#  ['English_language',
#   'Old_English_language',
#   '5th_century',
#   'Byzantine_Empire',
#   'Roman_Empire',
#   'Rhine',
#   'German_language',
#   'Soviet_Union',
#   'Federal_Bureau_of_Investigation',
#   'Library',
#   'Information',
#   'Mind',
#   'Psychology',
#   'Brain',
#   'Sleep'],
#  ['Africa', 'Human', 'Sleep'],
#  ['Africa',
#   'Famine',
#   'Leisure',
#   'Time',
#   'Philosophy',
#   'Philosophy_of_mind',
#   'Mind',
#   'Psychology',
#   'Brain',
#   'Sleep'],
#  array(['Africa', 'Human', 'Sleep'], dtype='<U6'),
#  ['Africa', 'Coffee', 'Cancer', 'Human', 'Sleep'],
#  ['Africa', 'Human', 'Brain', 'Sleep'],
#  ['Renaissance', 'Leonardo_da_Vinci', 'Visual_arts', 'Mona_Lisa', 'Art'],
#  ['Renaissance', 'Art'],
#  ['Art'],
#  ['German_language',
#   'Romania',
#   'Black_Sea',
#   'Georgia_%28country%29',
#   'Azerbaijan',
#   'Iran',
#   'Turkmenistan',
#   'Kazakhstan'],
#  ['Soviet_Union', 'Uzbekistan', 'Kazakhstan'],
#  array(['World_War_II', 'Soviet_Union', 'Russia', 'Kazakhstan'],
#        dtype='<U20'),
#  ['Russia', 'Kazakhstan'],
#  ['Soviet_Union', 'Turkmenistan', 'Kazakhstan'],
#  ['Europe', 'Russia', 'Kazakhstan'],
#  ['World_War_II', 'Soviet_Union', 'Turkmenistan', 'Kazakhstan'],
#  ['World_War_II',
#   'Republic_of_China',
#   'Mongolia',
#   'Soviet_Union',
#   'Uzbekistan',
#   'Kazakhstan'],
#  ['Soviet_Union', 'Uzbekistan', 'Kazakhstan'],
#  ['Russia', 'Kazakhstan'],
#  ['World_War_II', 'Joseph_Stalin'],
#  ['Philosophy', 'Francis_Bacon'],
#  ['South_America', 'Continent', 'Antarctica', 'Ice_sheet'],
#  array(['Geology', 'History_of_Earth', 'Ice_age', 'Ice_sheet'],
#        dtype='<U20'),
#  ['Age_of_Enlightenment', 'Voltaire'],
#  ['Physics',
#   'Science',
#   'Nature',
#   'Geology',
#   'Volcano',
#   'Magma',
#   'Igneous_rock'],
#  ['Physics', 'Archaeology', 'Geology', 'Magma', 'Igneous_rock'],
#  ['Volcano', 'Magma', 'Igneous_rock'],
#  array(['Physics', 'Science', 'Archaeology', 'Paleontology', 'Fossil',
#         'Mineral', 'Geology', 'Magma', 'Igneous_rock'], dtype='<U20'),
#  ['Christianity', 'Last_Supper'],
#  ['Biology', 'Yeast'],
#  ['United_States', 'Florida', 'Hurricane_Andrew'],
#  ['Earth', 'Solar_System', 'Planet', 'Extrasolar_planet'],
#  ['Age_of_Enlightenment', 'Galileo_Galilei', 'Astronomy', 'Extrasolar_planet'],
#  ['World_War_II', 'War', 'United_Nations', 'Nobel_Peace_Prize', 'Peace'],
#  ['Agriculture', 'History_of_the_world', 'Human', 'Language'],
#  ['China', 'People%27s_Republic_of_China', 'Mao_Zedong'],
#  ['Agriculture', 'History_of_the_world', 'Communism', 'Mao_Zedong'],
#  ['China', 'People%27s_Republic_of_China', 'Mao_Zedong'],
#  array(['Agriculture', 'Fossil_fuel', 'Coal', 'Triassic', 'Dinosaur',
#         'Ornithischia'], dtype='<U12'),
#  ['Agriculture', 'Food', 'Famine'],
#  ['Agriculture', 'Barley'],
#  ['France', 'Napoleonic_Wars', 'Russia', 'Ukraine', 'Kiev'],
#  ['Germany', 'Poland', 'Ukraine', 'Kiev'],
#  ['Germany', 'Ukraine', 'Kiev'],
#  array(['Europe', 'Owl', 'Bird', 'House_Sparrow', 'Sparrow'], dtype='<U13'),
#  ['Animal', 'Bird', 'House_Sparrow', 'Sparrow'],
#  ['Agriculture', 'Egg_%28food%29', 'Bird', 'House_Sparrow', 'Sparrow'],
#  ['Agriculture', 'Egg_%28food%29', 'Bird', 'House_Sparrow', 'Sparrow'],
#  array(['Agriculture', 'Egg_%28food%29', 'Ostrich', 'Sparrow'],
#        dtype='<U14'),
#  ['Agriculture', 'Egg_%28food%29', 'Bird', 'House_Sparrow', 'Sparrow'],
#  ['Agriculture',
#   'Food',
#   'Protein',
#   'Evolution',
#   'Bird',
#   'House_Sparrow',
#   'Sparrow'],
#  ['Agriculture', 'Egg_%28food%29', 'Bird', 'House_Sparrow', 'Sparrow'],
#  ['Agriculture',
#   'Cocoa',
#   'South_America',
#   'Brazil',
#   'Rainforest',
#   'Bird',
#   'House_Sparrow',
#   'Sparrow'],
#  ['Agriculture', 'Maize', 'Winter', 'Bird', 'House_Sparrow', 'Sparrow'],
#  ['Agriculture',
#   'Food',
#   'Protein',
#   'Feather',
#   'Bird',
#   'House_Sparrow',
#   'Sparrow'],
#  ['Agriculture',
#   'Global_warming',
#   'Tornado',
#   'Tropical_cyclone',
#   'Hurricane_Katrina',
#   '2005_Atlantic_hurricane_season',
#   'Tropical_Storm_Delta_%282005%29'],
#  ['Africa'],
#  ['Africa'],
#  ['Africa'],
#  ['Human', 'Art', 'Film'],
#  ['Germany'],
#  ['Christianity', 'Religion'],
#  ['United_States', 'Judaism', 'Jesus'],
#  ['Christianity', 'Jesus'],
#  ['France', 'Roman_Catholic_Church', 'Jesus'],
#  ['Africa',
#   'Latin_America',
#   'Guadeloupe',
#   'Christopher_Columbus',
#   'Jamaica',
#   'Dominican_Republic',
#   'Jesus'],
#  ['Italy', 'Roman_Catholic_Church', 'Jesus'],
#  ['Human', 'Religion', 'Jesus'],
#  ['20th_century', 'Jew', 'Bible', 'Jesus'],
#  ['United_States', 'Judaism', 'Jesus'],
#  ['Christianity', 'Jesus'],
#  ['Christianity', 'Jesus'],
#  ['Italy', 'Vatican_City', 'Christianity', 'Jesus'],
#  ['United_States', 'Abraham_Lincoln', 'Bible', 'Jesus'],
#  array(['United_States', 'United_States_Bill_of_Rights',
#         'United_States_Constitution', 'Benjamin_Franklin', 'London',
#         'Roman_Empire', 'Jerusalem', 'Christianity', 'Jesus'], dtype='<U28'),
#  ['World_War_II', 'Jew', 'Judaism', 'Christianity', 'Jesus'],
#  ['Christianity', 'Jesus'],
#  ['Christianity', 'Jesus'],
#  ['Christianity', 'Jesus'],
#  ['Russia', 'Soviet_Union', 'Cold_War'],
#  ['United_Nations', 'Cold_War'],
#  ['20th_century', 'Cold_War'],
#  ['Africa', 'Jazz', 'Saxophone'],
#  array(['Indian_Ocean', 'Maldives'], dtype='<U18'),
#  ['United_States', 'Gulf_of_Mexico'],
#  ['United_States', 'Steel'],
#  ['France', 'Paris'],
#  ['19th_century', 'Napoleonic_Wars', 'Napoleon_I_of_France'],
#  ['France', 'Napoleon_I_of_France'],
#  ['World_War_II', 'Adolf_Hitler'],
#  ['World_War_II', 'Adolf_Hitler'],
#  ['Germany', 'Adolf_Hitler'],
#  ['Germany', 'Adolf_Hitler'],
#  ['France', 'Paris', 'Tour_de_France'],
#  array(['French_language', 'Paris', 'Tour_de_France'], dtype='<U20'),
#  ['French_language', 'Paris', 'Tour_de_France'],
#  ['France',
#   'French_language',
#   'Mass_media',
#   'Broadcasting',
#   'Internet',
#   'Advertising',
#   'Google',
#   'Bicycle',
#   'Tour_de_France'],
#  ['France', 'Paris', 'Tour_de_France'],
#  ['France', 'Paris', 'Tour_de_France'],
#  ['France', 'Paris', 'Tour_de_France'],
#  ['France', 'Paris', 'Tour_de_France'],
#  ['Human', 'Ethics'],
#  ['Animal', 'Fish', 'Fishing', 'Cod'],
#  ['AIDS', 'Virus', 'Common_cold', 'Soup'],
#  ['German_language', 'Hungary', 'Paprika'],
#  array(['Hungary', 'Paprika'], dtype='<U9'),
#  array(['Cancer', 'Anemia', 'Parsley', 'Paprika'], dtype='<U7'),
#  array(['Human', 'Mammal', 'Bird', 'Flamingo'], dtype='<U8'),
#  ['Bird', 'Flamingo'],
#  ['Bird', 'Flamingo'],
#  ['Africa', 'Giraffe', 'Animal', 'Bird', 'Flamingo'],
#  ['Animal', 'Bird', 'Flamingo'],
#  array(['United_States', 'President_of_the_United_States',
#         'George_W._Bush', 'Tony_Blair'], dtype='<U30'),
#  ['United_Kingdom', 'Tony_Blair'],
#  ['Europe', 'Middle_East', 'Palestinian_territories'],
#  ['India', 'Hinduism', 'Varanasi'],
#  ['Africa', 'Hyena', 'Wildebeest'],
#  ['United_Kingdom', 'Bangladesh'],
#  ['Earth', 'Moon'],
#  ['World_War_II', 'Joseph_Stalin'],
#  ['Europe',
#   'Ancient_Greece',
#   'Roman_Greece',
#   'Roman_Empire',
#   'Western_Roman_Empire'],
#  ['France',
#   'Mediterranean_Sea',
#   'Ancient_Rome',
#   'Roman_Empire',
#   'Western_Roman_Empire'],
#  ['Roman_Empire', 'Western_Roman_Empire'],
#  ['Russia', 'Byzantine_Empire', 'Western_Roman_Empire'],
#  ['United_Kingdom', 'England', 'Rome', 'Ancient_Rome', 'Western_Roman_Empire'],
#  ['Hydrogen', 'Star', 'Sun', 'Solar_eclipse'],
#  ['Earth%27s_atmosphere', 'Ultraviolet', 'Sun', 'Solar_eclipse'],
#  ['Helium', 'Solar_eclipse'],
#  ['Russia', 'Earth', 'Moon', 'Solar_eclipse'],
#  ['Earth%27s_atmosphere',
#   'Ultraviolet',
#   'Astronomy',
#   'Solar_System',
#   'Sun',
#   'Solar_eclipse'],
#  ['Hydrogen', 'Sun', 'Solar_eclipse'],
#  ['Hydrogen', 'Sun', 'Solar_eclipse'],
#  ['Hydrogen', 'Sun', 'Solar_eclipse'],
#  ['Earth', 'Sun', 'Solar_eclipse'],
#  ['Hydrogen', 'Sun', 'Solar_eclipse'],
#  ['Hydrogen', 'Star', 'Sun', 'Solar_eclipse'],
#  array(['United_States', 'United_States_Constitution'], dtype='<U26'),
#  ['India',
#   'Chess',
#   'Science',
#   'Technology',
#   'Computer_science',
#   'Computer_programming',
#   'Microsoft',
#   'World_Wide_Web',
#   'Google'],
#  array(['World_War_II', 'San_Francisco%2C_California', 'California',
#         'Computer', 'Internet', 'World_Wide_Web', 'Gmail', 'Google'],
#        dtype='<U27'),
#  ['California', 'Computer', 'Internet', 'World_Wide_Web', 'Google'],
#  ['World_War_II',
#   'Enigma_machine',
#   'England',
#   'Tim_Berners-Lee',
#   'World_Wide_Web',
#   'Google'],
#  array(['Science', 'University', 'Logic', 'Computer_science',
#         'Information', 'Mass_media', 'Internet', 'World_Wide_Web',
#         'Google'], dtype='<U23'),
#  ['United_States', 'Internet', 'World_Wide_Web', 'Google'],
#  ['United_Kingdom', 'Arctic_Monkeys', 'Internet', 'World_Wide_Web', 'Google'],
#  ['Science',
#   'World_Wide_Web',
#   'Internet',
#   'Microsoft',
#   'Computer',
#   'Microsoft_Windows',
#   'Windows_Vista',
#   'Internet_Explorer',
#   'Mozilla_Firefox',
#   'Google'],
#  array(['20th_century', 'Computer', 'Computer_programming',
#         'Microsoft_Windows', 'Spyware', 'Internet', 'World_Wide_Web',
#         'Google'], dtype='<U20'),
#  ['United_Kingdom', 'Computer', 'Internet', 'World_Wide_Web', 'Google'],
#  ['United_States', 'Internet', 'World_Wide_Web', 'Google'],
#  ['United_Kingdom', 'Computer', 'Internet', 'World_Wide_Web', 'Google'],
#  array(['United_Kingdom', 'Capitalism', 'Corporation', 'Employment',
#         'Cornell_University', 'Internet', 'World_Wide_Web', 'Google'],
#        dtype='<U18'),
#  array(['California', 'Computer', 'World_Wide_Web', 'Google'], dtype='<U20'),
#  ['World_War_II',
#   'Royal_Navy',
#   'Communication',
#   'Internet',
#   'World_Wide_Web',
#   'Google'],
#  array(['United_Kingdom', 'Computer', 'Internet', 'Advertising', 'Google'],
#        dtype='<U14'),
#  array(['United_States', 'Computer', 'World_Wide_Web', 'Google'],
#        dtype='<U14'),
#  ['United_Kingdom',
#   'HSBC',
#   'Corporation',
#   'Cooperative',
#   'Business',
#   'Wall_Street',
#   'Newspaper',
#   'Internet',
#   'World_Wide_Web',
#   'Google'],
#  ['United_Kingdom',
#   'Computer',
#   'Internet',
#   'World_Wide_Web',
#   'Gmail',
#   'Google'],
#  ['Internet', 'World_Wide_Web', 'Google'],
#  ['United_Kingdom', 'Computer', 'World_Wide_Web', 'Gmail', 'Google'],
#  array(['United_States', 'Internet', 'World_Wide_Web', 'Gmail', 'Google'],
#        dtype='<U14'),
#  ['United_Kingdom', 'Computer', 'World_Wide_Web', 'Gmail', 'Google'],
#  ['United_States', 'Internet', 'World_Wide_Web', 'Google'],
#  ['United_States',
#   'Broadcasting',
#   'Internet',
#   'Microsoft',
#   'World_Wide_Web',
#   'Google'],
#  ['United_States',
#   'Computer',
#   'Internet',
#   'World_Wide_Web',
#   'Gmail',
#   'Google'],
#  ['United_Kingdom',
#   'English_language',
#   'Internet',
#   'World_Wide_Web',
#   'Google'],
#  ['United_States',
#   'California',
#   'Computer',
#   'Internet',
#   'World_Wide_Web',
#   'Google'],
#  ['United_States',
#   'Internet',
#   'Microsoft',
#   'World_Wide_Web',
#   'Gmail',
#   'Google'],
#  array(['United_Kingdom', 'Computer', 'Internet', 'World_Wide_Web',
#         'Google'], dtype='<U14'),
#  ['United_States',
#   'Electronics',
#   'Computer',
#   'Internet',
#   'World_Wide_Web',
#   'Gmail',
#   'Google'],
#  ['United_States', 'Internet', 'Microsoft', 'World_Wide_Web', 'Google'],
#  array(['Mathematics', 'Number', 'Prime_number', 'Algorithm',
#         'Mathematics', 'Geometry', 'Mathematical_analysis', 'Mathematics',
#         'Computer_science', 'Internet', 'World_Wide_Web', 'Google'],
#        dtype='<U21'),
#  array(['Aircraft', 'Boeing_747', 'Seattle%2C_Washington', 'Microsoft',
#         'World_Wide_Web', 'Google'], dtype='<U21'),
#  ['United_Kingdom',
#   'Computer',
#   'Internet',
#   'Microsoft',
#   'Microsoft_Windows',
#   'Windows_Vista',
#   'Internet_Explorer',
#   'Mozilla_Firefox',
#   'Google'],
#  array(['Mathematics', 'Geometry', 'Euclid'], dtype='<U12'),
#  ['Hydrogen', 'Special_relativity', 'String_theory', 'Manifold', 'Euclid'],
#  ['Human', 'Plato', 'Euclid'],
#  ['World_War_II', 'Adolf_Hitler'],
#  ['United_Kingdom', 'Parliament_of_the_United_Kingdom'],
#  ['United_Kingdom', 'Parliament_of_the_United_Kingdom'],
#  ['United_Kingdom',
#   'Church_of_England',
#   'Roman_Catholic_Church',
#   'Pope_John_Paul_II',
#   'Communism',
#   'Yugoslavia'],
#  ['Russia', 'Turkey', 'Bosnia_and_Herzegovina', 'Yugoslavia'],
#  ['Europe', 'Serbia', 'Yugoslavia'],
#  ['Russia', 'Belarus', 'Communism', 'Yugoslavia'],
#  array(['Russia', 'Montenegro', 'Yugoslavia'], dtype='<U10'),
#  ['World_War_II',
#   'Joseph_Stalin',
#   'Soviet_Union',
#   'European_Union',
#   'Slovenia',
#   'Croatia',
#   'Yugoslavia'],
#  ['World_War_II', 'Yugoslavia'],
#  ['Turkey', 'Bulgaria', 'Serbia', 'Croatia', 'Yugoslavia'],
#  ['Russia', 'Soviet_Union', 'Albania', 'Yugoslavia'],
#  ['World_War_II', 'Yugoslavia'],
#  ['World_War_II', 'Communism', 'Yugoslavia'],
#  ['World_War_II', 'Yugoslavia'],
#  ['United_Kingdom',
#   'India',
#   'Tamil_language',
#   'Tamil_people',
#   'Chola_dynasty'],
#  ['Roman_Empire', 'Heraclius'],
#  ['Russia',
#   'Poland',
#   'Polish-Lithuanian_Commonwealth',
#   'Constitution_of_May_3%2C_1791'],
#  ['Bird'],
#  ['English_language', 'Drama', 'Film'],
#  ['Time', 'Life'],
#  ['Spain', '16th_century', 'Spanish_Armada'],
#  ['Germany', 'Czech_Republic', 'Prague'],
#  ['Mathematics',
#   'Science',
#   'Physical_science',
#   'Chemistry',
#   'Periodic_table',
#   'Argon'],
#  ['English_language', 'India', 'Buddhism', 'Pali_Canon'],
#  ['England'],
#  ['Middle_Ages', 'Industrial_Revolution', 'Technology', 'Radio', 'Radar'],
#  ['Italy', 'Benito_Mussolini', 'Anarchism'],
#  ['Philosophy', 'Science', 'Chemistry', 'List_of_elements_by_name', 'Boron'],
#  ['Middle_Ages',
#   'Aristotle',
#   'Geology',
#   'Chlorine',
#   'Periodic_table',
#   'Boron'],
#  ['Philosophy', 'Astronomy', 'Chemistry', 'Periodic_table', 'Boron'],
#  ['Electron', 'Periodic_table', 'Boron'],
#  ['Middle_Ages', 'Gunpowder', 'Sulfur', 'List_of_elements_by_name', 'Boron'],
#  ['English_language', 'Germany', 'Brothers_Grimm'],
#  ['Earth', 'Volcano', 'Magma'],
#  array(['Aluminium', 'Diamond', 'Magma'], dtype='<U9'),
#  ['Moon', 'Apollo_8'],
#  ['India', 'Hinduism'],
#  array(['Aluminium', 'Potassium', 'Parsnip', 'Carrot'], dtype='<U9'),
#  ['United_States',
#   'Martin_Luther_King%2C_Jr.',
#   'Civil_rights',
#   'Women%27s_rights'],
#  ['Animal', 'Bird', 'Parrot'],
#  array(['Roman_Catholic_Church', 'Oceania', 'Ocean', 'Fish', 'Dolphin',
#         'Miocene', 'Owl', 'Bird', 'Parrot'], dtype='<U21'),
#  array(['Animal', 'Bird', 'Parrot'], dtype='<U18'),
#  ['United_Kingdom',
#   'London',
#   'New_York_City',
#   'North_America',
#   'South_America',
#   'Amazon_Rainforest',
#   'Bird',
#   'Parrot'],
#  array(['Ancient_Rome', 'Family', 'Religion', 'Mythology', 'Folklore',
#         'Dance', 'Rainforest', 'Bird', 'Parrot'], dtype='<U18'),
#  ['United_States',
#   'North_America',
#   'South_America',
#   'Amazon_Rainforest',
#   'Bird',
#   'Parrot'],
#  ['Oxygen', 'Water', 'Biodiversity', 'Bird', 'Parrot'],
#  ['Animal', 'Magellanic_Penguin', 'Bird', 'Parrot'],
#  ['Animal', 'Bird', 'Parrot'],
#  ['Color', 'Bird', 'Parrot'],
#  ['Animal', 'Bird', 'Parrot'],
#  ['Animal', 'Bird', 'Parrot'],
#  ['China', 'Desert', 'Animal', 'Bird', 'Parrot'],
#  ['Animal', 'Bird', 'Parrot'],
#  ['Animal', 'Bird', 'Parrot'],
#  ['Africa', 'Rainforest', 'Bird', 'Parrot'],
#  ['Latin',
#   'Spanish_language',
#   'South_America',
#   'Amazon_Rainforest',
#   'Bird',
#   'Parrot'],
#  array(['Earth', 'Animal', 'Bird', 'Parrot'], dtype='<U20'),
#  array(['Animal', 'Bird', 'Parrot'], dtype='<U18'),
#  ['Animal', 'Bird', 'Parrot'],
#  ['Bird', 'Parrot'],
#  ['Bird', 'Parrot'],
#  ['Animal', 'Bird', 'Parrot'],
#  ['Animal', 'Magellanic_Penguin', 'Penguin', 'Bird', 'Parrot'],
#  ['English_language',
#   'Philippines',
#   'Brazil',
#   'Amazon_Rainforest',
#   'Bird',
#   'Parrot'],
#  ['Animal', 'Bird', 'Parrot'],
#  ['Africa', 'Rainforest', 'Bird', 'Parrot'],
#  ['Animal', 'Bird', 'Parrot'],
#  ['Brazil', 'Rainforest', 'Bird', 'Parrot'],
#  ['Human', 'Chordate', 'Bird', 'Parrot'],
#  ['Human', 'Chordate', 'Bird', 'Parrot'],
#  ['Bangladesh', 'Tropics', 'Costa_Rica', 'Parrot'],
#  ['Earth', 'Animal', 'Bird', 'Parrot'],
#  ['China', 'Southern_Africa', 'Lion', 'Animal', 'Bird', 'Parrot'],
#  ['Bird', 'Parrot'],
#  array(['Animal', 'Bird', 'Parrot'], dtype='<U18'),
#  array(['Animal', 'Bird', 'Parrot'], dtype='<U18'),
#  array(['Egypt', 'Red_Sea', 'Invertebrate', 'Bird', 'Parrot'], dtype='<U18'),
#  ['Bird', 'Parrot'],
#  ['Indonesia', 'Biodiversity', 'Bird', 'Parrot'],
#  ['Color', 'Bird', 'Parrot'],
#  ['Physics', 'Biology', 'Biodiversity', 'Rainforest', 'Bird', 'Parrot'],
#  ['Zinc', 'Brain', 'Stroke'],
#  ['Salt', 'Edible_salt', 'Stroke'],
#  ['Gold', 'Money'],
#  array(['Salt', 'Almond', 'Olive_oil', 'Celery', 'Soup', 'Onion'],
#        dtype='<U18'),
#  ['United_States', 'United_States_Virgin_Islands'],
#  ['United_States', 'Martin_Luther_King%2C_Jr.', 'Malcolm_X', 'Ku_Klux_Klan'],
#  ['United_States', 'American_Civil_War', 'Ku_Klux_Klan'],
#  ['United_States', 'American_Civil_War', 'Ku_Klux_Klan'],
#  array(['Slavery', 'American_Civil_War', 'Ku_Klux_Klan'], dtype='<U18'),
#  ['Aluminium', 'Periodic_table', 'Neptunium'],
#  ['Jesus'],
#  array(['United_States', 'United_Kingdom', 'Great_Britain'], dtype='<U18'),
#  ['France', 'European_Union', 'Poland'],
#  ['Plant', 'Herbivore'],
#  array(['Human', 'Herbivore'], dtype='<U18'),
#  ['Ancient_Egypt',
#   'Archaeology',
#   'Paleontology',
#   'Fossil',
#   'Dinosaur',
#   'Herbivore'],
#  array(['France', 'Pacific_Ocean', 'Tuna', 'Animal', 'Mammal', 'Horse',
#         'Herbivore'], dtype='<U18'),
#  array(['United_States', 'Turkey_%28bird%29', 'Bird', 'Mammal', 'Animal',
#         'Plant', 'Herbivore'], dtype='<U18'),
#  array(['Agriculture', 'Milk', 'Cattle', 'Horse', 'Herbivore'],
#        dtype='<U18'),
#  ['United_States', 'World_War_II', 'Battle_of_Leyte_Gulf'],
#  ['Israel', 'Kuwait', 'Kuwait_City'],
#  ['American_Civil_War',
#   'Trench_warfare',
#   'Invasion',
#   'Baghdad',
#   'Iraq_War',
#   'Persian_Gulf',
#   'Kuwait',
#   'Kuwait_City'],
#  ['United_States',
#   'September_11%2C_2001_attacks',
#   'Afghanistan',
#   'Middle_East',
#   'Kuwait',
#   'Kuwait_City'],
#  ['United_States', 'Iraq', 'Kuwait', 'Kuwait_City'],
#  ['United_States', 'Iraq', 'Kuwait', 'Kuwait_City'],
#  ['United_States',
#   'North_America',
#   'Continent',
#   'Asia',
#   'Kuwait',
#   'Kuwait_City'],
#  ['France',
#   'Algeria',
#   'Arabic_language',
#   'Middle_East',
#   'Kuwait',
#   'Kuwait_City'],
#  ['United_States', 'Iraq', 'Kuwait', 'Kuwait_City'],
#  ['United_States', 'Iraq', 'Kuwait', 'Kuwait_City'],
#  ['France', 'Kenya', 'Egypt', 'Middle_East', 'Kuwait', 'Kuwait_City'],
#  ['English_language', 'England', 'Nottingham'],
#  ['United_States',
#   'Country',
#   'United_Kingdom',
#   'Great_Britain',
#   'England',
#   'Nottingham'],
#  ['American_Civil_War', 'Liverpool', 'Nottingham'],
#  ['American_Civil_War',
#   'Liverpool',
#   'City_status_in_the_United_Kingdom',
#   'Nottingham'],
#  ['Africa', 'Nouakchott'],
#  ['Japan'],
#  ['Africa', 'Sudan'],
#  ['Chordate', 'Reptile', 'Dinosaur', 'Theropoda', 'Allosaurus'],
#  array(['Reptile', 'Dinosaur', 'Theropoda', 'Allosaurus'], dtype='<U10'),
#  array(['Fish', 'Fishing', 'Food', 'Health', 'Nutrition'], dtype='<U9'),
#  ['Russia', 'Volga_River'],
#  ['China', 'Macau'],
#  ['Japan', 'Electronics', 'Computer', 'Computer_and_video_games'],
#  ['Spain', 'Islam', 'Religion', 'Agnosticism'],
#  ['South_America', 'Mexico', 'Religion', 'Agnosticism'],
#  ['Christianity', 'Atheism', 'Agnosticism'],
#  array(['Spain', 'Islam', 'Religion', 'Agnosticism'], dtype='<U11'),
#  ['Asia', 'Buddhism', 'Religion', 'Agnosticism'],
#  ['Christianity', 'Religion', 'Agnosticism'],
#  ['United_States', 'Islam', 'God', 'Blaise_Pascal', 'Religion', 'Agnosticism'],
#  ['Christianity', 'Religion', 'Agnosticism'],
#  ['France', 'God', 'Deity', 'Atheism', 'Agnosticism'],
#  ['Christianity', 'Religion', 'Agnosticism'],
#  ['United_Kingdom', 'London', 'London_Bridge'],
#  ['United_Kingdom', 'London', 'London_Bridge'],
#  array(['Europe', 'British_Isles', 'Great_Britain', 'United_Kingdom',
#         'London', 'River_Thames', 'London_Bridge'], dtype='<U14'),
#  ['Europe',
#   'United_Kingdom',
#   'England',
#   'London',
#   'Tower_Bridge',
#   'London_Bridge'],
#  array(['Electron', 'Chemical_element', 'Nitrogen', 'Nitrification'],
#        dtype='<U18'),
#  ['Bird', 'Dove', 'Passenger_Pigeon'],
#  ['Europe', 'United_Kingdom', 'English_language'],
#  array(['Mediterranean_Sea'], dtype='<U17'),
#  ['Physics', 'Special_relativity', 'Albert_Einstein'],
#  ['Physics', 'Albert_Einstein'],
#  ['Europe', 'Germany', 'Adolf_Hitler'],
#  ['19th_century', '6th_century'],
#  ['Ancient_Greece', 'Music', 'Musical_instrument', 'Flute'],
#  ['Ancient_Greece', 'Bread', 'Fruit', 'Citrus', 'Lemon', 'Lemon_balm'],
#  ['Agriculture', 'Tea', 'Lemon', 'Lemon_balm'],
#  ['Australia', 'Dingo', 'Dog'],
#  ['Animal', 'Mammal', 'Lion', 'Hyena', 'Carnivore', 'Gray_Wolf', 'Dog'],
#  ['Australia', 'Dingo', 'Dog'],
#  array(['Christianity', 'Roman_Catholic_Church', 'Apostolic_Succession'],
#        dtype='<U21'),
#  ['Africa', 'African_Union'],
#  ['Africa', 'African_Union'],
#  ['Africa', 'African_Union'],
#  ['United_States', 'Sudan', 'African_Union'],
#  array(['Earth', 'Human', 'Music', 'Sound'], dtype='<U14'),
#  ['Animal', 'Energy', 'Communication', 'Sound'],
#  array(['Animal', 'Mammal', 'Human', 'Communication', 'Sound'],
#        dtype='<U13'),
#  ['England',
#   'Church_of_England',
#   'Roman_Catholic_Church',
#   'Eastern_Orthodox_Church'],
#  ['Latin', 'Roman_Catholic_Church', 'Eastern_Orthodox_Church'],
#  ['Christianity', 'Eastern_Orthodox_Church'],
#  ['Latin', 'Roman_Catholic_Church', 'Eastern_Orthodox_Church'],
#  ['Animal',
#   'Human',
#   'Religion',
#   'Roman_Catholic_Church',
#   'Eastern_Orthodox_Church'],
#  array(['Animal', 'Water', 'River', 'Mackenzie_River'], dtype='<U15'),
#  array(['United_Kingdom', 'Monarchy', 'British_monarchy',
#         'Stephen_of_England', 'Matilda_of_Boulogne'], dtype='<U19'),
#  ['Animal', 'Mammal', 'Bird', 'Goose', 'Shelduck'],
#  ['Television', 'Technology', 'Integrated_circuit'],
#  ['William_Shakespeare',
#   'Macbeth',
#   'Globe_Theatre',
#   'Theatre',
#   'Stage_%28theatre%29'],
#  array(['United_States', 'Currency', 'Stock', 'Finance',
#         'Corporate_finance', 'Investment_banking', 'United_States',
#         'New_York_City', 'Wall_Street'], dtype='<U18'),
#  ['United_States', 'Wall_Street'],
#  ['United_States', 'Wall_Street'],
#  ['Mineral', 'Salt', 'Edible_salt'],
#  ['19th_century', '18th_century', 'Adam_Smith'],
#  ['Mammal', 'Vertebrate', 'Bird', 'Owl', 'Eurasian_Eagle_Owl'],
#  array(['Chordate', 'Bird', 'Owl', 'Eurasian_Eagle_Owl'], dtype='<U18'),
#  ['Africa', 'Somalia'],
#  ['William_Shakespeare',
#   'Macbeth',
#   'James_I_of_England',
#   'William_III_of_England'],
#  ['Lion', 'Zebra'],
#  ['Lion', 'Zebra'],
#  array(['Lion', 'Zebra'], dtype='<U13'),
#  array(['Africa', 'Lion', 'Zebra'], dtype='<U13'),
#  ['United_Kingdom', 'English_language'],
#  ['Mexico', 'Latin_America'],
#  ['United_States',
#   'North_America',
#   'South_America',
#   'Spain',
#   'Spanish_language',
#   'Latin_America'],
#  ['United_States', 'Latin_America'],
#  ['United_States', 'Apollo_11', 'Saturn_V'],
#  ['Israel', 'Hellenistic_Greece', 'History_of_Greece', 'Greek_mythology'],
#  ['European_Union', 'Republic_of_Ireland', 'Ireland'],
#  ['United_Kingdom', 'Ireland'],
#  ['European_Union', 'Republic_of_Ireland', 'Ireland'],
#  ['France',
#   'English_Channel',
#   'Paris',
#   'English_language',
#   'New_Zealand',
#   'Christianity',
#   'Europe',
#   'Ireland'],
#  ['Germany', 'Republic_of_Ireland', 'Ireland'],
#  ['United_Kingdom', 'Ireland'],
#  ['Europe', 'Republic_of_Ireland', 'Ireland'],
#  ['United_States', 'Republic_of_Ireland', 'Ireland'],
#  ['Adolf_Hitler'],
#  ['United_States', 'Jazz', 'Louis_Jordan'],
#  ['United_States',
#   'Pacific_Ocean',
#   'Igneous_rock',
#   'Crust_%28geology%29',
#   'Continental_crust'],
#  array(['Europe', 'Atlantic_Ocean', 'Earth', 'Crust_%28geology%29',
#         'Continental_crust'], dtype='<U19'),
#  ['Europe', 'Geology', 'Crust_%28geology%29', 'Continental_crust'],
#  ['Science', 'Chemistry', 'Periodic_table', 'Thorium'],
#  ['Scientific_classification',
#   'Genetics',
#   'Science',
#   'Chemistry',
#   'Periodic_table',
#   'Gold'],
#  ['Oxygen', 'Chemical_element', 'Alchemy', 'Gold'],
#  ['Gold'],
#  ['Earth', 'Iron', 'Gold'],
#  ['North_America', 'Gulf_of_Mexico', 'Hurricane_Katrina'],
#  ['Carbon_dioxide', 'Global_warming', 'Tropical_cyclone', 'Hurricane_Katrina'],
#  ['Carbon_dioxide', 'Global_warming', 'Tropical_cyclone', 'Hurricane_Katrina'],
#  ['Pacific_Ocean', 'Tropical_cyclone', 'Hurricane_Katrina'],
#  ['United_States', 'George_W._Bush', 'Hurricane_Katrina'],
#  ['United_States', 'George_W._Bush', 'Hurricane_Katrina'],
#  ['Earth', 'Tropical_cyclone', 'Hurricane_Katrina'],
#  array(['North_America', 'Atlantic_Ocean', 'Tropical_cyclone',
#         'Hurricane_Katrina'], dtype='<U17'),
#  ['Oxygen',
#   'Water',
#   'Rain',
#   'Thunderstorm',
#   'Tornado',
#   'Tropical_cyclone',
#   'Hurricane_Katrina'],
#  ['Europe',
#   'London',
#   'University_of_Cambridge',
#   'England',
#   'Norfolk',
#   'Norwich'],
#  ['England', 'Norfolk', 'Norwich'],
#  ['Europe', 'World_War_II', 'Adolf_Hitler'],
#  ['United_States', 'Elvis_Presley'],
#  ['United_States',
#   'Canada',
#   'United_Kingdom',
#   'Parliament_of_the_United_Kingdom'],
#  ['United_Kingdom', 'Parliament_of_the_United_Kingdom'],
#  ['United_Kingdom', 'Parliament_of_the_United_Kingdom'],
#  ['Earth', 'Weather', 'Snow', 'Avalanche'],
#  ['Climate', 'Weather', 'Snow', 'Avalanche'],
#  ['Oxygen',
#   'Gas',
#   'Phase_%28matter%29',
#   'Absolute_zero',
#   'Crystal',
#   'Snow',
#   'Skiing',
#   'Avalanche'],
#  ['North_America', 'Rocky_Mountains', 'Skiing', 'Avalanche'],
#  ['Earth', 'Weather', 'Snow', 'Avalanche'],
#  ['Canada', 'Rocky_Mountains', 'Skiing', 'Avalanche'],
#  ['Earth', 'Antarctica', 'Snow', 'Avalanche'],
#  ['Animal', 'Magellanic_Penguin', 'Penguin'],
#  array(['Earth', 'Iron', 'Electron', 'Electricity',
#         'Electrical_resistance', 'Superconductivity'], dtype='<U21'),
#  ['Oxygen',
#   'Chemical_element',
#   'Mercury_%28element%29',
#   'Aluminium',
#   'Electricity',
#   'Electrical_resistance',
#   'Superconductivity'],
#  ['Earth', 'Earth%27s_atmosphere', 'Hydrogen', 'Superconductivity'],
#  ['God'],
#  ['Human', 'Religion', 'God'],
#  ['Roman_Catholic_Church', 'God'],
#  ['Evolution', 'Charles_Darwin'],
#  ['Science', 'History_of_science'],
#  array(['New_York_City', 'U.S._state', 'British_Isles', 'Channel_Islands',
#         'Jersey'], dtype='<U24'),
#  ['United_States', 'Hip_hop_music'],
#  ['United_States', 'Hip_hop_music'],
#  ['United_States', 'Hip_hop_music'],
#  ['United_States', 'Chicago', 'Jazz', 'Drum_and_bass', 'Hip_hop_music'],
#  ['English_language', 'Internet', 'Music', 'Hip_hop_music'],
#  array(['Evolution', 'Creation-evolution_controversy', 'Mass_media',
#         'Compact_Disc', 'DVD', 'Sony', 'Video', 'Film', 'Piano',
#         'Musical_instrument', 'Music', 'Hip_hop_music'], dtype='<U30'),
#  ['Animal', 'Human', 'Music', 'Hip_hop_music'],
#  array(['United_States', 'Hip_hop_music'], dtype='<U13'),
#  ['Human', 'Music', 'Hip_hop_music'],
#  ['Africa', 'Jazz', 'Music', 'Hip_hop_music'],
#  ['Animal', 'Human', 'Music', 'Hip_hop_music'],
#  ['Scientific_classification', 'Human', 'Music', 'Hip_hop_music'],
#  ['United_States', 'Hip_hop_music'],
#  ['United_States', 'Hip_hop_music'],
#  ['United_States', 'Hip_hop_music'],
#  array(['United_States', 'Hip_hop_music'], dtype='<U13'),
#  ['Human', 'Music', 'Hip_hop_music'],
#  ['Human', 'Music', 'Hip_hop_music'],
#  ['20th_century', 'Music', 'Hip_hop_music'],
#  ['United_States', 'Hip_hop_music'],
#  ['United_States', 'Hip_hop_music'],
#  ['United_States', 'Hip_hop_music'],
#  ['Scientific_classification', 'Human', 'Music', 'Hip_hop_music'],
#  ['Human', 'Music', 'Hip_hop_music'],
#  ['Athens'],
#  ['Human', 'Cell_%28biology%29'],
#  ['Europe', 'Republic_of_Ireland', 'United_Kingdom', 'Glasgow'],
#  ['Athens', 'Edinburgh', 'Glasgow'],
#  ['Animal', 'Bird', 'Flamingo'],
#  array(['Animal', 'Bird', 'Flamingo'], dtype='<U8'),
#  ['Bird', 'Extinction', 'Dodo', 'Extinct_birds'],
#  ['United_States', 'President_of_the_United_States', 'Chester_A._Arthur'],
#  array(['World_War_I', 'Woodrow_Wilson', 'William_Howard_Taft',
#         'Theodore_Roosevelt', 'William_McKinley', 'Grover_Cleveland',
#         'Chester_A._Arthur'], dtype='<U19'),
#  ['United_States',
#   'George_W._Bush',
#   'President_of_the_United_States',
#   'Chester_A._Arthur'],
#  ['Law',
#   'United_States_Bill_of_Rights',
#   'President_of_the_United_States',
#   'Chester_A._Arthur'],
#  ['United_States',
#   'New_York_City',
#   'Culture',
#   'Art',
#   'Theatre',
#   'Opera',
#   'Madama_Butterfly'],
#  ['Canada', 'North_America', 'Rocky_Mountains', 'Skiing'],
#  ['Soviet_Union', 'Climate', 'Weather', 'Snow', 'Skiing'],
#  ['Ancient_Greece', 'Olympic_Games', 'Skiing'],
#  ['France', 'Germany', 'Norway', 'Iceland', 'Tourism', 'Skiing'],
#  ['Germany', 'Greece', 'Olympic_Games', 'Skiing'],
#  ['Athens', '1896_Summer_Olympics', 'Sport', 'Olympic_Games', 'Skiing'],
#  ['Archaeology', 'Anthropology'],
#  ['Art', 'Music'],
#  ['Egypt', 'Cairo', 'Nile'],
#  ['United_States', 'Coal', 'Sulfur', 'Electron', 'Atom'],
#  ['Rome', 'Pope', 'Pope_John_Paul_II', 'List_of_popes'],
#  ['United_States', 'North_America', 'South_America', 'Brazil', 'Ecuador'],
#  ['United_States', 'North_America', 'South_America', 'Ecuador'],
#  ['North_America', 'South_America', 'Ecuador'],
#  ['Peru', 'Ecuador'],
#  ['Peru', 'Ecuador'],
#  ['Pacific_Ocean', 'Ecuador'],
#  ['England', 'Brighton'],
#  ['United_States', 'North_Korea', 'South_Korea'],
#  ['Africa', 'Sudan', 'Darfur_conflict'],
#  array(['Christianity', 'London', 'Culture', 'Popular_culture',
#         'Literature', 'Romanticism', 'Walt_Whitman', 'Liberalism',
#         'Folk_music', 'Bob_Dylan', 'The_Beatles', 'Elvis_Presley',
#         'William_Shakespeare', 'Love'], dtype='<U24'),
#  ['London', 'William_Shakespeare', 'Love'],
#  array(['Christianity', 'Religion', 'Society', 'Civilization', 'Culture',
#         'Human', 'Love'], dtype='<U24'),
#  array(['English_language', 'William_Shakespeare', 'Love'], dtype='<U24'),
#  ['Europe', 'Asia', 'Vietnam'],
#  ['England',
#   'Socialism',
#   'Soviet_Union',
#   'Cold_War',
#   'Vietnam_War',
#   'Ho_Chi_Minh_City',
#   'Vietnam'],
#  array(['United_States', 'Vietnam_War', 'Thailand', 'Cambodia', 'Vietnam'],
#        dtype='<U24'),
#  ['France', 'Thailand', 'Vietnam_War', 'Ho_Chi_Minh_City', 'Vietnam'],
#  ['France', 'Buddhism', 'Vietnam'],
#  ['England',
#   'Cricket',
#   'Bangladesh',
#   'Bay_of_Bengal',
#   'Myanmar',
#   'Thailand',
#   'Cambodia',
#   'Vietnam'],
#  ['United_States', 'Vietnam_War', 'Ho_Chi_Minh_City', 'Vietnam'],
#  ['Europe', 'Asia', 'Vietnam'],
#  ['19th_century', '20th_century', 'Asia', 'Vietnam'],
#  ['World_War_II', 'War', 'Vietnam_War', 'Ho_Chi_Minh_City', 'Vietnam'],
#  ['England', 'Olympic_Games', 'Taiwan', 'China', 'Vietnam'],
#  ['Europe', 'Asia', 'China', 'Vietnam'],
#  ['Europe', 'Earth', 'Asia', 'Vietnam'],
#  ['Europe', 'Asia', 'Vietnam'],
#  ['Christianity', 'People%27s_Republic_of_China', 'Vietnam'],
#  ['United_States', 'Vietnam_War', 'Ho_Chi_Minh', 'Vietnam'],
#  ['United_States', 'Vietnam_War', 'Laos', 'Vietnam'],
#  ['China', 'Vietnam'],
#  ['England', 'Chinese_language', 'Vietnam'],
#  ['Christianity', 'Religion', 'Buddhism', 'Vietnam'],
#  ['United_States', 'Vietnam_War', 'Hanoi', 'Vietnam'],
#  ['China', 'Vietnam'],
#  ['China', 'Vietnam'],
#  array(['United_States', 'Vietnam_War', 'Ho_Chi_Minh', 'Vietnam'],
#        dtype='<U24'),
#  ['Asia', 'Vietnam'],
#  array(['United_States', 'Vietnam'], dtype='<U24'),
#  ['Europe', 'Asia', 'Vietnam'],
#  ['Europe', 'Asia', 'Vietnam'],
#  array(['Spain', 'People%27s_Republic_of_China', 'Vietnam'], dtype='<U28'),
#  ['Europe', 'Asia', 'Vietnam'],
#  ['Canada', 'Vancouver', 'Mount_Baker', 'Mount_Rainier'],
#  ['United_States',
#   'North_America',
#   'Florida',
#   'Space_Shuttle_Columbia',
#   'Hubble_Space_Telescope',
#   'Space_Shuttle_Challenger_disaster',
#   'Houston%2C_Texas',
#   'Moon',
#   'Apollo_8',
#   'Neil_Armstrong'],
#  ['United_States', 'Moon', 'Neil_Armstrong'],
#  array(['United_States', 'Neil_Armstrong'], dtype='<U24'),
#  ['United_States', 'Moon', 'Apollo_11', 'Neil_Armstrong'],
#  array(['United_States', 'Neil_Armstrong'], dtype='<U24'),
#  array(['United_States', 'Neil_Armstrong'], dtype='<U24'),
#  ['United_States', 'Neil_Armstrong'],
#  array(['United_States', 'Moon', 'Neil_Armstrong'], dtype='<U24'),
#  array(['United_States', 'Neil_Armstrong'], dtype='<U24'),
#  ['United_States', 'Neil_Armstrong'],
#  array(['United_States', 'Manifest_Destiny', 'Southern_United_States',
#         'Houston%2C_Texas'], dtype='<U24'),
#  ['United_States', 'Dallas%2C_Texas', 'Houston%2C_Texas'],
#  ['England',
#   'British_Empire',
#   'North_America',
#   'Florida',
#   'U.S._state',
#   'Houston%2C_Texas'],
#  array(['United_States', 'Houston%2C_Texas'], dtype='<U24'),
#  ['England',
#   'Time_zone',
#   'Earth',
#   'Sun',
#   'Galaxy',
#   'Hubble_Deep_Field',
#   'Universe'],
#  array(['United_States', 'Moon', 'Solar_System', 'Sun', 'Asteroid',
#         'Comet', 'Galaxy', 'Universe'], dtype='<U24'),
#  ['United_States',
#   'Moon',
#   'Solar_System',
#   'Planet',
#   'Extrasolar_planet',
#   'Extraterrestrial_life',
#   'Universe'],
#  ['Rome',
#   'Ancient_Rome',
#   'Technology',
#   'Space_exploration',
#   'International_Space_Station',
#   'Space_Shuttle_Endeavour',
#   'Hubble_Space_Telescope',
#   'Astronomy',
#   'Universe'],
#  ['Christianity', 'Religion', 'Mysticism', 'Universe'],
#  ['Asia', 'Jordan', 'Dead_Sea'],
#  ['Roman_Empire', 'Jerusalem', 'Dead_Sea'],
#  ['Europe', 'Middle_East', 'Israel', 'Dead_Sea'],
#  ['England',
#   'Stephen_Hawking',
#   'Carbon_dioxide',
#   'Argon',
#   'Periodic_table',
#   'Krypton'],
#  array(['China', 'Go_%28board_game%29', 'Board_game', 'Backgammon'],
#        dtype='<U19'),
#  ['India', 'Chess', 'Backgammon'],
#  array(['United_States', 'Computer', 'Computer_and_video_games', 'Chess',
#         'Board_game', 'Backgammon'], dtype='<U24'),
#  array(['Russia', 'Mass_media', 'Technology', 'Computer',
#         'Computer_and_video_games', 'Chess', 'Board_game', 'Backgammon'],
#        dtype='<U24'),
#  ['Africa', 'Niger'],
#  ['Evolution', 'Vertebrate'],
#  array(['Water', 'Fresh_water', 'Water_resources'], dtype='<U15'),
#  ['Water', 'Fresh_water', 'Water_resources'],
#  ['United_States', 'Mississippi_River'],
#  ['United_States', 'George_Washington', 'American_Revolutionary_War'],
#  ['United_States',
#   'Capitalism',
#   'Money',
#   'Finance',
#   'Corporate_finance',
#   'Investment_banking'],
#  ['China', 'Economics', 'Finance', 'Corporate_finance', 'Investment_banking'],
#  ['China', 'Civilization', 'Government', 'Oligarchy'],
#  ['Greece', 'Aristotle', 'Education', 'Educational_psychology', 'Pedagogy'],
#  array(['Earth', 'Human', 'Philosophy', 'German_language', 'Education',
#         'Educational_psychology', 'Pedagogy'], dtype='<U22'),
#  ['United_States', 'Canada', 'Canadian_Pacific_Railway', 'The_Canadian'],
#  ['United_States',
#   'Finance',
#   'Money',
#   'Banknote',
#   'Stock',
#   'Supply_and_demand',
#   'Market',
#   'Currency',
#   'Money',
#   'European_Union',
#   'European_Parliament',
#   'United_Kingdom',
#   'European_Union',
#   'World_War_II',
#   'Attack_on_Pearl_Harbor',
#   'Imperial_Japanese_Navy',
#   'Asia',
#   'Egypt',
#   'Israel',
#   'West_Bank'],
#  ['Mathematics', 'Arithmetic'],
#  array(['Government', 'George_W._Bush'], dtype='<U14'),
#  ['Africa', 'Gold', 'Iron', 'Iron_Age'],
#  array(['Iron', 'Iron_Age'], dtype='<U21'),
#  ['Ancient_Greece', 'Minoan_civilization', 'Iron_Age'],
#  ['United_Kingdom', 'Great_Britain'],
#  ['Italy', 'Agriculture', 'Food'],
#  ['Italy', 'Culture', 'Civilization', 'Agriculture', 'Food'],
#  ['Aristotle', 'Alexander_the_Great', 'Honey', 'Bread', 'Food'],
#  ['Agriculture', 'Food'],
#  ['Aristotle', 'Biology', 'Organism', 'Food'],
#  ['Aristotle', 'Biology', 'Yeast', 'Beer', 'Bread', 'Food'],
#  ['France',
#   'United_Kingdom',
#   'British_Empire',
#   'New_Zealand',
#   'All_Blacks',
#   'Rugby_World_Cup'],
#  array(['Aristotle', 'Biology', 'Ecology', 'Food', 'Scurvy', 'Vegetable',
#         'Potato', 'Maize', 'Soybean', 'Palm_oil', 'Biodiesel',
#         'List_of_vegetable_oils'], dtype='<U22'),
#  ['United_States', 'Music_of_the_United_States'],
#  ['Democracy',
#   'United_States_Constitution',
#   'Thomas_Jefferson',
#   'President_of_the_United_States',
#   'James_Monroe'],
#  array(['United_States', 'President_of_the_United_States', 'James_Monroe'],
#        dtype='<U30'),
#  ['Democracy',
#   'United_States_Constitution',
#   'Washington%2C_D.C.',
#   'President_of_the_United_States',
#   'James_Monroe'],
#  ['United_States', 'President_of_the_United_States', 'James_Monroe'],
#  ['United_States', 'President_of_the_United_States', 'James_Monroe'],
#  ['United_States', 'President_of_the_United_States', 'James_Monroe'],
#  ['United_States', 'President_of_the_United_States', 'James_Monroe'],
#  ['United_States', 'President_of_the_United_States', 'James_Monroe'],
#  array(['Roman_Empire', 'Claudius'], dtype='<U12'),
#  ['United_States', 'American_Civil_War'],
#  ['19th_century', 'American_Civil_War'],
#  ['United_States', 'American_Civil_War'],
#  ['United_States', 'American_Civil_War'],
#  ['Africa', 'Earth', 'Australia', 'New_Zealand', 'Wellington'],
#  ['Science', 'Society', 'Culture', 'Art', 'Music', 'Folk_music'],
#  ['Earth', 'Moon'],
#  ['Moon'],
#  ['Earth', 'Moon'],
#  ['Earth', 'Moon'],
#  ['Earth', 'Moon'],
#  ['Earth', 'Moon'],
#  ['Earth', 'Moon'],
#  ['Earth', 'Moon'],
#  ['Earth', 'Moon'],
#  array(['Philosophy', 'Religion', 'Shinto'], dtype='<U11'),
#  ['Japan', 'Shinto'],
#  ['Science', 'Biology', 'Evolution', 'Natural_selection'],
#  ['Africa', 'Continent', 'Asia', 'Cambodia'],
#  ['Africa', 'Asia', 'Cambodia'],
#  ['Art', 'Literature', 'Graphic_novel', 'Comics', 'Superman', 'Batman'],
#  ['Science', 'Nature'],
#  ['Art', 'Literature', 'Novel', 'Robinson_Crusoe'],
#  ['Science',
#   'Nature',
#   'Cambrian_explosion',
#   'Precambrian',
#   'Photosynthesis',
#   'Bacteria'],
#  ['Human', 'Organism', 'Bacteria'],
#  ['Ottoman_Empire', 'Byzantine_Empire'],
#  ['Ancient_Rome', 'Byzantine_Empire'],
#  ['Ancient_Rome', 'Byzantine_Empire'],
#  ['United_States', 'United_States_Constitution'],
#  ['Human',
#   'Society',
#   'Civilization',
#   'Government',
#   'Democracy',
#   'United_States_Constitution'],
#  ['United_States', 'United_States_Constitution'],
#  ['United_States', 'United_States_Constitution'],
#  ['United_States', 'United_States_Constitution'],
#  ['Australia', 'New_Zealand', 'All_Blacks'],
#  ['England', 'Scotland', 'Glasgow', 'Celtic_Park'],
#  ['Europe', 'Scotland', 'Glasgow', 'Celtic_Park'],
#  ['Art',
#   'Fine_art',
#   'Film',
#   'Sound',
#   'Music',
#   'Musical_instrument',
#   'Guitar',
#   'Double_bass'],
#  ['Art', 'Music', 'Musical_instrument', 'Guitar', 'Double_bass'],
#  ['Art', 'Music', 'Musical_instrument', 'Guitar', 'Double_bass'],
#  ['Art', 'Music', 'Musical_instrument', 'Guitar', 'Double_bass'],
#  ['Art', 'Music', 'Musical_instrument', 'Guitar', 'Double_bass'],
#  ['Art', 'Music', 'Jazz', 'Double_bass'],
#  ['Art', 'Music', 'Jazz', 'Double_bass'],
#  ['Art', 'Music', 'Musical_instrument', 'Guitar', 'Double_bass'],
#  ['Art', 'Music', 'Musical_instrument', 'Guitar', 'Double_bass'],
#  ['Art',
#   'Painting',
#   'Drawing',
#   'Computer',
#   'Python_%28programming_language%29',
#   'Macintosh',
#   'IPod',
#   'Hong_Kong',
#   'Fruit',
#   'Mango'],
#  ['Human', 'Herbivore', 'Fruit', 'Mango'],
#  array(['Agriculture', 'Fruit', 'Mango'], dtype='<U11'),
#  array(['England', 'British_Empire', 'Football_%28soccer%29', 'FIFA',
#         'World_War_I', 'Sarajevo', 'Ottoman_Empire', 'Siege',
#         'Leonardo_da_Vinci', 'Horse', 'Clothing', 'Insect', 'Hymenoptera',
#         'Triassic', 'Biosphere', 'Ecology', 'Cell_%28biology%29',
#         'Ostrich', 'Bird', 'Reptile', 'Heat', 'Hippocrates',
#         'William_Shakespeare', 'Poetry', 'Rapping', 'Jazz',
#         'Atlantic_slave_trade', 'Sugar', 'Brazil', 'Africa', 'Rainforest',
#         'Australia', 'Platypus', 'Protein', 'Potassium', 'Plant', 'Seed',
#         'Fruit', 'Mango'], dtype='<U21'),
#  ['India', 'Mango'],
#  ['Plant', 'Tree', 'Apple', 'Fruit', 'Mango'],
#  ['India', 'Mango'],
#  ['Agriculture', 'Fruit', 'Mango'],
#  array(['Agriculture', 'Fruit', 'Mango'], dtype='<U11'),
#  ['Art',
#   'Emotion',
#   'Educational_psychology',
#   'Biology',
#   'Botany',
#   'Fruit',
#   'Mango'],
#  ['France',
#   'Spanish_language',
#   'South_America',
#   'Chile',
#   'Venezuela',
#   'Coffee',
#   'Citrus',
#   'Fruit',
#   'Mango'],
#  array(['Plant', 'Arecaceae', 'Fruit', 'Mango'], dtype='<U9'),
#  ['Plant', 'Fruit', 'Mango'],
#  ['Art', 'Painting', 'Vincent_van_Gogh', 'Sunflower', 'Fruit', 'Mango'],
#  ['China', 'Biology', 'Plant', 'Fruit', 'Mango'],
#  ['Color', 'Fruit', 'Mango'],
#  array(['India', 'Indonesia', 'Jakarta', 'Black_pepper', 'Fruit', 'Mango'],
#        dtype='<U12'),
#  ['Color', 'Fruit', 'Mango'],
#  ['Color', 'Fruit', 'Mango'],
#  array(['China', 'Drought', 'Agriculture', 'Fruit', 'Mango'], dtype='<U11'),
#  array(['Plant', 'Potato', 'Nutrition', 'Scurvy', 'Fruit', 'Mango'],
#        dtype='<U14'),
#  ['Plant', 'Fruit', 'Mango'],
#  ['Earth', 'Food', 'Vitamin_C', 'Lemon', 'Fruit', 'Mango'],
#  ['Plant', 'Herbivore', 'Fruit', 'Mango'],
#  ['Color', 'Rainbow', 'Ecuador', 'Banana', 'Fruit', 'Mango'],
#  ['Earth',
#   'South_America',
#   'Brazil',
#   'Tropics',
#   'Climate',
#   'Weather',
#   'Forest',
#   'Tree',
#   'Apple',
#   'Fruit',
#   'Mango'],
#  array(['Plant', 'Fruit', 'Mango'], dtype='<U8'),
#  array(['Plant', 'Tree', 'Mango'], dtype='<U7'),
#  ['Plant', 'Fruit', 'Mango'],
#  ['Plant', 'Seed', 'Fruit', 'Mango'],
#  ['Agriculture', 'Fruit', 'Mango'],
#  ['Africa', 'Agriculture', 'Fruit', 'Mango'],
#  ['United_States', 'Education_in_the_United_States'],
#  ['United_States', 'Education_in_the_United_States'],
#  array(['United_States', 'Education_in_the_United_States'], dtype='<U30'),
#  ['United_States', 'Education_in_the_United_States'],
#  ['United_Kingdom', 'England', 'Rome', 'Ancient_Rome', 'Western_Roman_Empire'],
#  ['Computer', 'Trigonometry'],
#  ['United_States',
#   'Holy_Roman_Empire',
#   'Germany',
#   'Adolf_Hitler',
#   'Nazism',
#   'Swastika'],
#  array(['Computer', 'John_von_Neumann', 'Adolf_Hitler', 'Swastika'],
#        dtype='<U16'),
#  ['United_States', 'World_War_II', 'Nazi_Germany', 'Adolf_Hitler', 'Swastika'],
#  ['World_War_II', 'Nazi_Germany', 'Swastika'],
#  array(['Europe', 'Germany', 'Adolf_Hitler', 'Swastika'], dtype='<U13'),
#  array(['Computer', 'John_von_Neumann', 'Adolf_Hitler', 'Swastika'],
#        dtype='<U16'),
#  ['Germany', 'The_Holocaust', 'Nazism', 'Swastika'],
#  ['Germany', 'The_Holocaust', 'Nazi_Germany', 'Swastika'],
#  ['Germany', 'Adolf_Hitler', 'Swastika'],
#  array(['United_States', 'Poetry_of_the_United_States', 'H.D.'],
#        dtype='<U27'),
#  ['Latin',
#   '9th_century',
#   'Madagascar',
#   'Mauritius',
#   'Indian_Ocean',
#   'Japan',
#   'Earthquake',
#   'Volcano',
#   'Koryaksky',
#   'Avacha_Volcano'],
#  ['United_Kingdom',
#   'Natural_gas',
#   'Fossil_fuel',
#   'Global_warming',
#   'Volcano',
#   'Koryaksky',
#   'Avacha_Volcano'],
#  ['United_States', 'Netherlands_Antilles'],
#  ['Canada',
#   'Montreal',
#   'National_Hockey_League',
#   'New_York_City',
#   'September_11%2C_2001_attacks'],
#  ['United_States', 'Agriculture', 'Milk'],
#  ['Animal', 'Mammal', 'Milk'],
#  ['Elizabeth_II_of_the_United_Kingdom', 'Dog', 'Milk'],
#  ['Judaism', 'Menstrual_cycle', 'Mammal', 'Milk'],
#  ['Agriculture', 'Milk'],
#  ['Great_Britain', 'Isle_of_Man', 'Milk'],
#  ['Agriculture', 'Milk'],
#  ['Roman_Empire', 'Civilization', 'Greece', 'Parthenon'],
#  array(['United_States', 'Italy', 'Mediterranean_Sea', 'Ancient_Greece',
#         'Parthenon'], dtype='<U17'),
#  ['Latin', 'Byzantine_Empire', 'Athens', 'Parthenon'],
#  ['Roman_Empire', 'Civilization', 'Parthenon'],
#  ['Ancient_Greece', 'Parthenon'],
#  ['Roman_Empire', 'Ancient_Rome', 'Ancient_Greece', 'Parthenon'],
#  ['Roman_Empire',
#   'Cleopatra_VII',
#   'Nile',
#   'Ancient_Egypt',
#   'Egyptian_pyramids',
#   'Ramesses_II'],
#  ['United_States',
#   'List_of_rivers_by_length',
#   'Nile',
#   'Ancient_Egypt',
#   'Mummy',
#   'Ramesses_II'],
#  ['Egypt', 'Ramesses_II'],
#  ['Europe',
#   'Mediterranean_Sea',
#   'Ancient_Egypt',
#   'Egyptian_pyramids',
#   'Ramesses_II'],
#  ['Egypt', 'Ramesses_II'],
#  array(['Africa', 'Egypt', 'Ramesses_II'], dtype='<U11'),
#  ['China'],
#  ['Earth', 'Mammal', 'Human'],
#  array(['Japan', 'Meat', 'Mammal'], dtype='<U6'),
#  ['Earth', 'Dinosaur', 'Ichthyosaur'],
#  array(['Russia', 'Soviet_Union', 'Sputnik_1', 'Apollo_11',
#         'Neil_Armstrong'], dtype='<U14'),
#  ['Earth', 'Moon', 'Neil_Armstrong'],
#  ['Russia', 'Yuri_Gagarin', 'Moon', 'Neil_Armstrong'],
#  ['United_States', 'Moon', 'Neil_Armstrong'],
#  ['Europe', 'Renaissance', 'Science', 'Chemistry', 'Quantum_chemistry'],
#  ['Europe', 'European_Union'],
#  ['Asia', 'Continent', 'Antarctica', 'Arctic'],
#  ['Asia', 'Computer', 'Integrated_circuit', 'Semiconductor_device'],
#  ['Europe',
#   'United_Kingdom',
#   'England',
#   'William_Hogarth',
#   'National_Gallery%2C_London',
#   'J._M._W._Turner'],
#  ['Asia', 'South_Korea'],
#  array(['China', 'Biology', 'Scientific_classification', 'Vertebrate',
#         'Bird', 'Swift', 'Bird_migration', 'Blackcap', 'Blackbird'],
#        dtype='<U25'),
#  array(['Asia', 'Computer', 'Computer_and_video_games', 'Chess',
#         'Backgammon', 'Board_game', 'Dice', 'Playing_card', 'Blackjack'],
#        dtype='<U24'),
#  ['Carbon_dioxide'],
#  ['United_States', 'Minnesota', 'Minneapolis%2C_Minnesota'],
#  array(['Moon', 'Space_station', 'Mir'], dtype='<U13'),
#  ['20th_century', 'Cold_War', 'Mikhail_Gorbachev', 'Kazakhstan', 'Mir'],
#  ['Water', 'Fire'],
#  array(['Chemistry', 'Fire'], dtype='<U9'),
#  array(['Europe', 'Berlin_Wall', 'German_language', 'Germany',
#         'Friedrich_Nietzsche'], dtype='<U19'),
#  ['Philosophy', 'Friedrich_Nietzsche'],
#  ['Human', 'Politics', 'Government', 'Anarchism', 'Liberalism', 'Suffrage'],
#  array(['President_of_the_United_States', 'United_States_Constitution',
#         'Fourteenth_Amendment_to_the_United_States_Constitution',
#         'Equal_Protection_Clause', 'Civil_rights', 'Women%27s_rights',
#         'Suffrage'], dtype='<U54'),
#  ['United_States',
#   'Martin_Luther_King%2C_Jr.',
#   'Civil_rights',
#   'Human_rights',
#   'Women%27s_rights',
#   'Suffrage'],
#  ['Science', 'Chemistry', 'Salt', 'Edible_salt', 'Iodine'],
#  ['Poland', 'Polish-Soviet_War'],
#  array(['New_York_City', 'Global_city', 'Boston%2C_Massachusetts',
#         'Cheers'], dtype='<U23'),
#  ['Japan', 'Russia', 'Belarus', 'Flag_of_Belarus'],
#  array(['Poland', 'Belarus', 'Flag_of_Belarus'], dtype='<U19'),
#  ['World_War_II', 'Soviet_Union', 'Belarus', 'Flag_of_Belarus'],
#  ['Mexico', 'Olmec'],
#  ['Chemistry', 'Periodic_table', 'Technetium'],
#  ['Astronomy', 'Telescope', 'Johannes_Kepler', 'Tycho_Brahe'],
#  ['United_States', 'North_America', 'Continent', 'Africa', 'Ethiopia'],
#  ['Agriculture', 'Vegetable'],
#  ['Plant', 'Maize', 'Vegetable'],
#  ['United_States', 'Agriculture', 'Vegetable'],
#  ['United_States', 'Agriculture', 'Vegetable'],
#  ...]

# %%
processed_unfinished_paths = []
pages_with_no_rank_unfinished_paths = []  # those pages are missing in 'articles' ?! Should we add them to the graph ?
process_paths(unfinished_paths,processed_unfinished_paths,pages_with_no_rank_unfinished_paths)  
processed_unfinished_paths
# Out:
# [['Obi-Wan_Kenobi'],
#  ['Julius_Caesar'],
#  ['Democracy', 'Alexander_the_Great'],
#  ['Paraguay'],
#  ['Bolivia'],
#  ['China', 'Yangtze_River'],
#  ['Europe', 'Renaissance', 'Ancient_Greece', 'Afghanistan', 'Asia'],
#  ['United_States', 'Agriculture', 'Sugar', 'Australia'],
#  ['Logic'],
#  ['Science',
#   'Physical_science',
#   'Astronomy',
#   'Astrology',
#   'Moon',
#   'Apollo_11',
#   'Neil_Armstrong'],
#  ['United_States', 'Turkey_%28bird%29', 'Animal'],
#  ['Niobium'],
#  ['United_States', 'Baseball'],
#  ['Asia', 'Computer', 'Automobile'],
#  ['United_Kingdom', 'Christianity'],
#  ['Prostate_cancer'],
#  ['Wood'],
#  ['United_Kingdom', 'England', 'William_Shakespeare', 'Actor', 'Film'],
#  ['United_States', 'World_War_I'],
#  ['United_States', 'Pacific_Ocean', 'Volcano'],
#  ['Snowball_Earth'],
#  array(['Potato'], dtype='<U6'),
#  ['Leon_Trotsky'],
#  array(['English_language'], dtype='<U16'),
#  array(['English_language', 'European_Union', 'Russia'], dtype='<U24'),
#  ['Helmeted_Guineafowl'],
#  array(['United_Kingdom', 'Scotland'], dtype='<U16'),
#  ['Scooby-Doo'],
#  ['BBC'],
#  ['Menthol'],
#  ['Lerwick'],
#  ['Coal'],
#  array(['Iron', 'Steel', 'Metal', 'Corrosion'], dtype='<U9'),
#  ['Christianity', 'Jesus', 'Last_Supper', 'Wine'],
#  ['Great_Britain', 'Climate', 'Ocean'],
#  ['England', 'Cricket', 'Australia'],
#  ['Ralph_Nader'],
#  ['Zoroaster'],
#  ['Comics'],
#  ['Mexico', 'Nahuatl_language'],
#  ['Moon', 'Solar_eclipse'],
#  ['History',
#   'Anthropology',
#   'Age_of_Enlightenment',
#   'Aesthetics',
#   'Confucius'],
#  ['Revolution'],
#  ['Animal', 'Fungus', 'Human', 'AIDS', 'Cancer'],
#  ['London',
#   'British_House_of_Commons',
#   'Parliament_of_the_United_Kingdom',
#   'Constitutional_monarchy'],
#  ['Politics', 'Anarcho-capitalism'],
#  ['Human', 'Music'],
#  ['Africa'],
#  ['Oil_painting'],
#  ['Palau'],
#  ['Flamingo'],
#  array(['United_States', 'North_America', 'Continent', 'Asia',
#         'Bangladesh'], dtype='<U13'),
#  ['United_States', 'Supreme_Court_of_the_United_States'],
#  ['United_States', 'Judaism', 'Christianity', 'Roman_Catholic_Church'],
#  ['20th_century', 'Mass_media', 'Animation', 'Motion_%28physics%29'],
#  ['Norfolk'],
#  ['Odysseus'],
#  ['Middle_Ages', 'Ottoman_Empire', 'Romania', 'World_Heritage_Site'],
#  ['United_States', 'Cinema_of_the_United_States', 'The_Godfather'],
#  array(['China', 'Human', 'Science', 'World_Wide_Web', 'Internet',
#         'North_America', 'California'], dtype='<U14'),
#  ['United_States', 'Film', 'Animation'],
#  ['Greece'],
#  ['Andromeda_Galaxy'],
#  ['United_States',
#   'Medicine',
#   'Biology',
#   'Virus',
#   'Ottoman_Empire',
#   'Yemen',
#   'Middle_East'],
#  ['Diamond'],
#  ['Agriculture', 'Milk'],
#  array(['Germany', 'Berlin', 'Football_%28soccer%29', 'Japan',
#         'Electronics', 'Computer', 'Computer_and_video_games',
#         'Television'], dtype='<U24'),
#  array(['United_States'], dtype='<U13'),
#  ['Adolf_Hitler', 'The_Holocaust'],
#  ['Roman_Catholic_Church', 'Crusades', 'Byzantine_Empire'],
#  ['United_States_Bill_of_Rights'],
#  ['United_Kingdom', 'Christianity'],
#  array(['19th_century', 'Vincent_van_Gogh', 'Impressionism'], dtype='<U16'),
#  ['Cloud'],
#  array(['Italy', 'Ancient_Rome', 'Architecture'], dtype='<U14'),
#  ['Stonehenge'],
#  ['England',
#   'Drum_and_bass',
#   'Synthesizer',
#   'Speech_synthesis',
#   'Microsoft_Windows',
#   'Microsoft',
#   'Computer',
#   'Quantum_computer'],
#  ['English_language', 'England'],
#  ['United_States', 'World_War_II', 'Nazi_Germany'],
#  ['United_States',
#   'Cinema_of_the_United_States',
#   'Star_Wars_Episode_IV__A_New_Hope',
#   'Film',
#   'Actor',
#   'The_Simpsons'],
#  ['United_States', 'Corporation'],
#  ['Henry_I_of_England'],
#  ['China', 'People%27s_Republic_of_China'],
#  ['North_America', 'Florida'],
#  array(['Europe', 'Ancient_Greece', 'Aristotle', 'Mathematics', 'Raphael'],
#        dtype='<U14'),
#  array(['United_States', 'Film', 'Silent_film',
#         'Sunset_Boulevard_%281950_film%29', 'Bette_Davis', 'Vivien_Leigh',
#         'Gone_with_the_Wind_%28film%29', 'American_Civil_War',
#         'West_Virginia', 'U.S._state', 'United_States',
#         'Washington%2C_D.C.', 'U.S._state', 'United_States',
#         'West_Virginia', 'American_Civil_War', 'United_States', 'Film',
#         'Silent_film', 'Sunset_Boulevard_%281950_film%29', 'Drama',
#         'Actor', 'The_Simpsons', 'North_America'], dtype='<U32'),
#  array(['United_States', 'Pacific_Ocean', 'Japan', 'Electronics'],
#        dtype='<U13'),
#  ['President_of_the_United_States', 'Boeing_747', 'Concorde', 'Titanium'],
#  array(['Europe', 'Middle_East', 'Israel', 'Yom_Kippur_War', 'Pakistan',
#         'Russia', 'Communism', 'World_War_I', 'War', 'Weapon', 'Iraq',
#         'Baghdad', 'Iraq_War', 'Terrorism', 'War', 'Revolution',
#         'Cold_War', 'Invasion_of_Grenada', 'Soviet_Union', 'Afghanistan'],
#        dtype='<U19'),
#  ['Europe'],
#  array(['Africa', 'Continent', 'North_America', 'Caribbean_Sea', 'Sea',
#         'Ocean', 'Seawater', 'Baltic_Sea', 'Mediterranean_Sea',
#         'Atlantic_Ocean', 'Ocean', 'Earth', 'Universe',
#         'Metric_expansion_of_space', 'Nature', 'Galaxy',
#         'Plasma_%28physics%29', 'Electron', 'Electric_charge', 'Quark',
#         'Matter', 'Energy', 'Aristotle', 'Logic', 'Computer_science',
#         'Programming_language', 'Algorithm'], dtype='<U25'),
#  array(['United_States', 'Film', '20th_century', 'Physics', 'Black_hole',
#         'California', 'Arnold_Schwarzenegger'], dtype='<U21'),
#  array(['North_America', 'Saint_Lucia', 'Tourism'], dtype='<U13'),
#  ['Earth%27s_atmosphere', 'Evolution'],
#  ['Steel'],
#  array(['United_Kingdom', 'Cricket', 'Australia'], dtype='<U14'),
#  ['Canada', 'Beaver'],
#  array(['England', 'History_of_Anglo-Saxon_England'], dtype='<U30'),
#  ['Animal', 'Mammal'],
#  ['Spain'],
#  ['United_Kingdom'],
#  ['Chemical_element'],
#  ['Film'],
#  array(['London', 'Anglicanism'], dtype='<U17'),
#  ['Toronto', 'American_Revolutionary_War'],
#  ['Africa'],
#  array(['United_States', 'New_York_City', 'Dallas%2C_Texas',
#         'United_States', 'California'], dtype='<U16'),
#  ['United_States'],
#  ['South_Ossetia'],
#  array(['Roman_Empire'], dtype='<U14'),
#  ['England',
#   'Linguistics',
#   'Language',
#   'Biology',
#   'Cell_%28biology%29',
#   'Human',
#   'Brain',
#   'Eye',
#   'Protein',
#   'Genetic_code',
#   'Natural_selection'],
#  ['Europe', 'Italy', 'Bologna'],
#  ['Accra'],
#  ['Solomon_Islands'],
#  ['Pikachu'],
#  ['England', 'Christianity'],
#  ['Seattle%2C_Washington'],
#  array(['North_America', 'Earth', 'Cambrian_explosion', 'North_America',
#         'Earth'], dtype='<U23'),
#  array(['United_States', 'Petroleum', 'Global_warming', 'Carbon',
#         'Buckminster_Fuller'], dtype='<U18'),
#  array(['North_America', 'Pacific_Ocean', 'Plate_tectonics', 'Energy',
#         'Electricity', 'Industry', 'Pollution', 'Global_warming',
#         'Climate_change'], dtype='<U15'),
#  array(['United_States', 'North_America', 'Earth', 'Volcano',
#         'Mount_Vesuvius', 'Tsunami', '1755_Lisbon_earthquake'],
#        dtype='<U22'),
#  ['Greece'],
#  ['Arabic_language', 'Latin_alphabet'],
#  ['United_States',
#   'Moon',
#   'Apollo_11',
#   'Moon_landing',
#   '20th_century',
#   'Film',
#   'DVD'],
#  ['United_States'],
#  ['Maize', 'Soybean', 'Palm_oil', 'Biodiesel', 'Biofuel'],
#  ['China', 'Civilization'],
#  ['Johannes_Kepler'],
#  ['United_States'],
#  array(['Russia', 'Volcano'], dtype='<U30'),
#  ['Voynich_manuscript'],
#  array(['United_States', 'North_America', 'Earth', 'Moon', 'Apollo_11',
#         'Saturn_V', 'Space_Race', 'Sputnik_1'], dtype='<U13'),
#  array(['Europe', 'Africa', 'Southern_Africa'], dtype='<U15'),
#  array(['United_States', 'United_States_Constitution', 'Government',
#         'Democracy', 'Democracy'], dtype='<U26'),
#  ['Differential_equation'],
#  array(['Paris', 'Mona_Lisa', 'Sigmund_Freud', 'Eye', 'Human', 'Brain',
#         'Biology', 'Organism', 'Genetics', 'DNA', 'Eukaryote', 'Animal'],
#        dtype='<U18'),
#  array(['World_War_II', 'The_Holocaust'], dtype='<U13'),
#  array(['United_States', 'Martin_Luther_King%2C_Jr.', 'Voting'],
#        dtype='<U25'),
#  ['United_States', 'Battle_of_Gettysburg'],
#  array(['United_States', 'United_States', 'Manifest_Destiny',
#         'Rocky_Mountains', 'Salt_Lake_City%2C_Utah'], dtype='<U22'),
#  array(['English_language', 'India', 'Wheat', 'Protein', 'Potassium',
#         'Vegetable', 'Vitamin', 'Bean', 'Vicia_faba', 'Botany', 'Fruit',
#         'Black_pepper'], dtype='<U16'),
#  ['Fruit', 'Botany'],
#  ['Sandy_Koufax'],
#  ['United_States', 'Maize', 'Protein', 'Lipid'],
#  ['England',
#   'City',
#   'Automobile',
#   'Hydrogen',
#   'Metallurgy',
#   'Steel',
#   'Sheffield'],
#  ['World_War_II',
#   'The_Holocaust',
#   'Communism',
#   'Socialism',
#   'Anarchism',
#   'Political_philosophy',
#   'Democracy',
#   'Liberal_democracy',
#   'Liberalism',
#   'Anarcho-capitalism'],
#  ['Europe'],
#  ['Zinc'],
#  ['Oxford'],
#  ['List_of_rivers_by_length'],
#  array(['Mesopotamia'], dtype='<U17'),
#  ['United_States'],
#  ['Europe'],
#  array(['United_States', 'Hip_hop_music', 'Reggaeton', 'Britney_Spears'],
#        dtype='<U14'),
#  ['United_Kingdom', 'United_Nations'],
#  ['Bob_Marley'],
#  ['Europe', 'European_Union', 'English_language'],
#  array(['United_States'], dtype='<U15'),
#  ['United_States',
#   'Yellowstone_National_Park',
#   'Craters_of_the_Moon_National_Monument_and_Preserve',
#   'Cave'],
#  ['Toronto', 'American_Revolutionary_War', 'Gibraltar'],
#  ['Ununbium'],
#  ['United_States'],
#  ['Internet'],
#  ['Cereal', 'Barley'],
#  ['Europe', 'Republic_of_Ireland'],
#  ['World_War_II', 'Soviet_Union', 'Russia'],
#  array(['Philosophy', 'Biology', 'Virus'], dtype='<U10'),
#  array(['Europe'], dtype='<U12'),
#  ['Physics', 'Archimedes', 'Isaac_Newton'],
#  ['South_Africa', 'Ladysmith_Black_Mambazo'],
#  ['China'],
#  array(['Plant', 'Flower'], dtype='<U8'),
#  ['Arthur_Wellesley%2C_1st_Duke_of_Wellington'],
#  ['United_Kingdom'],
#  array(['North_America', 'California'], dtype='<U13'),
#  ['Netherlands', 'Bicycle', 'Tour_de_France'],
#  array(['United_States', 'North_America', 'Continent', 'Earth', 'Asteroid',
#         'Dinosaur', 'Ornithischia'], dtype='<U13'),
#  array(['Europe'], dtype='<U10'),
#  ['Antarctica', 'Ice_sheet', 'Ice_age', 'Sea_level_rise', 'Global_warming'],
#  array(['Europe'], dtype='<U21'),
#  ['Europe', 'Asia', 'Egypt', 'Cairo', 'Mosque', 'India'],
#  ['Gaborone'],
#  array(['England', 'London'], dtype='<U28'),
#  array(['Christianity'], dtype='<U12'),
#  array(['United_States', 'Cinema_of_the_United_States', 'Drama',
#         'Television', 'Broadcasting'], dtype='<U27'),
#  array(['United_States', 'Abraham_Lincoln', 'American_Civil_War',
#         'Slavery'], dtype='<U18'),
#  array(['United_States', 'Computer', 'Telephone', 'Telecommunication',
#         'Internet', 'Music'], dtype='<U17'),
#  array(['United_States', 'Moon', 'Earth', 'Solar_System', 'Mars'],
#        dtype='<U16'),
#  ['Hymenoptera'],
#  ['Ancient_Egypt', 'Society', 'Business', 'Economics'],
#  ['HIV'],
#  array(['Sesame_Street'], dtype='<U13'),
#  ['Grape_seed_oil'],
#  ['Behavioral_finance'],
#  ['United_Kingdom', 'NATO'],
#  ['Human',
#   'Government',
#   'Democracy',
#   'United_States_Bill_of_Rights',
#   'United_States_Constitution',
#   'President_of_the_United_States'],
#  ['Human',
#   'Technology',
#   'Steel',
#   'Metal',
#   'Hydrogen',
#   'Metallurgy',
#   'Metal',
#   'Steel',
#   'Bridge',
#   'Industrial_Revolution',
#   'Manufacturing'],
#  array(['United_States', 'Household_income_in_the_United_States',
#         'Poverty', 'Employment', 'Business', 'Economics', 'Finance'],
#        dtype='<U37'),
#  array(['Electron'], dtype='<U25'),
#  ['President_of_the_United_States', 'George_Washington'],
#  ['Agriculture', 'Fossil_fuel', 'Natural_gas', 'Saudi_Arabia'],
#  array(['Petroleum'], dtype='<U12'),
#  array(['Europe', 'Christianity', 'Jesus', 'Trinity'], dtype='<U16'),
#  ['Human',
#   'Carnivore',
#   'Tyrannosaurus',
#   'Fossil_record',
#   'Paleontology',
#   'Fossil',
#   'Mineral',
#   'Calcium',
#   'Mohs_scale_of_mineral_hardness',
#   'Mineral',
#   'Biology',
#   'Cell_%28biology%29',
#   'Bacteria',
#   'Pneumonia',
#   'Health',
#   'Medicine',
#   'Anatomy',
#   'Vertebrate',
#   'Human',
#   'Brain',
#   'Cerebellum',
#   'Vertebrate'],
#  ['Wrestling'],
#  ['Oxygen', 'Ozone', 'Earth%27s_atmosphere'],
#  ['Earth', 'Weather', 'Tropical_cyclone'],
#  ['Poetry'],
#  ['Salt', 'Edible_salt'],
#  ['Latin_America'],
#  array(['Economics', 'Capitalism', 'Political_economy',
#         'Political_science', 'Statistics'], dtype='<U34'),
#  ['Elephant'],
#  ['England'],
#  ['Boat'],
#  ['U.S._Route_66'],
#  ['Italy'],
#  ['Germany'],
#  array(['United_States', 'Moon', 'Neil_Armstrong'], dtype='<U14'),
#  ['Black_panther'],
#  ['Earth', 'Geography'],
#  ['Georg_Cantor'],
#  ['Spain',
#   'Constitutional_monarchy',
#   'Sport',
#   'China',
#   'Human',
#   'Love',
#   'Family',
#   'Religion',
#   'Isaac_Newton',
#   'Physics',
#   'Science',
#   'Biology',
#   'Animal'],
#  ['Richard_Nixon', 'Lyndon_B._Johnson'],
#  array(['France', 'Constitutional_monarchy', 'French_Revolution',
#         'Algeria'], dtype='<U23'),
#  ['Serbia'],
#  ['Europe'],
#  ['Cold_War', 'Richard_Nixon', 'Elvis_Presley', 'Actor', 'Film'],
#  array(['United_States', 'Olympic_Games', '1896_Summer_Olympics',
#         'Australia', 'United_Kingdom'], dtype='<U20'),
#  ['Germany', 'Otto_von_Bismarck'],
#  ['United_States',
#   'Yellowstone_National_Park',
#   'Animal_rights',
#   'Gorilla',
#   'Herbivore',
#   'Animal'],
#  ['United_Kingdom', 'Isle_of_Man'],
#  ['Music'],
#  ['Roman_Catholic_Church'],
#  ['Triassic', 'Ichthyosaur'],
#  ['Cancer'],
#  array(['Khazars'], dtype='<U7'),
#  array(['California', 'Film', 'Actor'], dtype='<U11'),
#  array(['Earth', 'Weather'], dtype='<U20'),
#  ['India'],
#  array(['France', 'European_Union'], dtype='<U14'),
#  ['World_War_II'],
#  ['England'],
#  array(['Mexico'], dtype='<U6'),
#  ['England'],
#  array(['World_War_II', 'Nuclear_weapon'], dtype='<U15'),
#  ['France'],
#  ['Brighton'],
#  ['Bodyline'],
#  ['Human'],
#  array(['Measurement'], dtype='<U11'),
#  ['French_language', 'Roman_Empire'],
#  ['Japan', 'Time_zone'],
#  array(['Howland_Island'], dtype='<U14'),
#  ['Philip_II_of_Spain'],
#  ['United_States',
#   'Cinema_of_the_United_States',
#   '21st_century',
#   'Blade_Runner',
#   'Cinema_of_the_United_States',
#   'Los_Angeles%2C_California',
#   'Film'],
#  ['United_States'],
#  array(['Oxygen', 'Ozone'], dtype='<U6'),
#  array(['United_States', 'Cinema_of_the_United_States'], dtype='<U27'),
#  array(['Serbia'], dtype='<U10'),
#  array(['Europe', 'Rainforest'], dtype='<U10'),
#  ['Atlantic_Ocean'],
#  array(['Agriculture'], dtype='<U11'),
#  array(['Ethanol'], dtype='<U17'),
#  array(['Climate'], dtype='<U16'),
#  array(['Christianity', 'Paul_of_Tarsus'], dtype='<U14'),
#  array(['United_States', 'United_Nations'], dtype='<U18'),
#  ['Europe',
#   'Germany',
#   'Industrial_Revolution',
#   'Copper',
#   'Electricity',
#   'Thunderstorm'],
#  ['Extrasolar_planet'],
#  ['H%C3%A4nsel_und_Gretel'],
#  ['English_language', 'Old_English_language'],
#  ['Malaria', 'Anemia'],
#  ['United_States', 'New_York_City'],
#  ['Netherlands'],
#  array(['Earth', 'Photosynthesis', 'Plant', 'Tree', 'Chestnut', 'Fruit',
#         'Seed'], dtype='<U14'),
#  ['United_States',
#   'Nuclear_power',
#   'Jimmy_Carter',
#   'Aristotle',
#   'Psychology',
#   'Sigmund_Freud'],
#  ['France', 'European_Union', 'Republic_of_Ireland', '%C3%89ire'],
#  ['Honduras'],
#  ['England', 'Bede'],
#  ['Cryptography'],
#  ['City', 'Rain'],
#  ['Film'],
#  ['France', 'Indian_Ocean', 'India'],
#  array(['United_States', 'Computer', 'Toy', 'Child', 'Sport', 'Art',
#         'Film', 'Newspaper', 'Day', 'Time', 'Bible', 'Christianity',
#         'Jesus', 'Roman_Empire', 'Holy_Roman_Empire',
#         'Roman_Catholic_Church', 'Astronomy', 'Astrology',
#         'Greek_mythology', 'Romanticism', '20th_century', 'New_York_City',
#         'Culture', 'Religion', 'Society', 'Civilization', 'Climate_change',
#         'Ice', 'Ice_hockey', 'The_Simpsons', 'Halloween', 'Autumn',
#         'Winter'], dtype='<U21'),
#  ['Spain'],
#  ['United_Kingdom', 'Time_zone'],
#  ['Christianity'],
#  ['Baghdad', 'Theatre'],
#  ['Philippines', 'Volcano', 'Democratic_Republic_of_the_Congo'],
#  array(['World_War_I', 'North_Sea', 'Atlantic_Ocean', 'Pacific_Ocean',
#         'Southern_Ocean', 'Oceanography', 'Ocean', 'Pacific_Ocean',
#         'Indonesia'], dtype='<U31'),
#  ['Europe',
#   'Mediterranean_Sea',
#   'Italy',
#   'Ancient_Rome',
#   'Ancient_Greece',
#   'Plato'],
#  ['United_States',
#   'Television',
#   'Computer_and_video_games',
#   'Nintendo',
#   'The_Legend_of_Zelda_series',
#   'Super_Mario_Bros.',
#   'Nintendo_Entertainment_System'],
#  ['United_States', 'Education_in_the_United_States'],
#  ['Mesopotamia'],
#  ['Biology', 'Organism', 'Ant', 'Insect', 'Arthropod'],
#  ['Fossil'],
#  ['Taiwan', 'South_China_Sea'],
#  ['South_America'],
#  ['Roman_Catholic_Church'],
#  array(['United_States', 'Detroit%2C_Michigan', 'Super_Bowl_XL',
#         'Microsoft'], dtype='<U19'),
#  array(['Climate', 'Global_warming', 'Retreat_of_glaciers_since_1850',
#         'Ice_sheet', 'Sea_level_rise', 'Retreat_of_glaciers_since_1850',
#         'Global_warming', 'Ocean'], dtype='<U30'),
#  ['Agriculture'],
#  array(['Russia'], dtype='<U6'),
#  ['9th_century', 'Charlemagne'],
#  ['Scotland'],
#  array(['North_America', 'California', 'Arnold_Schwarzenegger', 'Actor',
#         'Television', 'BBC', 'Doctor_Who', 'The_Simpsons', 'Television',
#         'Film'], dtype='<U40'),
#  ['Animal', 'Scientific_classification', 'Mammal'],
#  ['Timbuktu'],
#  array(['United_States', 'Mississippi_River'], dtype='<U21'),
#  ['Hong_Kong'],
#  array(['Earth'], dtype='<U18'),
#  array(['United_States', 'Rhode_Island', 'U.S._state',
#         'Newark%2C_New_Jersey', 'Jew', 'Latin', 'Rome'], dtype='<U20'),
#  array(['Christianity', 'Anglican_Communion', 'Roman_Catholic_Church',
#         'Christianity', 'Anglicanism', 'John_Calvin', 'Calvin_and_Hobbes',
#         'Popular_culture', 'Film', 'Actor', 'The_Simpsons', 'Seinfeld'],
#        dtype='<U21'),
#  ['United_States',
#   'World_War_II',
#   'Battle_of_the_Bulge',
#   'United_States',
#   'Vietnam_War'],
#  array(['Maize', 'Spring_%28season%29'], dtype='<U19'),
#  ['Greek_mythology'],
#  ['Osama_bin_Laden'],
#  ['Mineral', 'Diamond'],
#  ['Dinosaur', 'Sauropodomorpha', 'Saurischia'],
#  ['United_Kingdom'],
#  ['India', 'Bangladesh'],
#  ['United_States'],
#  ['Holy_Roman_Empire'],
#  ['Edinburgh'],
#  ['Greece', 'Ancient_Greece', 'Homer', 'Trojan_War'],
#  ['United_States', 'Hip_hop_music'],
#  ['Language'],
#  ['Rhine'],
#  ['Iron', 'Georgia_%28country%29'],
#  ['Russian_language', 'Mongolia'],
#  ['France', 'European_Union', 'Europe'],
#  array(['Europe', 'Middle_East', 'Fertile_Crescent', 'Mesopotamia',
#         'Akkadian_Empire'], dtype='<U16'),
#  ['Corrosion'],
#  ['Beetle'],
#  array(['Europe', 'United_Kingdom', 'England', 'English_Channel'],
#        dtype='<U15'),
#  ['Folk_music'],
#  ['United_States',
#   'Education_in_the_United_States',
#   'University_of_Chicago',
#   'Princeton_University'],
#  ['Turtle'],
#  ['Carbon_dioxide'],
#  ['Fluorine'],
#  ['Arabic_language', 'Hebrew_language'],
#  ['Blaise_Pascal'],
#  array(['United_States'], dtype='<U13'),
#  ['English_language',
#   'England',
#   'History_of_Anglo-Saxon_England',
#   'Edward_the_Confessor',
#   'Henry_II_of_England'],
#  ['Germany', 'Country'],
#  array(['Animal', 'Precambrian', 'History_of_Earth', 'Dinosaur'],
#        dtype='<U25'),
#  ['Electricity'],
#  array(['20th_century'], dtype='<U17'),
#  ['English_language',
#   'Internet',
#   'Information',
#   'Mass_media',
#   'Television',
#   'Telecommunication'],
#  ['Japan',
#   'Meat',
#   'Poultry',
#   'Food',
#   'Health',
#   'Nutrition',
#   'Agriculture',
#   'Botany',
#   'Gardening',
#   'Plant',
#   'Wine',
#   'Fruit',
#   'Vegetable',
#   'Vitamin',
#   'Folic_acid',
#   'Cancer',
#   'Anemia',
#   'Oxygen',
#   'Chemical_element',
#   'Sulfur',
#   'Sulfuric_acid',
#   'Acid_rain',
#   'Cloud',
#   'Meteorology',
#   'Weather',
#   'Weather_forecasting'],
#  ['World_War_I', 'Middle_East', 'Lebanon'],
#  ['Europe',
#   'Culture',
#   'Organization',
#   'Corporation',
#   'Employment',
#   'Business',
#   'Money',
#   'Finance',
#   'Accountancy',
#   'Economics'],
#  ['Linux',
#   'Open_source',
#   'Linus_Torvalds',
#   'GNOME',
#   'Ubuntu_%28Linux_distribution%29'],
#  ['Aluminium'],
#  ['New_York_City',
#   'Culture',
#   'Literature',
#   'Fiction',
#   'Art',
#   'Expressionism',
#   'Impressionism',
#   '%C3%89douard_Manet',
#   'Edgar_Allan_Poe',
#   'Employment',
#   'Wikipedia_Text_of_the_GNU_Free_Documentation_License'],
#  ['United_States',
#   'Terrorism',
#   'September_11%2C_2001_attacks',
#   'Osama_bin_Laden',
#   'Afghanistan'],
#  ['19th_century', '20th_century', 'Technology'],
#  ['United_Kingdom',
#   'Hydrogen',
#   'Quantum_mechanics',
#   'Paul_Dirac',
#   'Atom',
#   'Physics',
#   'Schr%C3%B6dinger_equation'],
#  ['United_States',
#   'North_America',
#   'Earth',
#   'Solar_System',
#   'Plate_tectonics',
#   'Fossil',
#   'Dinosaur',
#   'United_States'],
#  ['United_States', 'Florida', 'Amtrak'],
#  ['United_States',
#   'Christopher_Columbus',
#   'South_America',
#   'Mestizo',
#   'Inca_Empire'],
#  array(['20th_century', 'Mass_media', 'Book', 'Poetry'], dtype='<U12'),
#  array(['Biology', 'Anthropology', 'Sociology', 'Society', 'Tribe',
#         'Ethnic_group'], dtype='<U13'),
#  ['Iron'],
#  array(['Egypt', 'Greece', 'Aristotle', 'Ancient_Greece', 'Hippocrates',
#         'Rome', '4th_century', '5th_century', 'Roman_Empire', 'Istanbul',
#         'Cairo'], dtype='<U19'),
#  ['United_States',
#   'Hip_hop_music',
#   'Music_of_the_United_States',
#   'American_popular_music',
#   'Nirvana_%28band%29'],
#  ['United_States',
#   'Denver%2C_Colorado',
#   'Rocky_Mountains',
#   'Skiing',
#   '20th_century',
#   'United_States',
#   'Education_in_the_United_States',
#   'Colorado_River'],
#  ['Europe'],
#  array(['Australia', 'Dingo', 'Kangaroo', 'Wallaby', 'Animal', 'Mammal',
#         'Platypus', 'Tasmanian_Devil', 'Wombat', 'Sydney'], dtype='<U19'),
#  ['Egypt'],
#  array(['Africa', 'Lion', 'Chordate', 'Vertebrate', 'Fish', 'Organism',
#         'Biodiversity', 'Tropics', 'Rainforest', 'Turtle', 'Reptile',
#         'Continent', 'Africa', 'Carnivore', 'Frog', 'African_clawed_frog',
#         'South_Africa', 'The_Wall_Street_Journal'], dtype='<U23'),
#  ['German_reunification'],
#  array(['England', 'Ireland', 'Eurovision_Song_Contest'], dtype='<U23'),
#  array(['North_America', 'Caribbean_Sea', 'Haiti', 'Christopher_Columbus',
#         'DNA', 'Animal', 'Bird'], dtype='<U20'),
#  ['Cloud'],
#  ['Neutron'],
#  ['Earth',
#   'Crust_%28geology%29',
#   'Geology',
#   'Science',
#   'Mathematics',
#   'Arithmetic',
#   'Elementary_arithmetic'],
#  ['French_language'],
#  ['United_Kingdom'],
#  array(['Philosophiae_Naturalis_Principia_Mathematica'], dtype='<U44'),
#  ['Child', 'Tiger_Woods'],
#  ['Education'],
#  ['Petroleum', 'Venezuela', 'Andes'],
#  ['Science'],
#  ['Islam'],
#  ['Scientific_classification', 'Organism', 'DNA', 'Genetic_code'],
#  ['United_Kingdom', 'Roman_Britain', 'Rome', 'Italy'],
#  ['United_States', 'Nuclear_weapon', 'World_War_II'],
#  ['Kosovo'],
#  ['London'],
#  array(['Carbon'], dtype='<U14'),
#  ['Extraterrestrial_life'],
#  ['United_States', 'World_War_II', 'Battle_of_the_Bulge', 'United_States'],
#  ['Trafalgar_Square'],
#  ['United_States', 'U.S._state'],
#  array(['North_America'], dtype='<U13'),
#  ['Malaysia'],
#  ['Nirvana_%28band%29'],
#  ['Palace_of_Westminster'],
#  ['Atlantic_Ocean'],
#  ['United_States',
#   'United_States_Constitution',
#   'Fourteenth_Amendment_to_the_United_States_Constitution',
#   'Franklin_D._Roosevelt'],
#  ['Alfred_Hitchcock'],
#  ['Linguistics'],
#  ['Europe'],
#  ['Europe', 'NATO', 'Italy'],
#  ['Christianity', 'Roman_Empire'],
#  ['Earth',
#   'Oxygen',
#   'DNA',
#   'Cell_%28biology%29',
#   'Human',
#   'Science',
#   'Biology',
#   'Anatomy'],
#  ['Lost_%28TV_series%29'],
#  ['North_America'],
#  ['Italy', 'Renaissance', 'Oil_painting', 'Impressionism', 'Claude_Monet'],
#  ['Sistine_Chapel_ceiling'],
#  ['United_States', 'Liberal_democracy'],
#  ['Despotism'],
#  ['Tropical_cyclone'],
#  ['Human',
#   'Government',
#   'George_W._Bush',
#   'United_States_House_of_Representatives',
#   'British_House_of_Commons'],
#  ['United_States',
#   'Yellowstone_National_Park',
#   'Ulysses_S._Grant',
#   'American_Civil_War',
#   'Jesus',
#   'Last_Supper'],
#  ['United_States',
#   'United_Nations',
#   'International_law',
#   'World_Trade_Organization'],
#  ['United_States',
#   'List_of_rivers_by_length',
#   'Nile',
#   'Egypt',
#   'Giza_pyramid_complex',
#   'Great_Pyramid_of_Giza'],
#  ['Christianity'],
#  ['Spain'],
#  ['Judaism', 'The_Holocaust', 'Nazi_Germany', 'Fascism', 'Communism'],
#  ['Argentina'],
#  array(['Africa', 'Hyena', 'Carnivore', 'Carnivore', 'Walrus',
#         'Scientific_classification'], dtype='<U25'),
#  ['Oxygen'],
#  ['United_States', 'Moon', 'Soviet_Union'],
#  ['U.S._state', 'Oregon'],
#  array(['United_States', 'West_Virginia', 'Suffrage', 'Finland',
#         'Agriculture', 'History_of_the_world', 'North_America',
#         'United_States'], dtype='<U20'),
#  array(['Africa'], dtype='<U17'),
#  ['United_States'],
#  ['List_of_European_Union_member_states_by_accession'],
#  ['France', 'United_Kingdom', 'London', 'Buckingham_Palace'],
#  ['Cornea'],
#  array(['Manufacturing'], dtype='<U13'),
#  array(['13th_century', 'Time'], dtype='<U12'),
#  array(['United_Kingdom', 'Constitutional_monarchy', 'Monarchy'],
#        dtype='<U23'),
#  ['Flemish_%28linguistics%29'],
#  ['Scotland', 'Parliament_of_the_United_Kingdom'],
#  array(['France', 'French_Revolution', 'Democracy'], dtype='<U17'),
#  array(['Middle_Ages', 'Christian_monasticism', 'Abbot'], dtype='<U27'),
#  ['Byzantine_Empire', 'Iraq'],
#  ['United_Kingdom',
#   'England',
#   'Germany',
#   'Capital',
#   'South_Africa',
#   'Dance',
#   'Sport',
#   'Football_%28soccer%29',
#   'Football'],
#  ['Napster'],
#  ['United_States', 'Islam'],
#  array(['United_States', 'Elvis_Presley', 'Actor', 'The_Simpsons',
#         'Popular_culture', 'Music', 'Art', 'Film', 'Actor'], dtype='<U15'),
#  ['Timbuktu'],
#  ['Booby'],
#  ['J._K._Rowling'],
#  ['Athanasius_Kircher'],
#  ['Animal', 'Mammal', 'Human', 'Chimpanzee', 'Bonobo'],
#  ['World_War_II'],
#  ['Tank'],
#  ['Latin', 'Vatican_City', 'Rome', 'Michelangelo'],
#  array(['Physics', 'Science', 'Political_science'], dtype='<U17'),
#  ['Mathematics', 'Computer_science', 'Computer_programming', 'Unix'],
#  array(['Art'], dtype='<U21'),
#  ['United_States', 'Yellowstone_National_Park'],
#  ['Apollo'],
#  ['United_Kingdom', 'Scotland', 'Glorious_Revolution', 'Scottish_Highlands'],
#  ['Earth',
#   'Human',
#   'Brain',
#   'Cerebellum',
#   'Eye',
#   'Cornea',
#   'Pupil',
#   'Retina',
#   'Chemical_synapse'],
#  array(['Art', 'Romanticism'], dtype='<U12'),
#  array(['Film', 'Actor', 'The_Simpsons', 'Popular_culture'], dtype='<U15'),
#  ['Ireland'],
#  ['Earth'],
#  array(['Animal', 'Bird', 'Albatross'], dtype='<U9'),
#  ['The_Beatles'],
#  ['United_Kingdom', 'Ireland', 'Republic_of_Ireland'],
#  array(['Africa', 'Carnivore', 'Gray_Wolf'], dtype='<U14'),
#  array(['Japan', 'Mario', 'Television', 'Computer_and_video_games'],
#        dtype='<U24'),
#  ['Hurricane_Andrew', 'Hurricane_Camille'],
#  ['Lord_Voldemort'],
#  ['Electricity'],
#  array(['Earth', 'Energy', 'Petroleum'], dtype='<U9'),
#  ['Archbishop_of_Canterbury'],
#  ['England',
#   'Culture',
#   '20th_century',
#   'Internet',
#   'World_Wide_Web',
#   'Mass_media'],
#  ['Poland', 'Climate'],
#  ['Bantu'],
#  ['Atlantic_Ocean'],
#  ['Middle_Ages'],
#  ['China', 'Economics', 'Education', 'Technology', 'Electronics'],
#  ['United_Kingdom', 'Republic_of_Ireland', 'Ireland'],
#  ['United_Kingdom', 'Republic_of_Ireland', 'Ireland', 'Irish_poetry'],
#  ['North_America', 'Continent'],
#  ['Brain', 'Emotion', 'Mind'],
#  ['Roman_Empire'],
#  array(['India'], dtype='<U14'),
#  ['Spain'],
#  ['Henry_III_of_England'],
#  ['Black-backed_Jackal'],
#  ['Fed_Cup'],
#  ['Niccol%C3%B2_Paganini'],
#  ['People%27s_Republic_of_China', 'Steel'],
#  ['Middle_East'],
#  ['United_States',
#   'Apollo_11',
#   'Moon_landing',
#   'John_F._Kennedy',
#   'Space_Race',
#   'Space_exploration'],
#  ['Eye'],
#  ['Saturn'],
#  ['United_Nations', 'Sudan'],
#  ['Blackcap'],
#  ['Global_warming'],
#  ['Art'],
#  ['William_Gilbert'],
#  ['Genetics'],
#  array(['Literacy'], dtype='<U8'),
#  ['Chemistry'],
#  ['World_War_I', 'Middle_East'],
#  ['Italy'],
#  array(['Animal', 'Human', 'Cell_%28biology%29', 'Organism'], dtype='<U18'),
#  ['Animal'],
#  ['Steel', 'Chromium', 'List_of_elements_by_name'],
#  ['Isaac_Newton'],
#  ['United_States', 'Ethnic_group'],
#  ['Nigeria'],
#  array(['China', 'Christianity', 'Religion', 'Philosophy', 'Ethics',
#         'Psychology', 'Political_science'], dtype='<U17'),
#  ['Germany'],
#  array(['Electric_field'], dtype='<U14'),
#  array(['North_America'], dtype='<U15'),
#  ['United_Kingdom', 'Parliament_of_the_United_Kingdom', 'Glorious_Revolution'],
#  ['Plant'],
#  ['United_States',
#   'United_States_Declaration_of_Independence',
#   'American_Revolutionary_War'],
#  ['United_Kingdom'],
#  array(['List_of_countries_by_system_of_government'], dtype='<U41'),
#  ['Comet'],
#  ['Pacific_Ocean'],
#  ['Earth'],
#  ['Italy'],
#  ['Mammal', 'Bird', 'Theropoda'],
#  ['S%C3%A3o_Paulo'],
#  ['New_Zealand'],
#  ['Energy', 'Force'],
#  ['Snow'],
#  ['Atlantic_Ocean', 'Ocean', 'Fish', 'Whale_shark', 'Shark', 'Chordate'],
#  ['United_States'],
#  ['United_States',
#   'George_W._Bush',
#   'Chicago',
#   'National_Hockey_League',
#   'Europe',
#   'Republic_of_Ireland',
#   'U2'],
#  ['Attila_the_Hun'],
#  ['Central_processing_unit'],
#  array(['United_States', 'Japan', 'Tokyo', 'Osaka', 'Japan', 'Nintendo',
#         'Computer_and_video_games'], dtype='<U24'),
#  ['Edgar_Allan_Poe'],
#  ['United_States',
#   'Country',
#   'United_Kingdom',
#   'India',
#   'Indira_Gandhi',
#   'Indian_independence_movement'],
#  ['History', 'Linguistics', 'Noam_Chomsky'],
#  ['Agriculture', 'Irrigation'],
#  array(['Mars'], dtype='<U4'),
#  ['Cocoa'],
#  array(['William_Shakespeare'], dtype='<U19'),
#  ['Periodic_table'],
#  ['19th_century'],
#  array(['Evolution', 'Fish', 'Aquarium', 'Philadelphia'], dtype='<U12'),
#  ['International_Space_Station',
#   'Space_Shuttle_program',
#   'Boeing_747',
#   'Airbus_A380'],
#  ['California'],
#  array(['English_language', 'Internet', 'Optical_fiber', 'Light', 'Eye',
#         'Organism', 'Pond', 'Vegetation', 'Plant', 'Animal', 'Insect',
#         'Beetle', 'Aphid', 'Ant'], dtype='<U16'),
#  ['United_Kingdom', 'Olympic_Games', 'World_War_II'],
#  ['Clarinet'],
#  ['Spain'],
#  ['Fish', 'Tuna'],
#  ['United_States', 'New_York_City', 'American_football'],
#  array(['Reptile', 'Reptile'], dtype='<U30'),
#  ['Pakistan'],
#  array(['Ukraine'], dtype='<U7'),
#  ['Egypt', 'Ancient_Egypt'],
#  ['The_Godfather'],
#  ['Battle_of_Hastings'],
#  ['Republic_of_Ireland', 'Church_of_Ireland'],
#  ['Where_Did_Our_Love_Go'],
#  ['United_States', 'Capitalism', 'Money', 'United_States_dollar'],
#  ['Irrigation', 'Rain', 'Sphere'],
#  ['Switzerland'],
#  ['British_Empire'],
#  ['Pennsylvania_Railroad'],
#  array(['Earth%27s_atmosphere'], dtype='<U20'),
#  ['United_States'],
#  array(['Agriculture', 'Fish', 'Whale_shark', 'Family'], dtype='<U11'),
#  ['Aristotle',
#   'Poetry',
#   'Globalization',
#   'Sociology',
#   'Society',
#   'Organization'],
#  ['United_States', 'Cold_War', 'Nuclear_weapon', 'Uranium'],
#  ['Novel'],
#  ['Atom'],
#  ['United_Kingdom'],
#  array(['England', 'London', 'Nottingham'], dtype='<U17'),
#  ['Toy'],
#  ['United_States',
#   'Country',
#   'Law',
#   'Election',
#   'Government',
#   'Liberalism',
#   'Democracy',
#   'Liberal_democracy',
#   'Slavery'],
#  ['English_language', 'Language', 'Communication'],
#  ['United_States', 'Education_in_the_United_States'],
#  ['Switzerland', 'Industrial_Revolution', 'Ship', 'Hovercraft', 'Boat'],
#  ['Sony'],
#  ['United_States'],
#  ['Animal', 'Mammal'],
#  ['United_Kingdom'],
#  ['United_States',
#   'California',
#   'Computer',
#   'Internet',
#   'Microsoft',
#   'Microsoft_Windows',
#   'Macintosh',
#   'Bill_Gates',
#   'Programming_language'],
#  ['United_States'],
#  ['German_language'],
#  array(['Film', 'Actor', 'The_Marriage_of_Figaro'], dtype='<U22'),
#  ['President_of_the_United_States',
#   'United_States_Constitution',
#   'United_States_Bill_of_Rights',
#   'Fourteenth_Amendment_to_the_United_States_Constitution',
#   'Equal_Protection_Clause',
#   'Gender'],
#  ['Sand'],
#  array(['United_States', 'California', 'Computer'], dtype='<U13'),
#  ['20th_century'],
#  ['English_language'],
#  ['Germany'],
#  ['Mexico', 'Malawi'],
#  ['Germany', 'Netherlands'],
#  ['18th_century',
#   '17th_century',
#   '16th_century',
#   '15th_century',
#   '14th_century',
#   '13th_century'],
#  ['China'],
#  ['George_W._Bush'],
#  ['English_Channel', 'Channel_Islands', 'Victor_Hugo'],
#  ['World_War_II', 'Singapore'],
#  ['Flower'],
#  ['Siege'],
#  array(['United_Kingdom', 'British_Empire', 'Elizabeth_I_of_England',
#         'Edward_III_of_England'], dtype='<U22'),
#  ['Reptile', 'Food', 'Cereal', 'Maize'],
#  ['Atlantic_Ocean', 'Falkland_Islands'],
#  array(['United_States', 'George_W._Bush', 'Houston%2C_Texas'],
#        dtype='<U16'),
#  ['Radio', 'Electromagnetic_radiation'],
#  array(['Chicago_and_North_Western_Railway'], dtype='<U33'),
#  ['Jersey'],
#  ['Genetics'],
#  ['South_America', 'Caribbean_Sea'],
#  ['United_Kingdom', 'Lake_District', 'England'],
#  ['Jehovah'],
#  array(['France', 'World_War_I'], dtype='<U11'),
#  ['Chernobyl_disaster'],
#  ['Africa', 'Herbivore', 'Animal', 'Mammal'],
#  ['Light', 'Galileo_Galilei', 'Astronomy'],
#  ['United_States',
#   'American_Revolutionary_War',
#   'War_of_the_Spanish_Succession'],
#  ['Christianity', 'Roman_Catholic_Church', 'Asia', 'Africa'],
#  array(['Latin', 'Byzantine_Empire'], dtype='<U26'),
#  ['Africa', 'Cape_Town', 'Sub-Saharan_Africa', 'South_Africa', 'Cape_Town'],
#  array(['Plant'], dtype='<U5'),
#  ['David_Attenborough'],
#  ['England', 'London'],
#  ['Edward_VIII_of_the_United_Kingdom'],
#  array(['Egypt', 'Hebrew_language'], dtype='<U16'),
#  ['Water', 'Ice'],
#  array(['Human', 'Cell_%28biology%29', 'DNA', 'Genetics'], dtype='<U18'),
#  ['Colombia'],
#  ['Trumpet'],
#  ['Government_of_France'],
#  ['Hydrogen', 'Schr%C3%B6dinger_equation'],
#  array(['Economics', 'Money', 'Finance', 'Accountancy'], dtype='<U23'),
#  array(['Brain', 'Action_potential'], dtype='<U16'),
#  array(['United_Kingdom', 'Scotland'], dtype='<U23'),
#  ['France', 'Russia'],
#  ['Fruit', 'Food', 'Peanut'],
#  ['Dog', 'Onion'],
#  ['Soviet_Union'],
#  ['France'],
#  ['Gmail'],
#  ['Super_Chief'],
#  ['United_States'],
#  array(['United_Kingdom', 'Lion', 'Carnivore', 'Vitamin', 'Vitamin_C',
#         'Scurvy', 'Vegetable', 'Plant', 'Maize', 'Cereal', 'Wheat'],
#        dtype='<U37'),
#  ['Gravitation', 'Mineral', 'Sulfur', 'Nature'],
#  ['Blue_Whale'],
#  ['Corinthian_War'],
#  ['Philosophy'],
#  ['John_Calvin'],
#  ['Latin'],
#  ['Red_giant'],
#  ['Portugal', 'European_Union'],
#  ['Africa', 'Tunisia'],
#  ['Europe', 'Russia', 'Soviet_Union'],
#  ['India', 'United_Arab_Emirates'],
#  ['United_States', 'Music_of_the_United_States', 'American_popular_music'],
#  ['20th_century',
#   'Technology',
#   'Space_exploration',
#   'Yuri_Gagarin',
#   'Moon',
#   'Neil_Armstrong',
#   'Space_Shuttle_Challenger_disaster'],
#  ['Capital', 'Politics', 'Religion'],
#  ['United_States',
#   'United_States_Constitution',
#   'President_of_the_United_States',
#   'Monarchy',
#   'Democracy',
#   'Ancient_Greece',
#   'Athens'],
#  ['Russia',
#   'Law',
#   'Company_%28law%29',
#   'Business',
#   'Transport',
#   'Energy',
#   'Electricity',
#   'Electronics',
#   'Semiconductor_device',
#   'Electron',
#   'Electric_charge',
#   'Electric_field',
#   'Volt'],
#  array(['Boston%2C_Massachusetts'], dtype='<U23'),
#  ['Mammal', 'Milk', 'Butter', 'Peanut', 'Maize', 'Barbara_McClintock'],
#  ['Germany'],
#  ['Hydrogen',
#   'Carbon',
#   'Coal',
#   'Industrial_Revolution',
#   'Rail_transport',
#   'Train',
#   'Florida'],
#  array(['World_War_II', 'Egypt'], dtype='<U14'),
#  array(['United_States', 'Fine_art', 'Visual_arts', 'Comics'], dtype='<U24'),
#  ['United_States', 'Pacific_Ocean'],
#  ['Middle_Ages'],
#  ['William_Wilberforce'],
#  ['Europe', 'Arctic_Ocean', 'Walrus', 'Orca', 'Fish', 'Organism'],
#  array(['United_States', 'Fine_art', 'Literature', 'Poetry'], dtype='<U13'),
#  ['Africa', 'North_Africa'],
#  ['International_Red_Cross_and_Red_Crescent_Movement'],
#  ['England', 'London', 'National_Gallery%2C_London'],
#  ['United_Kingdom', 'Ireland'],
#  ['United_States', 'Atlantic_Ocean', 'United_Kingdom', 'London'],
#  ['Rain', 'Thunderstorm'],
#  array(['Art', 'Drawing', '21st_century'], dtype='<U26'),
#  ['Agriculture', 'Horse', 'Mammal'],
#  ['Airship'],
#  array(['Europe', 'Russia', 'Finland', 'Norway', 'Germany'], dtype='<U32'),
#  ['United_States',
#   'Moon',
#   'Apollo_11',
#   'Moon_landing',
#   'Neil_Armstrong',
#   'Space_Shuttle_Challenger_disaster',
#   'Space_Shuttle_Challenger',
#   'Space_Shuttle_Columbia'],
#  ['World_War_II', 'Japan', 'Electronics'],
#  array(['United_States', 'Mining', 'Diamond', 'Semiconductor',
#         'Semiconductor_device', 'Quantum_mechanics', 'Albert_Einstein',
#         'Wave', 'Electromagnetic_radiation', 'Electron'], dtype='<U25'),
#  ['John_F._Kennedy_assassination'],
#  array(['United_States', 'Elvis_Presley', 'Kurt_Cobain',
#         'Alternative_rock', 'Musical_instrument', 'Music', 'Jazz',
#         'Louis_Armstrong', 'Radio', 'Television', 'BBC', 'Podcasting',
#         'ITunes', 'Hip_hop_music', 'Music_of_the_United_States',
#         'Rhythm_and_blues', 'United_States', 'Mississippi_River'],
#        dtype='<U26'),
#  ['Religion', 'Peru', 'Inca_Empire'],
#  ['Sugar_beet'],
#  ['Crystal'],
#  ['Yes_Minister'],
#  array(['United_States', 'Hip_hop_music', 'Music_of_the_United_States',
#         'American_popular_music', 'Nirvana_%28band%29'], dtype='<U26'),
#  ['Metal'],
#  ['United_States',
#   'Religious_Society_of_Friends',
#   'Jesus',
#   'Christianity',
#   'Religion',
#   'Science',
#   'Technology'],
#  ['United_States', 'Pacific_Ocean'],
#  ['Viking'],
#  ['Germany', 'Italy', 'Middle_Ages', 'Book_of_Kells', 'Lindisfarne_Gospels'],
#  ['Ethiopian_Wolf'],
#  ['Linux', 'Richard_Stallman'],
#  array(['Textile', 'Clothing'], dtype='<U8'),
#  ['Ivory'],
#  ['United_States', 'Petroleum'],
#  ['Poetry_of_the_United_States'],
#  ['Physics', 'Force', 'Momentum'],
#  ['United_States',
#   'Pacific_Ocean',
#   'Atlantic_Ocean',
#   'Whale',
#   'Fish',
#   'Whale_shark',
#   'Shark'],
#  ['France', 'Paris'],
#  ['Carbon_dioxide'],
#  ['Matrix_%28mathematics%29'],
#  ['Osmium'],
#  ['United_States'],
#  ['The_Lion_King', 'Forrest_Gump'],
#  ['Middle_Ages', 'Mediterranean_Sea', 'Red_Sea'],
#  array(['Rome'], dtype='<U15'),
#  ['United_States', 'President_of_the_United_States'],
#  ['Soviet_Union',
#   'Forest',
#   'Tree',
#   'Agriculture',
#   'History_of_the_world',
#   'Transport'],
#  ['United_States',
#   'Pacific_Ocean',
#   'Tropical_cyclone',
#   'Tropics',
#   'Climate',
#   'Weather',
#   'Japan'],
#  ['Christianity'],
#  array(['Lighting_designer'], dtype='<U17'),
#  ['Greece'],
#  ['Jonah_Lomu'],
#  array(['United_States', 'American_Civil_War', 'Martin_Luther'],
#        dtype='<U18'),
#  ['Tourism'],
#  ['Johannes_Kepler'],
#  ['Colossus_of_Rhodes'],
#  array(['Kenya', 'Lion', 'Sahara'], dtype='<U6'),
#  ['United_States', 'Yellowstone_National_Park'],
#  ['United_States', 'Country', 'Earth'],
#  ['China', 'Yangtze_River'],
#  ['Angkor'],
#  ['English_language'],
#  ['Sri_Lanka'],
#  ['International_Space_Station', 'Space_station'],
#  ['Sweden', 'Revolution', 'Political_science'],
#  ['Blitzkrieg'],
#  ['Saladin'],
#  array(['English_language', 'England'], dtype='<U16'),
#  ['Salt'],
#  array(['English_language', 'Internet', 'Information'], dtype='<U21'),
#  ['Ramayana'],
#  ['Pompeii'],
#  ['Australia'],
#  ['Philosophy',
#   'Religion',
#   'Society',
#   'Culture',
#   'Anthropology',
#   'Evolution',
#   'Organism',
#   'Ecology',
#   'Bear',
#   'Mammal'],
#  ['Earth'],
#  ['United_Kingdom'],
#  ['Philippines'],
#  ['Science', 'Computer_science'],
#  ['England', 'Spain'],
#  array(['United_States', 'Corporation'], dtype='<U13'),
#  ['Italy'],
#  ['Boston%2C_Massachusetts', 'Biotechnology'],
#  array(['United_Kingdom', 'United_Kingdom',
#         'Elizabeth_II_of_the_United_Kingdom',
#         'George_VI_of_the_United_Kingdom',
#         'Edward_VIII_of_the_United_Kingdom',
#         'George_V_of_the_United_Kingdom',
#         'Edward_VII_of_the_United_Kingdom',
#         'George_III_of_the_United_Kingdom'], dtype='<U34'),
#  ['Christianity', 'John_Calvin', 'Egg_%28food%29'],
#  array(['Capital'], dtype='<U7'),
#  ['United_States',
#   'United_States_Declaration_of_Independence',
#   'George_Washington',
#   'American_Revolutionary_War',
#   'Atlantic_Ocean',
#   'RMS_Titanic',
#   'World_War_II'],
#  ['Florida'],
#  ['Atlantic_Ocean',
#   'Arctic_Ocean',
#   'Arctic',
#   'Global_warming',
#   'Retreat_of_glaciers_since_1850'],
#  ['Russia', 'Battle_of_Stalingrad', 'Romania', 'Israel'],
#  ['United_States', 'Cinema_of_the_United_States', 'DVD'],
#  array(['United_States', 'U.S._state',
#         'List_of_U.S._states_by_date_of_statehood'], dtype='<U40'),
#  ['South_Africa'],
#  ['England',
#   'History_of_Anglo-Saxon_England',
#   'Rome',
#   'Ancient_Rome',
#   'Italy'],
#  ['Cobalt'],
#  ['India'],
#  ['Capitalism'],
#  ['United_States',
#   'Mexico',
#   'Maya_civilization',
#   'Mythology',
#   'Greek_mythology'],
#  ['New_Zealand', 'Forest', 'Tree', 'Plant', 'Flower'],
#  ['Japan', 'Pacific_Ocean', 'South_America', 'Spain', 'Portugal'],
#  ['India'],
#  ['China'],
#  ['Order_of_the_Bath'],
#  ['South_Africa', 'Madagascar'],
#  ['Togo'],
#  ['United_States', 'George_W._Bush', 'Houston%2C_Texas', 'Global_city'],
#  ['United_States',
#   'Oregon',
#   'California',
#   'United_States',
#   'September_11%2C_2001_attacks',
#   'NATO'],
#  array(['Martin_Luther_King%2C_Jr.'], dtype='<U25'),
#  ['Art'],
#  ['Julius_Caesar'],
#  ['Electricity', 'Coulomb%27s_law', 'Albert_Einstein', 'Capitalism'],
#  ['England',
#   'Church_of_England',
#   'Elizabeth_II_of_the_United_Kingdom',
#   'Buckingham_Palace'],
#  array(['United_Kingdom', 'Northern_Ireland', 'Church_of_Ireland'],
#        dtype='<U19'),
#  ['Animal_rights'],
#  ['North_America'],
#  array(['United_States', 'George_W._Bush'], dtype='<U14'),
#  ['Anemia'],
#  ['Libya', 'Human_rights', 'Poverty', 'Crime', 'Society'],
#  ['Germany',
#   'Soviet_Union',
#   'Russia',
#   'People%27s_Republic_of_China',
#   'Government',
#   'Country'],
#  ['Africa', 'Diamond'],
#  ['Roman_Catholic_Church'],
#  ['Magnesium'],
#  ['United_States',
#   'Hip_hop_music',
#   'Rhythm_and_blues',
#   'American_popular_music'],
#  ['Banana'],
#  ['Economics'],
#  ['Salt', 'Sodium', 'Sodium_hydroxide'],
#  ['Netherlands'],
#  array(['United_States', 'Crime', 'Economics', 'Employment'], dtype='<U13'),
#  ['Protein'],
#  ['Ireland', 'Natural_gas', 'Petroleum'],
#  array(['India'], dtype='<U5'),
#  ['Ouagadougou'],
#  ['Slavery'],
#  ['England',
#   '10th_century',
#   'Time',
#   'Isaac_Newton',
#   'Heliocentrism',
#   '2nd_century',
#   'Anno_Domini',
#   'Christianity'],
#  array(['United_States'], dtype='<U15'),
#  ['Business', 'Wall_Street'],
#  ['United_States'],
#  ['United_States', 'Olympic_Games', 'Carl_Lewis'],
#  ['Europe', 'European_Union', 'European_Parliament'],
#  ['United_States',
#   'Denver%2C_Colorado',
#   'Rocky_Mountains',
#   'Yellowstone_National_Park'],
#  ['Cat'],
#  ['Parliament_of_Canada'],
#  ['Tropical_cyclone'],
#  ['United_States'],
#  ['United_States', 'Canada'],
#  ['United_Nations'],
#  ['Elizabeth_II_of_the_United_Kingdom', 'George_VI_of_the_United_Kingdom'],
#  array(['United_States', 'Cinema_of_the_United_States'], dtype='<U27'),
#  array(['United_States', 'Country', 'Earth', 'Arabic_language', 'Iran',
#         'Persian_Empire', 'Abbasid'], dtype='<U18'),
#  ['United_States', 'Agriculture', 'Food', 'Protein'],
#  ['Light'],
#  ['Australia', 'Australian_English'],
#  ['Global'],
#  ['United_States',
#   'New_York_City',
#   'Wall_Street',
#   'Trade_union',
#   'Corporation',
#   'Andrew_Carnegie',
#   'Petroleum',
#   'Industry',
#   'Industrial_Revolution',
#   'Robert_Owen',
#   'Business',
#   'Wall_Street',
#   'New_York_City',
#   'George_W._Bush'],
#  ['Lightning_rod'],
#  ['Physics'],
#  ['World_War_I'],
#  ['20th_century'],
#  ['United_States', 'Household_income_in_the_United_States', 'Oregon'],
#  ['Europe', 'Mediterranean_Sea', 'Africa', 'Lion'],
#  array(['Philosophy', 'Logic', 'Plato', 'The_Mismeasure_of_Man',
#         'History_of_science'], dtype='<U21'),
#  ['Superconductivity'],
#  ['Manufacturing', 'Electronics'],
#  ['Spain'],
#  ['Three_Laws_of_Robotics'],
#  ['Physics', 'Gravitation'],
#  ['Norse_mythology'],
#  array(['United_Kingdom', 'British_Empire', 'India'], dtype='<U17'),
#  array(['Bacteria', 'Evolution', 'Fossil_record', 'Devonian', 'Fossil',
#         'Evolution', 'Bacteria', 'Eukaryote'], dtype='<U13'),
#  array(['United_States'], dtype='<U29'),
#  ['Animal'],
#  ['Panama_Canal'],
#  ['Star', 'Big_Bang'],
#  ['United_States'],
#  ['New_York_City'],
#  ['United_States', 'Yellowstone_National_Park'],
#  ['Europe', 'Greek_mythology', 'Mythology', 'Folklore', 'Scottish_mythology'],
#  ['United_States'],
#  array(['Germany', 'Poland', 'World_War_II'], dtype='<U16'),
#  array(['Drawing'], dtype='<U11'),
#  array(['European_Union', 'Global_warming',
#         'Retreat_of_glaciers_since_1850'], dtype='<U30'),
#  ['Fossil_fuel', 'Biofuel'],
#  ['President_of_the_United_States', 'George_W._Bush', 'Stem_cell'],
#  ['Nigeria', 'Lagos'],
#  ['United_States', 'Florida'],
#  ['Allosaurus'],
#  array(['Paris', 'Transport', 'Automobile', 'Karl_Benz', 'Auto_racing',
#         'Formula_One'], dtype='<U20'),
#  ['The_Beatles', 'Bob_Dylan', 'Neil_Young'],
#  ['England', 'London', 'New_York_City'],
#  ['Atlantic_Ocean',
#   'Tropical_cyclone',
#   'Hurricane_Katrina',
#   '2005_Atlantic_hurricane_season',
#   '2004_Atlantic_hurricane_season'],
#  array(['United_States', 'Pacific_Ocean', 'Volcano', 'Mauna_Loa'],
#        dtype='<U30'),
#  ['United_States', 'American_football'],
#  ['Attack_on_Pearl_Harbor'],
#  array(['South_America', 'Petroleum', 'Carbon', 'Natural_gas', 'Mining'],
#        dtype='<U13'),
#  ['World_War_II',
#   'Attack_on_Pearl_Harbor',
#   'September_11%2C_2001_attacks',
#   'Mercury_%28element%29'],
#  ['Globe_Theatre'],
#  ['English_language', 'United_Nations'],
#  ['India'],
#  array(['Latin', 'Roman_Empire', 'Civilization', 'Iran', 'Middle_East',
#         'Mesopotamia'], dtype='<U12'),
#  ['United_Nations'],
#  ['Venezuela'],
#  ['Roman_Empire'],
#  array(['California', 'Los_Angeles%2C_California', 'Film', 'Actor',
#         'Drama'], dtype='<U25'),
#  ['London'],
#  ['Soil'],
#  ['United_States'],
#  ['United_States'],
#  ['North_America', 'Atlantic_Ocean'],
#  ['Germany'],
#  array(['United_States', 'Canada'], dtype='<U13'),
#  ['Sweden'],
#  ['North_Sea'],
#  ['Machu_Picchu'],
#  ['Rome'],
#  array(['Weight_training'], dtype='<U15'),
#  ['Norfolk'],
#  ['Europe'],
#  ['United_States', 'Liberal_democracy', 'Liberalism'],
#  ['Germany', 'NATO', 'Cold_War', 'Communism', 'Human', 'Language'],
#  ['France', 'North_Sea'],
#  array(['Big_Bang'], dtype='<U15'),
#  ['Middle_Ages', '5th_century', '1st_century_BC'],
#  array(['Puerto_Rico', 'Dominican_Republic', 'Caribbean_Sea', 'James_Bond'],
#        dtype='<U18'),
#  ['United_Kingdom', 'British_Empire', 'South_Africa'],
#  ['Istanbul'],
#  ['Plant', 'Potato', 'Maize'],
#  ['Bronze_Age'],
#  array(['NATO', 'September_11%2C_2001_attacks'], dtype='<U28'),
#  ['Atlantic_Ocean', 'Sea', 'North_Sea'],
#  ['Europe',
#   'United_Kingdom',
#   'Constitutional_monarchy',
#   'Elizabeth_II_of_the_United_Kingdom',
#   'British_Empire',
#   'Henry_VII_of_England',
#   'Westminster_Abbey',
#   'Oliver_Cromwell'],
#  array(['Middle_East', 'Lebanon', 'Syria', 'Cereal', 'Bread'], dtype='<U29'),
#  ['W._Mark_Felt'],
#  ['United_States', 'U.S._state', 'Denver%2C_Colorado', 'Rocky_Mountains'],
#  ['United_States'],
#  ['Mars'],
#  ['Croatia'],
#  ['France', 'Country', 'Earth', 'Geography', 'Marco_Polo', 'Genoa'],
#  ['Plant', 'Flower'],
#  ['Petroleum'],
#  ['British_Empire'],
#  array(['Scientific_classification', 'Evolution', 'Biology', 'Human',
#         'Cell_%28biology%29'], dtype='<U25'),
#  ['Physics', 'Science'],
#  array(['India', 'Bay_of_Bengal', 'Ganges_River', 'Dolphin', 'Mammal',
#         'Lion', 'North_Africa'], dtype='<U13'),
#  ['Able_Archer_83'],
#  ['Electric_charge'],
#  ['Sultan'],
#  ['20th_century', 'Technology'],
#  ['Michelangelo', 'Italian_Renaissance'],
#  ['Mauritius'],
#  array(['European_Union', 'Soviet_Union',
#         'Federal_Bureau_of_Investigation', 'Terrorism'], dtype='<U31'),
#  ['France', 'French_Revolution', 'Napoleon_I_of_France', 'France'],
#  ['New_York_City'],
#  ['Paris'],
#  ['England'],
#  ['United_States', 'Chicago'],
#  ['England', 'Culture', 'Art', 'Renaissance'],
#  ['India', 'Indus_River', 'Tibet'],
#  ['Charles_Darwin'],
#  ['China', 'Ming_Dynasty'],
#  ['Hawk-Eye'],
#  ['English_language', 'German_language', 'High_German_consonant_shift'],
#  ['United_States',
#   'Rocky_Mountains',
#   'Salt_Lake_City%2C_Utah',
#   'Great_Salt_Lake'],
#  ['Mathematics', 'Number'],
#  ['Scientific_classification', 'Aristotle', 'Biology'],
#  ['United_States', 'Manifest_Destiny'],
#  ['Tree', 'Triassic', 'Ichthyosaur'],
#  ['California',
#   'Invasive_species',
#   'Giraffe',
#   'Mammal',
#   'Lion',
#   'Carnivore',
#   'Hyena',
#   'Mongoose',
#   'Cat',
#   'Wild_cat'],
#  ['United_States',
#   'North_America',
#   'Panama',
#   'Theodore_Roosevelt',
#   'William_Howard_Taft',
#   'President_of_the_United_States',
#   'George_W._Bush',
#   'Bill_Clinton',
#   'John_F._Kennedy'],
#  array(['Japan', 'Asia', 'Continent', 'South_America',
#         'Trinidad_and_Tobago'], dtype='<U19'),
#  ['United_States', 'Elvis_Presley'],
#  ['India', 'Currency', 'List_of_circulating_currencies'],
#  ['Music_of_Spain'],
#  ['United_States',
#   'President_of_the_United_States',
#   'John_F._Kennedy',
#   'Bob_Dylan'],
#  ['People%27s_Republic_of_China'],
#  ['19th_century'],
#  ['Life'],
#  ['German_language'],
#  ['Hong_Kong'],
#  ['El_Salvador'],
#  ['Bicycle',
#   'Toy',
#   'Star_Wars',
#   'Computer_and_video_games',
#   'Nintendo_DS',
#   'Nintendo',
#   'The_Legend_of_Zelda_series'],
#  array(['Europe'], dtype='<U15'),
#  ['Industrial_Revolution'],
#  ['Action_potential', 'Multiple_sclerosis'],
#  ['Earth', 'Moon', 'Apollo_8'],
#  ['Egyptian_pyramids'],
#  ['United_States',
#   'Cinema_of_the_United_States',
#   '21st_century',
#   'Harry_Potter'],
#  ['Spanish_language'],
#  ['United_States', 'Olympic_Games'],
#  ['Russia', 'Cold_War'],
#  ['Attila_the_Hun'],
#  ['Spain',
#   'European_Union',
#   'Russia',
#   'Kazakhstan',
#   'Turkmenistan',
#   'Afghanistan',
#   'Pakistan',
#   'Currency',
#   'List_of_circulating_currencies'],
#  ['United_Kingdom', 'Irish_Sea', 'Ireland'],
#  ['World_War_II'],
#  ['World_War_I', 'Persian_Gulf', 'Iraq', 'Turkey'],
#  ['Monty_Python'],
#  ['United_States', 'Martin_Luther_King%2C_Jr.', 'Voting'],
#  ['London', 'Temperate', 'Tropics'],
#  ['Ununhexium'],
#  ['Tower_of_London'],
#  array(['United_States', 'Florida',
#         'United_States_House_of_Representatives', 'California', 'Oregon',
#         'River', 'Missouri_River', 'Kansas_City%2C_Missouri',
#         'United_States', 'American_Civil_War', 'Ku_Klux_Klan',
#         'U.S._state', 'United_States', 'Walt_Whitman', 'Jack_Kerouac',
#         'Chicago', 'Mississippi_River', 'Missouri_River'], dtype='<U38'),
#  ['United_States'],
#  ['World_War_II', 'War'],
#  array(['United_Kingdom', 'London', 'City_status_in_the_United_Kingdom',
#         'York'], dtype='<U33'),
#  ['United_Kingdom', 'Northern_Ireland'],
#  ['Latin',
#   'Vulgar_Latin',
#   'Roman_Empire',
#   'Civilization',
#   '11th_century',
#   'Dark_Ages',
#   'Age_of_Enlightenment'],
#  ['United_States', 'Cold_War', 'NATO'],
#  ['France'],
#  ['Germany', 'Danube'],
#  ['Volcano'],
#  ['Plant'],
#  array(['United_States', 'Chicago'], dtype='<U30'),
#  ['France', 'Louis_XIV_of_France'],
#  array(['Atlantic_Ocean', 'Tropical_cyclone', 'Gulf_of_Mexico', 'Florida',
#         'Dolphin', 'Chimpanzee', 'Cornell_University'], dtype='<U18'),
#  array(['United_States', 'Latin', 'World_War_II', 'Japan'], dtype='<U13'),
#  array(['Europe', 'United_Kingdom', 'England', 'British_Isles'],
#        dtype='<U15'),
#  array(['Plant', 'Tree', 'Apple', 'Fruit'], dtype='<U12'),
#  ['Eye', 'Lens_%28anatomy%29'],
#  ['The_Beatles'],
#  ['Capital'],
#  ['United_States',
#   'Holy_Roman_Empire',
#   'France',
#   'Paris',
#   'French_Revolution',
#   'Age_of_Enlightenment',
#   'Dark_Ages',
#   'Romanticism',
#   'Napoleonic_Wars',
#   'Roman_Empire',
#   '3rd_century',
#   '16th_century',
#   'Leonardo_da_Vinci',
#   'Bologna'],
#  ['Christianity'],
#  ['President_of_the_United_States'],
#  ['Romanticism'],
#  ['Earth'],
#  ['Inner_Hebrides'],
#  ['11th_century'],
#  ['Employment'],
#  ['Europe'],
#  array(['Europe', 'Earth', 'Universe', 'Big_Bang', 'Science', 'Technology',
#         'Organization', 'Government', 'Marxism', 'Communism'], dtype='<U12'),
#  ['Nazism', 'The_Holocaust', 'Adolf_Hitler'],
#  array(['Biology', 'Cell_%28biology%29', 'Mitochondrion'], dtype='<U18'),
#  ['Prime_Minister_of_the_United_Kingdom'],
#  ['Russia', 'Arctic'],
#  array(['Telescope'], dtype='<U9'),
#  ...]

# %% [markdown]
# ### Next Step
# use the dataframe categories to replace each page in processed paths by each category and construct the graph using categories

# %%
categories = pd.read_csv("wikispeedia_paths-and-graph/categories.tsv", sep='\t', skiprows = 12, names=['article', 'category'])

# %%
categories.head()
# Out:
#                             article  \
# 0  %C3%81ed%C3%A1n_mac_Gabr%C3%A1in
# 1  %C3%81ed%C3%A1n_mac_Gabr%C3%A1in
# 2                        %C3%85land
# 3                        %C3%85land
# 4                %C3%89douard_Manet
#
#                                             category
# 0  subject.History.British_History.British_Histor...
# 1                  subject.People.Historical_figures
# 2                                  subject.Countries
# 3  subject.Geography.European_Geography.European_...
# 4                             subject.People.Artists

# %%
# the number of periods is the specifity of the category, the more specific 
# the more relevant 
def count_periods(s):
    return s.count('.')

# %%
# Add a column with the count of periods in the category
categories['period_count'] = categories['category'].apply(count_periods)

# Selecting the most specific category for each article
most_specific_category = categories.sort_values(by='period_count', ascending=False).drop_duplicates('article')

# Dropping the period_count column to get the final result
specific_categories = most_specific_category.drop(columns=['period_count'])

# Resetting the index for cleanliness
specific_categories.reset_index(drop=True, inplace=True)

specific_categories.head()
# Out:
#                             article  \
# 0  %C3%81ed%C3%A1n_mac_Gabr%C3%A1in
# 1               European_Greenfinch
# 2                     Rutherfordium
# 3            Eurasian_Oystercatcher
# 4                      Eurasian_Jay
#
#                                             category
# 0  subject.History.British_History.British_Histor...
# 1                      subject.Science.Biology.Birds
# 2        subject.Science.Chemistry.Chemical_elements
# 3                      subject.Science.Biology.Birds
# 4                      subject.Science.Biology.Birds

# %%
# making the article column the index
specific_categories = specific_categories.set_index('article')

# %%
specific_categories.head()
# Out:
#                                                                            category
# article
# %C3%81ed%C3%A1n_mac_Gabr%C3%A1in  subject.History.British_History.British_Histor...
# European_Greenfinch                                   subject.Science.Biology.Birds
# Rutherfordium                           subject.Science.Chemistry.Chemical_elements
# Eurasian_Oystercatcher                                subject.Science.Biology.Birds
# Eurasian_Jay                                          subject.Science.Biology.Birds

# %%
# transforming the article paths into paths of categories  
processed_finished_paths_serie = pd.Series(processed_finished_paths)
category_finished_paths = processed_finished_paths_serie.map(lambda path: [specific_categories.loc[article, 'category'] if article in specific_categories.index else 'Unknown_Category' for article in path])

processed_unfinished_paths_serie = pd.Series(processed_unfinished_paths)
category_unfinished_paths = processed_unfinished_paths_serie.map(lambda path: [specific_categories.loc[article, 'category'] if article in specific_categories.index else 'Unknown_Category' for article in path])

# %%
category_finished_paths.head()
# Out:
# 0    [subject.Geography.European_Geography, subject...
# 1    [subject.Geography.African_Geography, subject....
# 2    [subject.Geography.European_Geography.European...
# 3    [subject.Geography.European_Geography.European...
# 4    [subject.Geography.North_American_Geography, s...
# dtype: object

# %%
category_unfinished_paths.head()
# Out:
# 0                        [subject.Everyday_life.Films]
# 1                  [subject.People.Historical_figures]
# 2    [subject.Citizenship.Politics_and_government, ...
# 3    [subject.Geography.Central_and_South_American_...
# 4    [subject.Geography.Central_and_South_American_...
# dtype: object

# %%
from collections import defaultdict

# building the connection dataframe with the counter
def build_category_connections(category_paths) :
    category_pairs_counter = defaultdict(int)

    # Process each path
    for path in category_paths:
        for i in range(len(path) - 1):
            # Increment the counter for each found pair
            pair = (path[i], path[i + 1])
            category_pairs_counter[pair] += 1

    # unique category list that appear in our paths, 
    # no need for all categories of articles in  

    unique_categories = list(set(cat for path in category_paths for cat in path))

    # Initialize an the connections
    category_connections = pd.DataFrame(index=unique_categories, columns=unique_categories).fillna(0)

    # filling up the values with the counts
    for (cat1, cat2), count in category_pairs_counter.items():
        category_connections.loc[cat1, cat2] = count
    
    return category_connections

# %%
category_connections_finished_paths = build_category_connections(category_finished_paths)
category_connections_finished_paths
# Out:
#                                                     subject.Citizenship.Animal_and_Human_Rights  \
# subject.Citizenship.Animal_and_Human_Rights                                                  43
# subject.IT.Cryptography                                                                       0
# subject.Everyday_life.Games                                                                   0
# subject.Religion.Religious_movements_traditions...                                            3
# subject.Everyday_life.Films                                                                   0
# ...                                                                                         ...
# subject.Geography.Natural_Disasters                                                           6
# subject.History.Recent_History                                                                2
# subject.History.Military_History_and_War                                                      0
# subject.History.General_history                                                               1
# subject.Design_and_Technology.Road_transport                                                  0
#
#                                                     subject.IT.Cryptography  \
# subject.Citizenship.Animal_and_Human_Rights                               0
# subject.IT.Cryptography                                                  13
# subject.Everyday_life.Games                                               0
# subject.Religion.Religious_movements_traditions...                        0
# subject.Everyday_life.Films                                               0
# ...                                                                     ...
# subject.Geography.Natural_Disasters                                       0
# subject.History.Recent_History                                            0
# subject.History.Military_History_and_War                                  0
# subject.History.General_history                                           0
# subject.Design_and_Technology.Road_transport                              0
#
#                                                     subject.Everyday_life.Games  \
# subject.Citizenship.Animal_and_Human_Rights                                   0
# subject.IT.Cryptography                                                       0
# subject.Everyday_life.Games                                                 188
# subject.Religion.Religious_movements_traditions...                            0
# subject.Everyday_life.Films                                                   0
# ...                                                                         ...
# subject.Geography.Natural_Disasters                                           0
# subject.History.Recent_History                                                0
# subject.History.Military_History_and_War                                      0
# subject.History.General_history                                               2
# subject.Design_and_Technology.Road_transport                                  0
#
#                                                     subject.Religion.Religious_movements_traditions_and_organizations  \
# subject.Citizenship.Animal_and_Human_Rights                                                         1
# subject.IT.Cryptography                                                                             0
# subject.Everyday_life.Games                                                                         0
# subject.Religion.Religious_movements_traditions...                                                632
# subject.Everyday_life.Films                                                                         0
# ...                                                                                               ...
# subject.Geography.Natural_Disasters                                                                 0
# subject.History.Recent_History                                                                      4
# subject.History.Military_History_and_War                                                            4
# subject.History.General_history                                                                    38
# subject.Design_and_Technology.Road_transport                                                        0
#
#                                                     subject.Everyday_life.Films  \
# subject.Citizenship.Animal_and_Human_Rights                                   0
# subject.IT.Cryptography                                                       0
# subject.Everyday_life.Games                                                   0
# subject.Religion.Religious_movements_traditions...                            0
# subject.Everyday_life.Films                                                 383
# ...                                                                         ...
# subject.Geography.Natural_Disasters                                           0
# subject.History.Recent_History                                                0
# subject.History.Military_History_and_War                                      0
# subject.History.General_history                                              39
# subject.Design_and_Technology.Road_transport                                  0
#
#                                                     subject.Citizenship.Conflict_and_Peace  \
# subject.Citizenship.Animal_and_Human_Rights                                              0
# subject.IT.Cryptography                                                                  0
# subject.Everyday_life.Games                                                              0
# subject.Religion.Religious_movements_traditions...                                       0
# subject.Everyday_life.Films                                                              0
# ...                                                                                    ...
# subject.Geography.Natural_Disasters                                                      0
# subject.History.Recent_History                                                           0
# subject.History.Military_History_and_War                                                 4
# subject.History.General_history                                                          1
# subject.Design_and_Technology.Road_transport                                             0
#
#                                                     subject.Music.Musical_Recordings_and_compositions  \
# subject.Citizenship.Animal_and_Human_Rights                                                         0
# subject.IT.Cryptography                                                                             0
# subject.Everyday_life.Games                                                                         0
# subject.Religion.Religious_movements_traditions...                                                  0
# subject.Everyday_life.Films                                                                         0
# ...                                                                                               ...
# subject.Geography.Natural_Disasters                                                                 0
# subject.History.Recent_History                                                                      0
# subject.History.Military_History_and_War                                                            0
# subject.History.General_history                                                                     1
# subject.Design_and_Technology.Road_transport                                                        0
#
#                                                     subject.People.Philosophers  \
# subject.Citizenship.Animal_and_Human_Rights                                   3
# subject.IT.Cryptography                                                       0
# subject.Everyday_life.Games                                                   0
# subject.Religion.Religious_movements_traditions...                            1
# subject.Everyday_life.Films                                                   0
# ...                                                                         ...
# subject.Geography.Natural_Disasters                                           0
# subject.History.Recent_History                                                0
# subject.History.Military_History_and_War                                      0
# subject.History.General_history                                              16
# subject.Design_and_Technology.Road_transport                                  0
#
#                                                     subject.Everyday_life.Food_and_agriculture  \
# subject.Citizenship.Animal_and_Human_Rights                                                  8
# subject.IT.Cryptography                                                                      0
# subject.Everyday_life.Games                                                                  0
# subject.Religion.Religious_movements_traditions...                                          13
# subject.Everyday_life.Films                                                                  0
# ...                                                                                        ...
# subject.Geography.Natural_Disasters                                                          6
# subject.History.Recent_History                                                               0
# subject.History.Military_History_and_War                                                     1
# subject.History.General_history                                                              9
# subject.Design_and_Technology.Road_transport                                                 0
#
#                                                     subject.Science.Chemistry.Chemical_elements  \
# subject.Citizenship.Animal_and_Human_Rights                                                   0
# subject.IT.Cryptography                                                                       0
# subject.Everyday_life.Games                                                                   0
# subject.Religion.Religious_movements_traditions...                                            0
# subject.Everyday_life.Films                                                                   0
# ...                                                                                         ...
# subject.Geography.Natural_Disasters                                                           0
# subject.History.Recent_History                                                                1
# subject.History.Military_History_and_War                                                    141
# subject.History.General_history                                                              29
# subject.Design_and_Technology.Road_transport                                                  8
#
#                                                     ...  \
# subject.Citizenship.Animal_and_Human_Rights         ...
# subject.IT.Cryptography                             ...
# subject.Everyday_life.Games                         ...
# subject.Religion.Religious_movements_traditions...  ...
# subject.Everyday_life.Films                         ...
# ...                                                 ...
# subject.Geography.Natural_Disasters                 ...
# subject.History.Recent_History                      ...
# subject.History.Military_History_and_War            ...
# subject.History.General_history                     ...
# subject.Design_and_Technology.Road_transport        ...
#
#                                                     subject.History.North_American_History  \
# subject.Citizenship.Animal_and_Human_Rights                                              0
# subject.IT.Cryptography                                                                  0
# subject.Everyday_life.Games                                                              0
# subject.Religion.Religious_movements_traditions...                                       0
# subject.Everyday_life.Films                                                              1
# ...                                                                                    ...
# subject.Geography.Natural_Disasters                                                      0
# subject.History.Recent_History                                                           0
# subject.History.Military_History_and_War                                                 0
# subject.History.General_history                                                          6
# subject.Design_and_Technology.Road_transport                                             0
#
#                                                     subject.Business_Studies.Currency  \
# subject.Citizenship.Animal_and_Human_Rights                                         0
# subject.IT.Cryptography                                                             0
# subject.Everyday_life.Games                                                         1
# subject.Religion.Religious_movements_traditions...                                  0
# subject.Everyday_life.Films                                                         0
# ...                                                                               ...
# subject.Geography.Natural_Disasters                                                 0
# subject.History.Recent_History                                                      0
# subject.History.Military_History_and_War                                            0
# subject.History.General_history                                                     1
# subject.Design_and_Technology.Road_transport                                        0
#
#                                                     subject.People.Engineers_and_inventors  \
# subject.Citizenship.Animal_and_Human_Rights                                              0
# subject.IT.Cryptography                                                                  0
# subject.Everyday_life.Games                                                              0
# subject.Religion.Religious_movements_traditions...                                       0
# subject.Everyday_life.Films                                                              0
# ...                                                                                    ...
# subject.Geography.Natural_Disasters                                                      0
# subject.History.Recent_History                                                           0
# subject.History.Military_History_and_War                                                 0
# subject.History.General_history                                                         15
# subject.Design_and_Technology.Road_transport                                            21
#
#                                                     subject.Religion.Religious_texts  \
# subject.Citizenship.Animal_and_Human_Rights                                        1
# subject.IT.Cryptography                                                            0
# subject.Everyday_life.Games                                                        0
# subject.Religion.Religious_movements_traditions...                               176
# subject.Everyday_life.Films                                                        0
# ...                                                                              ...
# subject.Geography.Natural_Disasters                                                0
# subject.History.Recent_History                                                     0
# subject.History.Military_History_and_War                                           0
# subject.History.General_history                                                    3
# subject.Design_and_Technology.Road_transport                                       0
#
#                                                     subject.Music.Musical_Instruments  \
# subject.Citizenship.Animal_and_Human_Rights                                         0
# subject.IT.Cryptography                                                             0
# subject.Everyday_life.Games                                                         0
# subject.Religion.Religious_movements_traditions...                                  0
# subject.Everyday_life.Films                                                         9
# ...                                                                               ...
# subject.Geography.Natural_Disasters                                                 0
# subject.History.Recent_History                                                      0
# subject.History.Military_History_and_War                                            0
# subject.History.General_history                                                     3
# subject.Design_and_Technology.Road_transport                                        0
#
#                                                     subject.Geography.Natural_Disasters  \
# subject.Citizenship.Animal_and_Human_Rights                                           3
# subject.IT.Cryptography                                                               0
# subject.Everyday_life.Games                                                           0
# subject.Religion.Religious_movements_traditions...                                    0
# subject.Everyday_life.Films                                                           0
# ...                                                                                 ...
# subject.Geography.Natural_Disasters                                                  47
# subject.History.Recent_History                                                        0
# subject.History.Military_History_and_War                                              1
# subject.History.General_history                                                      12
# subject.Design_and_Technology.Road_transport                                          0
#
#                                                     subject.History.Recent_History  \
# subject.Citizenship.Animal_and_Human_Rights                                      0
# subject.IT.Cryptography                                                          0
# subject.Everyday_life.Games                                                      0
# subject.Religion.Religious_movements_traditions...                               1
# subject.Everyday_life.Films                                                      0
# ...                                                                            ...
# subject.Geography.Natural_Disasters                                              0
# subject.History.Recent_History                                                  83
# subject.History.Military_History_and_War                                        10
# subject.History.General_history                                                 16
# subject.Design_and_Technology.Road_transport                                     0
#
#                                                     subject.History.Military_History_and_War  \
# subject.Citizenship.Animal_and_Human_Rights                                                0
# subject.IT.Cryptography                                                                    0
# subject.Everyday_life.Games                                                                0
# subject.Religion.Religious_movements_traditions...                                         1
# subject.Everyday_life.Films                                                                1
# ...                                                                                      ...
# subject.Geography.Natural_Disasters                                                        1
# subject.History.Recent_History                                                            93
# subject.History.Military_History_and_War                                                 384
# subject.History.General_history                                                           21
# subject.Design_and_Technology.Road_transport                                               0
#
#                                                     subject.History.General_history  \
# subject.Citizenship.Animal_and_Human_Rights                                       1
# subject.IT.Cryptography                                                           0
# subject.Everyday_life.Games                                                       0
# subject.Religion.Religious_movements_traditions...                               73
# subject.Everyday_life.Films                                                      35
# ...                                                                             ...
# subject.Geography.Natural_Disasters                                               0
# subject.History.Recent_History                                                   12
# subject.History.Military_History_and_War                                          6
# subject.History.General_history                                                1134
# subject.Design_and_Technology.Road_transport                                      0
#
#                                                     subject.Design_and_Technology.Road_transport
# subject.Citizenship.Animal_and_Human_Rights                                                    0
# subject.IT.Cryptography                                                                        0
# subject.Everyday_life.Games                                                                    0
# subject.Religion.Religious_movements_traditions...                                             0
# subject.Everyday_life.Films                                                                    0
# ...                                                                                          ...
# subject.Geography.Natural_Disasters                                                            0
# subject.History.Recent_History                                                                 0
# subject.History.Military_History_and_War                                                       1
# subject.History.General_history                                                                7
# subject.Design_and_Technology.Road_transport                                                  19
#
# [128 rows x 128 columns]

# %%
category_connections_unfinished_paths = build_category_connections(category_unfinished_paths)
category_connections_unfinished_paths
# Out:
#                                                     subject.Citizenship.Animal_and_Human_Rights  \
# subject.Citizenship.Animal_and_Human_Rights                                                  11
# subject.IT.Cryptography                                                                       0
# subject.Everyday_life.Games                                                                   0
# subject.Religion.Religious_movements_traditions...                                            0
# subject.Everyday_life.Films                                                                   0
# ...                                                                                         ...
# subject.Geography.Natural_Disasters                                                           1
# subject.History.Recent_History                                                                0
# subject.History.Military_History_and_War                                                      1
# subject.History.General_history                                                               1
# subject.Design_and_Technology.Road_transport                                                  0
#
#                                                     subject.IT.Cryptography  \
# subject.Citizenship.Animal_and_Human_Rights                               0
# subject.IT.Cryptography                                                   0
# subject.Everyday_life.Games                                               0
# subject.Religion.Religious_movements_traditions...                        0
# subject.Everyday_life.Films                                               0
# ...                                                                     ...
# subject.Geography.Natural_Disasters                                       0
# subject.History.Recent_History                                            0
# subject.History.Military_History_and_War                                  0
# subject.History.General_history                                           0
# subject.Design_and_Technology.Road_transport                              0
#
#                                                     subject.Everyday_life.Games  \
# subject.Citizenship.Animal_and_Human_Rights                                   0
# subject.IT.Cryptography                                                       0
# subject.Everyday_life.Games                                                  15
# subject.Religion.Religious_movements_traditions...                            0
# subject.Everyday_life.Films                                                   0
# ...                                                                         ...
# subject.Geography.Natural_Disasters                                           0
# subject.History.Recent_History                                                0
# subject.History.Military_History_and_War                                      0
# subject.History.General_history                                               0
# subject.Design_and_Technology.Road_transport                                  0
#
#                                                     subject.Religion.Religious_movements_traditions_and_organizations  \
# subject.Citizenship.Animal_and_Human_Rights                                                         1
# subject.IT.Cryptography                                                                             0
# subject.Everyday_life.Games                                                                         0
# subject.Religion.Religious_movements_traditions...                                                149
# subject.Everyday_life.Films                                                                         0
# ...                                                                                               ...
# subject.Geography.Natural_Disasters                                                                 0
# subject.History.Recent_History                                                                      4
# subject.History.Military_History_and_War                                                           10
# subject.History.General_history                                                                    15
# subject.Design_and_Technology.Road_transport                                                        0
#
#                                                     subject.Everyday_life.Films  \
# subject.Citizenship.Animal_and_Human_Rights                                   0
# subject.IT.Cryptography                                                       0
# subject.Everyday_life.Games                                                   0
# subject.Religion.Religious_movements_traditions...                            0
# subject.Everyday_life.Films                                                 107
# ...                                                                         ...
# subject.Geography.Natural_Disasters                                           0
# subject.History.Recent_History                                                0
# subject.History.Military_History_and_War                                      0
# subject.History.General_history                                              29
# subject.Design_and_Technology.Road_transport                                  0
#
#                                                     subject.Citizenship.Conflict_and_Peace  \
# subject.Citizenship.Animal_and_Human_Rights                                              0
# subject.IT.Cryptography                                                                  0
# subject.Everyday_life.Games                                                              0
# subject.Religion.Religious_movements_traditions...                                       0
# subject.Everyday_life.Films                                                              0
# ...                                                                                    ...
# subject.Geography.Natural_Disasters                                                      0
# subject.History.Recent_History                                                           0
# subject.History.Military_History_and_War                                                 3
# subject.History.General_history                                                          0
# subject.Design_and_Technology.Road_transport                                             0
#
#                                                     subject.Music.Musical_Recordings_and_compositions  \
# subject.Citizenship.Animal_and_Human_Rights                                                         0
# subject.IT.Cryptography                                                                             0
# subject.Everyday_life.Games                                                                         0
# subject.Religion.Religious_movements_traditions...                                                  0
# subject.Everyday_life.Films                                                                         0
# ...                                                                                               ...
# subject.Geography.Natural_Disasters                                                                 0
# subject.History.Recent_History                                                                      0
# subject.History.Military_History_and_War                                                            0
# subject.History.General_history                                                                     0
# subject.Design_and_Technology.Road_transport                                                        0
#
#                                                     subject.People.Philosophers  \
# subject.Citizenship.Animal_and_Human_Rights                                   2
# subject.IT.Cryptography                                                       0
# subject.Everyday_life.Games                                                   0
# subject.Religion.Religious_movements_traditions...                            0
# subject.Everyday_life.Films                                                   0
# ...                                                                         ...
# subject.Geography.Natural_Disasters                                           0
# subject.History.Recent_History                                                0
# subject.History.Military_History_and_War                                      0
# subject.History.General_history                                               2
# subject.Design_and_Technology.Road_transport                                  0
#
#                                                     subject.Everyday_life.Food_and_agriculture  \
# subject.Citizenship.Animal_and_Human_Rights                                                  4
# subject.IT.Cryptography                                                                      0
# subject.Everyday_life.Games                                                                  0
# subject.Religion.Religious_movements_traditions...                                           9
# subject.Everyday_life.Films                                                                  0
# ...                                                                                        ...
# subject.Geography.Natural_Disasters                                                          4
# subject.History.Recent_History                                                               0
# subject.History.Military_History_and_War                                                     0
# subject.History.General_history                                                              2
# subject.Design_and_Technology.Road_transport                                                 0
#
#                                                     subject.Science.Chemistry.Chemical_elements  \
# subject.Citizenship.Animal_and_Human_Rights                                                   0
# subject.IT.Cryptography                                                                       0
# subject.Everyday_life.Games                                                                   0
# subject.Religion.Religious_movements_traditions...                                            0
# subject.Everyday_life.Films                                                                   0
# ...                                                                                         ...
# subject.Geography.Natural_Disasters                                                           0
# subject.History.Recent_History                                                                1
# subject.History.Military_History_and_War                                                     10
# subject.History.General_history                                                              11
# subject.Design_and_Technology.Road_transport                                                  1
#
#                                                     ...  \
# subject.Citizenship.Animal_and_Human_Rights         ...
# subject.IT.Cryptography                             ...
# subject.Everyday_life.Games                         ...
# subject.Religion.Religious_movements_traditions...  ...
# subject.Everyday_life.Films                         ...
# ...                                                 ...
# subject.Geography.Natural_Disasters                 ...
# subject.History.Recent_History                      ...
# subject.History.Military_History_and_War            ...
# subject.History.General_history                     ...
# subject.Design_and_Technology.Road_transport        ...
#
#                                                     subject.History.North_American_History  \
# subject.Citizenship.Animal_and_Human_Rights                                              0
# subject.IT.Cryptography                                                                  0
# subject.Everyday_life.Games                                                              0
# subject.Religion.Religious_movements_traditions...                                       0
# subject.Everyday_life.Films                                                              0
# ...                                                                                    ...
# subject.Geography.Natural_Disasters                                                      0
# subject.History.Recent_History                                                           0
# subject.History.Military_History_and_War                                                 0
# subject.History.General_history                                                          2
# subject.Design_and_Technology.Road_transport                                             0
#
#                                                     subject.Business_Studies.Currency  \
# subject.Citizenship.Animal_and_Human_Rights                                         0
# subject.IT.Cryptography                                                             0
# subject.Everyday_life.Games                                                         0
# subject.Religion.Religious_movements_traditions...                                  0
# subject.Everyday_life.Films                                                         0
# ...                                                                               ...
# subject.Geography.Natural_Disasters                                                 0
# subject.History.Recent_History                                                      0
# subject.History.Military_History_and_War                                            0
# subject.History.General_history                                                     0
# subject.Design_and_Technology.Road_transport                                        0
#
#                                                     subject.People.Engineers_and_inventors  \
# subject.Citizenship.Animal_and_Human_Rights                                              0
# subject.IT.Cryptography                                                                  0
# subject.Everyday_life.Games                                                              0
# subject.Religion.Religious_movements_traditions...                                       0
# subject.Everyday_life.Films                                                              0
# ...                                                                                    ...
# subject.Geography.Natural_Disasters                                                      0
# subject.History.Recent_History                                                           0
# subject.History.Military_History_and_War                                                 0
# subject.History.General_history                                                          1
# subject.Design_and_Technology.Road_transport                                            12
#
#                                                     subject.Religion.Religious_texts  \
# subject.Citizenship.Animal_and_Human_Rights                                        0
# subject.IT.Cryptography                                                            0
# subject.Everyday_life.Games                                                        0
# subject.Religion.Religious_movements_traditions...                                42
# subject.Everyday_life.Films                                                        0
# ...                                                                              ...
# subject.Geography.Natural_Disasters                                                0
# subject.History.Recent_History                                                     0
# subject.History.Military_History_and_War                                           0
# subject.History.General_history                                                    1
# subject.Design_and_Technology.Road_transport                                       0
#
#                                                     subject.Music.Musical_Instruments  \
# subject.Citizenship.Animal_and_Human_Rights                                         0
# subject.IT.Cryptography                                                             0
# subject.Everyday_life.Games                                                         1
# subject.Religion.Religious_movements_traditions...                                  0
# subject.Everyday_life.Films                                                         3
# ...                                                                               ...
# subject.Geography.Natural_Disasters                                                 0
# subject.History.Recent_History                                                      0
# subject.History.Military_History_and_War                                            0
# subject.History.General_history                                                     0
# subject.Design_and_Technology.Road_transport                                        0
#
#                                                     subject.Geography.Natural_Disasters  \
# subject.Citizenship.Animal_and_Human_Rights                                           0
# subject.IT.Cryptography                                                               0
# subject.Everyday_life.Games                                                           0
# subject.Religion.Religious_movements_traditions...                                    0
# subject.Everyday_life.Films                                                           0
# ...                                                                                 ...
# subject.Geography.Natural_Disasters                                                  13
# subject.History.Recent_History                                                        0
# subject.History.Military_History_and_War                                              0
# subject.History.General_history                                                       2
# subject.Design_and_Technology.Road_transport                                          0
#
#                                                     subject.History.Recent_History  \
# subject.Citizenship.Animal_and_Human_Rights                                      0
# subject.IT.Cryptography                                                          0
# subject.Everyday_life.Games                                                      0
# subject.Religion.Religious_movements_traditions...                               0
# subject.Everyday_life.Films                                                      0
# ...                                                                            ...
# subject.Geography.Natural_Disasters                                              0
# subject.History.Recent_History                                                  35
# subject.History.Military_History_and_War                                         5
# subject.History.General_history                                                  2
# subject.Design_and_Technology.Road_transport                                     0
#
#                                                     subject.History.Military_History_and_War  \
# subject.Citizenship.Animal_and_Human_Rights                                                0
# subject.IT.Cryptography                                                                    0
# subject.Everyday_life.Games                                                                0
# subject.Religion.Religious_movements_traditions...                                         0
# subject.Everyday_life.Films                                                                2
# ...                                                                                      ...
# subject.Geography.Natural_Disasters                                                        3
# subject.History.Recent_History                                                            13
# subject.History.Military_History_and_War                                                  33
# subject.History.General_history                                                            1
# subject.Design_and_Technology.Road_transport                                               0
#
#                                                     subject.History.General_history  \
# subject.Citizenship.Animal_and_Human_Rights                                       0
# subject.IT.Cryptography                                                           0
# subject.Everyday_life.Games                                                       0
# subject.Religion.Religious_movements_traditions...                               19
# subject.Everyday_life.Films                                                      33
# ...                                                                             ...
# subject.Geography.Natural_Disasters                                               2
# subject.History.Recent_History                                                   10
# subject.History.Military_History_and_War                                          2
# subject.History.General_history                                                 280
# subject.Design_and_Technology.Road_transport                                      0
#
#                                                     subject.Design_and_Technology.Road_transport
# subject.Citizenship.Animal_and_Human_Rights                                                    0
# subject.IT.Cryptography                                                                        0
# subject.Everyday_life.Games                                                                    0
# subject.Religion.Religious_movements_traditions...                                             0
# subject.Everyday_life.Films                                                                    0
# ...                                                                                          ...
# subject.Geography.Natural_Disasters                                                            0
# subject.History.Recent_History                                                                 0
# subject.History.Military_History_and_War                                                       0
# subject.History.General_history                                                                1
# subject.Design_and_Technology.Road_transport                                                  10
#
# [128 rows x 128 columns]

# %%
def count_words(index):
    return len(index.split('.'))

# %%
# Out:
# C:\Users\rac\AppData\Local\Temp\ipykernel_19444\1948324822.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.index = df.index.str.replace('subject.', '')
# C:\Users\rac\AppData\Local\Temp\ipykernel_19444\1948324822.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.columns = df.columns.str.replace('subject.', '')

# %%
df
# Out:
#                          History  Science  Geography  Design_and_Technology  \
# History                        0        0          0                      0
# Science                        0        0          0                      0
# Geography                      0      232          0                     20
# Design_and_Technology          0        0          4                      0
# Art                           28       20          4                      0
# Business_Studies               0       36         18                      8
# Music                          8        0          4                      0
# Citizenship                    0      116          2                      0
# Religion                      46        2          6                      0
# People                        28        0         18                      4
# Language_and_literature       16        0          0                      0
# Everyday_life                  0        2          6                      0
# IT                             0        0          2                      0
# Mathematics                    4        0          0                      0
#
#                          Art  Business_Studies  Music  Citizenship  Religion  \
# History                    0                 0     12            0         8
# Science                    8                 0      0           20         0
# Geography                 68               338     28           30       268
# Design_and_Technology      0                 4      0            4         0
# Art                        0                 2    352            2        16
# Business_Studies           8                 0      8            2         0
# Music                    112                 0      0            0         0
# Citizenship                0                 0      0            0        12
# Religion                  30                 0      4           48         0
# People                     4                 0      0            4        16
# Language_and_literature   12                 0    112            0         0
# Everyday_life              0                96      0            0         0
# IT                         0               289      0            0         0
# Mathematics                8                 0      0           10        56
#
#                          People  Language_and_literature  Everyday_life   IT  \
# History                      20                       28              0    0
# Science                       0                        0              0    0
# Geography                    38                        8            102    0
# Design_and_Technology         0                        0              0    0
# Art                          10                       68             56    6
# Business_Studies              0                        0            120  221
# Music                         6                       28              0    2
# Citizenship                   0                        0              0    0
# Religion                     24                        8              2    8
# People                        0                      213              2    0
# Language_and_literature      60                        0              0    0
# Everyday_life                 2                        2              0   23
# IT                            0                        2            165    0
# Mathematics                   0                        0              0    8
#
#                          Unknown_Category  Mathematics
# History                                 0            0
# Science                                 0            0
# Geography                               0          104
# Design_and_Technology                   0            0
# Art                                     0            0
# Business_Studies                        0            0
# Music                                   0            4
# Citizenship                             0            0
# Religion                                0          156
# People                                  0            2
# Language_and_literature                 0            0
# Everyday_life                          12            0
# IT                                      0           40
# Mathematics                             0         3216

# %%
def count_words(index):
    return len(index.split('.'))

# %%
import seaborn as sns
def heatmap_general_categories(category_connections) :
    df = category_connections.copy() 
    #Remove 'subject.' prefix
    df.index = df.index.str.replace('subject.', '')
    df.columns = df.columns.str.replace('subject.', '')
    # Sort the dataframe based on the number of words in ascending order
    df['WordCount'] = df.index.map(count_words)
    df_sorted = df.sort_values(by='WordCount', ascending = False)
    df_sorted = df_sorted.drop(columns='WordCount')
    index_order = df_sorted.index.tolist()

    # Reorder the columns based on the order of the index
    df_sorted = df_sorted.reindex(columns=index_order)

    #regroup all columns that have a common prefix, to  keep only general categories
    for ind1,row1 in df_sorted.iterrows() :
        for ind2,row2 in df_sorted.iterrows() :
            if ind1.split('.')[0] == ind2.split('.')[0] :
                for ind3,row3 in df_sorted.iterrows() :
                    df_sorted.loc[ind3,ind1] += df_sorted.loc[ind3,ind2]
                    df_sorted.loc[ind1,ind3]+= df_sorted.loc[ind2,ind3]
                break
    iter1=0         
    for ind1,row1 in df_sorted.iterrows() :
            iter2=0
            for ind2,row2 in df_sorted.iterrows():
                if ind1!=ind2 and ind1.split('.')[0] == ind2.split('.')[0] and iter2<iter1 :
                    df_sorted = df_sorted.drop(columns = ind1)
                    df_sorted= df_sorted.drop(index=ind1)
                    break
                iter2+=1
            iter1+=1
        
        

    new_index = df_sorted.index.str.split('.').str.get(0)

    # Replace the index with the new_index
    df_sorted.index = new_index

    new_columns = df_sorted.columns.str.split('.').str.get(0)

    # Replace the columns with the new_columns
    df_sorted.columns = new_columns
    df = df_sorted.reindex(df.index, axis=1)
    df = df_sorted.drop(columns="Unknown_Category")
    df = df.drop(index = "Unknown_Category")
    np.fill_diagonal(df.values, 0)
    plt.figure(figsize=(10, 8))
    sns.heatmap(df, annot=True, fmt='.2f', cmap="YlGnBu", cbar=True)

    plt.title('Heatmap of Weights between Categories')
    plt.show()

# %%
heatmap_general_categories(category_connections_finished_paths)
# Out:
# C:\Users\rac\AppData\Local\Temp\ipykernel_19444\3938921778.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.index = df.index.str.replace('subject.', '')
# C:\Users\rac\AppData\Local\Temp\ipykernel_19444\3938921778.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.columns = df.columns.str.replace('subject.', '')

# %%
heatmap_general_categories(category_connections_unfinished_paths)
# Out:
# C:\Users\rac\AppData\Local\Temp\ipykernel_19444\3938921778.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.index = df.index.str.replace('subject.', '')
# C:\Users\rac\AppData\Local\Temp\ipykernel_19444\3938921778.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.columns = df.columns.str.replace('subject.', '')

# %%
#Now we can also focus only on only categories of science 

def heatMap_Special_Category(category,category_connections) : 
    df = category_connections.copy() 
    #Remove 'subject.' prefix
    df.index = df.index.str.replace('subject.', '')
    df.columns = df.columns.str.replace('subject.', '')
    df = df.filter(like='Science.', axis=1).filter(like='Science.', axis=0)
    np.fill_diagonal(df.values, 0)
    df = df.div(df.sum().sum())
    plt.figure(figsize=(10, 8))
    sns.heatmap(df, annot=True, fmt='.2f', cmap="YlGnBu", cbar=True)

    plt.title('Heatmap of Weights between Categories')
    plt.show()   
heatMap_Special_Category("",category_connections_finished_paths)
# Out:
# C:\Users\rac\AppData\Local\Temp\ipykernel_19444\568268725.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.index = df.index.str.replace('subject.', '')
# C:\Users\rac\AppData\Local\Temp\ipykernel_19444\568268725.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df.columns = df.columns.str.replace('subject.', '')
